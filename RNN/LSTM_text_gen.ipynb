# %%
import pandas as pd
import numpy
import sys
import nltk
nltk.download('punkt')
import re
import random
import matplotlib.pyplot as plt
from nltk import FreqDist
import math

from keras.models import Sequential
from keras.layers import Dense, TimeDistributed, Activation
from keras.layers import Dropout
from keras.layers import LSTM
from keras.callbacks import ModelCheckpoint
from keras.utils import np_utils
from keras.models import load_model
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/pascalequeralt/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
raw_data = pd.read_csv("tweets_clustered_15_16_17_speeches.csv") #format: 0 = twitter, 1 = speech
raw_data.head()
# Out:
#   Unnamed: 0                                           synopsis  cluster  \
# 0      (11,)  Economists on the TAX CUTS and JOBS ACT:\n\n“T...       11
# 1       (0,)  The media has been speculating that I fired Re...        0
# 2       (5,)  RT @WhiteHouse: President Trump proclaims toda...        5
# 3       (0,)  Republicans Senators are working hard to pass ...        0
# 4       (0,)  The jury was not told the killer of Kate was a...        0
#
#    format_
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0

# %%
print raw_data.shape
# Out:
# (22752, 4)

# %% [markdown]
# ## Visualize Length of Tweets
#
# * We know Twitter used to have a 140 char limit, now it has been raised to 280
# * When considering generating tweets, must generate a particular number of words and subsequent characters
# * Rather than generating an arbitrary num of characters between [140,280] or even [0,280] (which would create far too many super short tweets), generate a length based on Trump's typical usage

# %%
raw_data['length'] = raw_data.apply(lambda x: len(x.synopsis), axis=1)
raw_data.head()
# Out:
#   Unnamed: 0                                           synopsis  cluster  \
# 0      (11,)  Economists on the TAX CUTS and JOBS ACT:\n\n“T...       11
# 1       (0,)  The media has been speculating that I fired Re...        0
# 2       (5,)  RT @WhiteHouse: President Trump proclaims toda...        5
# 3       (0,)  Republicans Senators are working hard to pass ...        0
# 4       (0,)  The jury was not told the killer of Kate was a...        0
#
#    format_  length
# 0        0     231
# 1        0     275
# 2        0     113
# 3        0     279
# 4        0     173

# %%
raw_data.loc[raw_data['format_'] == 0]['length'].describe()
# Out:
# count    14173.000000
# mean       116.417343
# std         30.964453
# min          2.000000
# 25%         98.000000
# 50%        129.000000
# 75%        139.000000
# max        328.000000
# Name: length, dtype: float64

# %% [markdown]
# The longest char tweet is likely due to a URL at the end of the tweet (which does not count towards character len).  Still think it's best to cap at 280 regardless of these exceptions

# %%
raw_data.loc[raw_data['format_'] == 0]['length'].plot.hist(title="# Characters in Tweets", color='b')
plt.show()

# %%
def get_tweet_length():
    tweet_len_dist = raw_data.loc[raw_data['format_'] == 0]['length'].value_counts()
    total_tweets = tweet_len_dist.sum()
    p = tweet_len_dist/total_tweets
    
    index = numpy.random.multinomial(1,p,1).argmax()
    return tweet_len_dist.index.values[index]

# %% [markdown]
# ## Visualize number of words per tweet
#
# * This might be insightful in tuning the seq_length parameter

# %%
raw_data['num_words'] = raw_data.apply(lambda x: len(x.synopsis.split()), axis=1)
raw_data.head()
# Out:
#   Unnamed: 0                                           synopsis  cluster  \
# 0      (11,)  Economists on the TAX CUTS and JOBS ACT:\n\n“T...       11
# 1       (0,)  The media has been speculating that I fired Re...        0
# 2       (5,)  RT @WhiteHouse: President Trump proclaims toda...        5
# 3       (0,)  Republicans Senators are working hard to pass ...        0
# 4       (0,)  The jury was not told the killer of Kate was a...        0
#
#    format_  length  num_words
# 0        0     231         36
# 1        0     275         46
# 2        0     113         10
# 3        0     279         51
# 4        0     173         35

# %%
raw_data.loc[raw_data['format_'] == 0]['num_words'].plot.hist(title="# Words in Tweets", color='b')
plt.show()

# %%
raw_data.loc[raw_data['format_'] == 0]['num_words'].describe()
# Out:
# count    14173.000000
# mean        17.308051
# std          6.511801
# min          1.000000
# 25%         13.000000
# 50%         18.000000
# 75%         22.000000
# max         54.000000
# Name: num_words, dtype: float64

# %% [markdown]
# * On average, 17 words/tweet
# * interesting to see one tweet is only 1 word long - keep in mind that any tweets < seq_length set will not be trained on at all. This is probably ok if seq_length < 13. Any higher than 13 would cause loss of 25% of tweets (if using version 1 of building training set)

# %% [markdown]
# ##  Grab Tweets related to a particular topic cluster
#
# Explore topics:
# * Cluster 0 words: great country just hillary said want like looking clinton winning time 'm say big new years vote think bad trump president ll believe many american totally hillary ve got work interview making way enjoy did national things talking polls thank
# * Cluster 1 words: making america america making making great great america https let making america safe together together together realdonaldtrump trump thank s let america great vote s safe america s let let let 's let 's big needed great trump //t.co/u25yi5t7e8 https
# * Cluster 2 words: very right thank thank very very great good 's very very 's nice bad just very dishonest important very time said very sadness realdonaldtrump looking big think new very making https president watch years coming many tough very country very
# * Cluster 3 words: day great great https big big realdonaldtrump just every today 's remember winning every 's thank trump tomorrow making people another happy elections amazing day like elections national love billion white american years memorial states many looking crowd white house
# * Cluster 4 words: know n't n't know 's realdonaldtrump did said because does say said think people does did because did things like realdonaldtrump know want coming happens president ll trump know winning only does lot run just why mean right better mean
# * Cluster 5 words: https thank rt join great trump today honor realdonaldtrump maga americafirst new draintheswamp realdonaldtrump imwithyou tomorrow maga video tickets polls clinton vote support living tickets watch makeamericagreatagain trump2016 americafirst ohio imwithyou votetrump draintheswamp welcome whitehouse crookedhillary american tonight president time
# * Cluster 6 words: 's realdonaldtrump happens 's hillary time clinton country said let trump realdonaldtrump let clinton because like just 's america say good things right looking hillary america n't said think 's only great https 's why way bad 's hillary want
# * Cluster 7 words: trump2016 https trump2016 makeamericagreatagain thank makeamericagreatagain makeamericagreatagain makeamericagreatagain trump2016 trump2016 new thank thank polls thank join thank votetrump supertuesday support indiana carolina great tomorrow thank realdonaldtrump thank america south south california thank soon america pennsylvania iowa thank new hampshire polls
# * Cluster 8 words: people great great many american want american 's country many just coming n't say like because clinton love people hillary work realdonaldtrump vote said lot only https know crowd lot amazing trump new million looking got really people time ve
# * Cluster 9 words: thank thank https true true http folks eric greta great love reminded beautiful ohio say thank thank service honor amazing everybody mississippi joe thank marks general increases care man erictrump sharing usa ve final ted iowa enemies jobs foxandfriends foxnews
# * Cluster 10 words: realdonaldtrump trump run president needed thank love vote great trump2016 apprenticenbc please best run http watch celebapprentice celebrityapprentice realdonaldtrump man like country donald realdonaldtrump hopefully realdonaldtrump america 'm foxnews just true realdonaldtrump only foxandfriends time u makeamericagreatagain mr. winning agree
# * Cluster 11 words: jobs great great bring bring country american created jobs good realdonaldtrump did new good 's trade just million thank lost tax manufacturing hillary https mexico many work people fantastic companies america clinton fantastic way business want deals today workers communities
# * Cluster 12 words: states united united president president president united states america https country 's world great security national people deals trump realdonaldtrump run united states states border run mexico happens run making supreme supreme iran time court n't refugees trade citizens israel
# * Cluster 13 words: trump http donald donald president https realdonaldtrump polls 's gop trump golf trump run donald trump thank newsmax_media great new think s breitbartnews lead winning presidential want donald makeamericagreatagain vote national asktrump donald say trump making only president love asktrump
# * Cluster 14 words: n't ca ca does does did wo wo realdonaldtrump did n't n't want wait ca say think n't said why n't believe like trump winning n't because hillary n't just n't needed 's country let realdonaldtrump realdonaldtrump president used things

# %%
for c in range(0,15):
    cluster = raw_data.loc[raw_data['cluster'] == c]['synopsis']
    print 'Cluster ', c, ': ', cluster.shape, 'tweets'
# Out:
# Cluster  0 :  (9506,) tweets
# Cluster  1 :  (529,) tweets
# Cluster  2 :  (809,) tweets
# Cluster  3 :  (349,) tweets
# Cluster  4 :  (536,) tweets
# Cluster  5 :  (1961,) tweets
# Cluster  6 :  (1582,) tweets
# Cluster  7 :  (449,) tweets
# Cluster  8 :  (1141,) tweets
# Cluster  9 :  (201,) tweets
# Cluster  10 :  (2507,) tweets
# Cluster  11 :  (722,) tweets
# Cluster  12 :  (262,) tweets
# Cluster  13 :  (996,) tweets
# Cluster  14 :  (1202,) tweets

# %%
CLUSTER = 1 #Test with MAGA tweets 

clustered_data = raw_data.loc[raw_data['cluster'] == CLUSTER]['synopsis']
clustered_data.head()
# Out:
# 11     Thank you @SenOrrinHatch. Let’s continue MAKIN...
# 63     Since the first day I took office, all you hea...
# 85                             MAKE AMERICA GREAT AGAIN!
# 86              @ThePlumLineGS MAKE AMERICA GREAT AGAIN!
# 145    One of the most accurate polls last time aroun...
# Name: synopsis, dtype: object

# %% [markdown]
# ## Do some data cleanup

# %%
tweets = []
for i in clustered_data: 
    i = re.sub(r"http\S+", "", i) #remove all URLs
    i = re.sub(r"amp\S+", "", i) #remove all amps following &
    i = re.sub(r"“", '"', i) #standardize punctuation
    i = re.sub(r"”", '"', i)
    i = re.sub(r"’", "'", i)
    i = re.sub(r"‘", "'", i)
    i = re.sub(r"…", "...", i)
    tweets.append(i)

# %%
print 'Total number of tweets in CLUSTER ', CLUSTER, ":", len(tweets)
print '\nFirst 10 tweets: ', tweets[0:10]
numpy.savetxt('tweets.txt', tweets, fmt='%s')
# Out:
# Total number of tweets in CLUSTER  1 : 529
#
# First 10 tweets:  ["Thank you @SenOrrinHatch. Let's continue MAKING AMERICA GREAT AGAIN!  ", 'Since the first day I took office, all you hear is the phony Democrat excuse for losing the election, Russia, Russia,Russia.  Despite this I have the economy booming and have possibly done more than any 10 month President. MAKE AMERICA GREAT AGAIN!', 'MAKE AMERICA GREAT AGAIN!', '@ThePlumLineGS MAKE AMERICA GREAT AGAIN!', "One of the most accurate polls last time around. But #FakeNews likes to say we're in the 30's. They are wrong. Some people think numbers could be in the 50's. Together, WE will MAKE AMERICA GREAT AGAIN! ", 'Happy birthday to the great @TheLeeGreenwood. You and your beautiful song have made such a difference. MAKE AMERICA GREAT AGAIN!', 'Happy birthday to the great @leegreenwood83. You and your beautiful song have made such a difference. MAKE AMERICA GREAT AGAIN!', 'Wacky & totally unhinged Tom Steyer, who has been fighting me and my Make America Great Again agenda from beginning, never wins elections!', 'Together, we will Make America Great Again!\n#AmericaFirst\xf0\x9f\x87\xba\xf0\x9f\x87\xb8 ', 'MAKE AMERICA GREAT AGAIN! ']

# %% [markdown]
# ## Tokenize words

# %%
# create mapping of unique chars to integers
all_text = ' '.join(tweets).decode('utf-8')

chars = sorted(list(set(all_text)))
char_to_int = dict((c, i) for i, c in enumerate(chars))
print char_to_int
# for c in char_to_int:
#     print c
print len(all_text)
# Out:
# {u' ': 1, u'$': 5, u'(': 9, u',': 11, u'0': 15, u'4': 19, u'8': 23, u'\ud83c': 85, u'@': 29, u'D': 33, u'H': 37, u'L': 41, u'P': 45, u'T': 49, u'd': 59, u'h': 63, u'l': 67, u'p': 71, u't': 75, u'x': 79, u'\u200b': 83, u'\u2013': 84, u'\xa0': 82, u'#': 4, u"'": 8, u'/': 14, u'3': 18, u'7': 22, u';': 26, u'?': 28, u'C': 32, u'G': 36, u'\udc4d': 87, u'K': 40, u'O': 44, u'S': 48, u'W': 52, u'_': 55, u'c': 58, u'g': 62, u'k': 66, u'o': 70, u's': 74, u'w': 78, u'\uddfa': 89, u'\n': 0, u'"': 3, u'&': 7, u'\ud83d': 86, u'.': 13, u'2': 17, u'6': 21, u':': 25, u'B': 31, u'F': 35, u'J': 39, u'N': 43, u'R': 47, u'V': 51, u'Z': 54, u'b': 57, u'f': 61, u'j': 65, u'n': 69, u'r': 73, u'v': 77, u'z': 81, u'!': 2, u'%': 6, u')': 10, u'-': 12, u'1': 16, u'5': 20, u'9': 24, u'=': 27, u'A': 30, u'E': 34, u'I': 38, u'M': 42, u'Q': 46, u'U': 50, u'Y': 53, u'a': 56, u'e': 60, u'i': 64, u'm': 68, u'q': 72, u'u': 76, u'y': 80, u'\uddf8': 88}
# 57366

# %%
words = re.findall(r"[\w'+]+|[.,!?;@#*'*]", all_text)

tweets_tokenized = []
for tweet in tweets: 
    tweet = re.findall(r"[\w'+]+|[.,!?;@#*'*]", tweet)
    tweets_tokenized.append(tweet)

# %%
for tweet in tweets_tokenized[0:30]:
   print tweet
# Out:
# ['Thank', 'you', '@', 'SenOrrinHatch', '.', "Let's", 'continue', 'MAKING', 'AMERICA', 'GREAT', 'AGAIN', '!']
# ['Since', 'the', 'first', 'day', 'I', 'took', 'office', ',', 'all', 'you', 'hear', 'is', 'the', 'phony', 'Democrat', 'excuse', 'for', 'losing', 'the', 'election', ',', 'Russia', ',', 'Russia', ',', 'Russia', '.', 'Despite', 'this', 'I', 'have', 'the', 'economy', 'booming', 'and', 'have', 'possibly', 'done', 'more', 'than', 'any', '10', 'month', 'President', '.', 'MAKE', 'AMERICA', 'GREAT', 'AGAIN', '!']
# ['MAKE', 'AMERICA', 'GREAT', 'AGAIN', '!']
# ['@', 'ThePlumLineGS', 'MAKE', 'AMERICA', 'GREAT', 'AGAIN', '!']
# ['One', 'of', 'the', 'most', 'accurate', 'polls', 'last', 'time', 'around', '.', 'But', '#', 'FakeNews', 'likes', 'to', 'say', "we're", 'in', 'the', "30's", '.', 'They', 'are', 'wrong', '.', 'Some', 'people', 'think', 'numbers', 'could', 'be', 'in', 'the', "50's", '.', 'Together', ',', 'WE', 'will', 'MAKE', 'AMERICA', 'GREAT', 'AGAIN', '!']
# ['Happy', 'birthday', 'to', 'the', 'great', '@', 'TheLeeGreenwood', '.', 'You', 'and', 'your', 'beautiful', 'song', 'have', 'made', 'such', 'a', 'difference', '.', 'MAKE', 'AMERICA', 'GREAT', 'AGAIN', '!']
# ['Happy', 'birthday', 'to', 'the', 'great', '@', 'leegreenwood83', '.', 'You', 'and', 'your', 'beautiful', 'song', 'have', 'made', 'such', 'a', 'difference', '.', 'MAKE', 'AMERICA', 'GREAT', 'AGAIN', '!']
# ['Wacky', 'totally', 'unhinged', 'Tom', 'Steyer', ',', 'who', 'has', 'been', 'fighting', 'me', 'and', 'my', 'Make', 'America', 'Great', 'Again', 'agenda', 'from', 'beginning', ',', 'never', 'wins', 'elections', '!']
# ['Together', ',', 'we', 'will', 'Make', 'America', 'Great', 'Again', '!', '#', 'AmericaFirst']
# ['MAKE', 'AMERICA', 'GREAT', 'AGAIN', '!']
# ['Just', 'arrived', 'in', 'Indianapolis', ',', 'Indiana', 'to', 'make', 'an', 'announcement', 'on', '#', 'TaxReform', '!', 'Together', ',', 'we', 'are', 'going', 'to', 'MAKE', 'AMERICA', 'GREAT', 'AGAIN', '!']
# ['Making', 'America', 'Safe', 'is', 'my', 'number', 'one', 'priority', '.', 'We', 'will', 'not', 'admit', 'those', 'into', 'our', 'country', 'we', 'cannot', 'safely', 'vet', '.']
# ['Courageous', 'Patriots', 'have', 'fought', 'and', 'died', 'for', 'our', 'great', 'American', 'Flag', 'we', 'MUST', 'honor', 'and', 'respect', 'it', '!', 'MAKE', 'AMERICA', 'GREAT', 'AGAIN', '!']
# ['Big', 'meetings', 'today', 'at', 'the', 'United', 'Nations', '.', 'So', 'many', 'interesting', 'leaders', '.', 'America', 'First', 'will', 'MAKE', 'AMERICA', 'GREAT', 'AGAIN', '!']
# ['RT', '@', 'glamourizes', '@', 'realDonaldTrump', 'Only', 'true', 'Americans', 'can', 'see', 'that', 'president', 'Trump', 'is', 'making', 'America', 'great', '.', "He's", 'the', 'only', 'person', 'who', 'can', '!', 'H', '.', '.', '.']
# ['RT', '@', 'LouDobbs', 'Making', 'America', 'Great', 'Again', '@', 'Kellyannepolls', 'After', '#', 'Irma', '@', 'POTUS', 'is', 'focused', 'on', 'saving', 'lives', ',', 'not', 'swamp', 'shenanigans', '.', '#', 'Dobbs', '#', 'MA', '.', '.', '.']
# ['MAKE', 'AMERICA', 'GREAT', 'AGAIN', '!']
# ['MAKE', 'AMERICA', 'GREAT', 'AGAIN', '!']
# ['MAKE', 'AMERICA', 'GREAT', 'AGAIN', '!']
# ['Thank', 'you', 'West', 'Virginia', '!', 'All', 'across', 'the', 'country', ',', 'Americans', 'of', 'every', 'kind', 'are', 'coming', 'together', 'w', 'one', 'simple', 'goal', 'to', 'MAKE', 'AMERICA', 'GREAT', 'AGAIN', '!']
# ['Just', 'arrived', 'in', 'West', 'Virginia', 'for', 'a', 'MAKE', 'AMERICA', 'GREAT', 'AGAIN', 'rally', 'in', 'Huntington', 'at', '7', '00pmE', '.', 'Massive', 'crowd', 'expected', 'tune', 'in', '!', '#', 'MAGA']
# ['MAKE', 'AMERICA', 'GREAT', 'AGAIN', '!']
# ['MAKE', 'AMERICA', 'GREAT', 'AGAIN', '!']
# ['My', 'use', 'of', 'social', 'media', 'is', 'not', 'Presidential', "it's", 'MODERN', 'DAY', 'PRESIDENTIAL', '.', 'Make', 'America', 'Great', 'Again', '!']
# ['MAKE', 'AMERICA', 'SAFE', 'AGAIN', '!', '#', 'NoSanctuaryForCriminalsAct', '#', 'KatesLaw', '#', 'SaveAmericanLives']
# ['MAKE', 'AMERICA', 'GREAT', 'AGAIN', '!']
# ['Together', ',', 'we', 'are', 'going', 'to', 'MAKE', 'AMERICA', 'GREAT', 'AGAIN', '!', '#', 'AmericaFirst']
# ['Thank', 'you', 'Kirkwood', 'Community', 'College', '.', 'Heading', 'to', 'the', 'U', '.', 'S', '.', 'Cellular', 'Center', 'now', 'for', 'an', '8pmE', 'MAKE', 'AMERICA', 'GREAT', 'AGAIN', '.', '.', '.']
# ['Well', ',', 'the', 'Special', 'Elections', 'are', 'over', 'and', 'those', 'that', 'want', 'to', 'MAKE', 'AMERICA', 'GREAT', 'AGAIN', 'are', '5', 'and', 'O', '!', 'All', 'the', 'Fake', 'News', ',', 'all', 'the', 'money', 'spent', '0']
# ['The', 'MAKE', 'AMERICA', 'GREAT', 'AGAIN', 'agenda', 'is', 'doing', 'very', 'well', 'despite', 'the', 'distraction', 'of', 'the', 'Witch', 'Hunt', '.', 'Many', 'new', 'jobs', ',', 'high', 'business', 'enthusiasm', ',', '.', '.']

# %%
# create mapping of unique words to integers
unique_words = sorted(list(set(words)))
word_to_int = dict((w, i) for i, w in enumerate(unique_words))
int_to_word = dict((i, w) for i, w in enumerate(unique_words))
print word_to_int
# Out:
# {u'EVERYONE': 241, u'personally': 1410, u'Chris_R_2014': 173, u'Toledo': 685, u"tonight's": 1665, u'someplace': 1571, u'votes': 1726, u'LAST': 372, u"China's": 170, u'Watch': 751, u'Ronald': 570, u'voted': 1724, u'under': 1699, u'@': 57, u'digit': 999, u'rise': 1506, u'PATRIOTS': 506, u'VoteTrump': 733, u'GO': 274, u'Rsherfy': 574, u'tickets': 1656, u'four': 1108, u'SJSOPIO': 590, u'ovation': 1390, u'PattyDs50': 521, u'red': 1486, u'Go': 283, u'Paul': 522, u'WartburgCollege': 748, u'leaders': 1248, u'blue': 873, u'Arizona': 98, u'OgreUasshole': 493, u'endorse': 1035, u'new': 1353, u'ever': 1053, u'Presidential': 540, u'Made': 416, u'hero': 1165, u'Sioux': 619, u'men': 1306, u'here': 1164, u'Ohio': 495, u'100': 13, u'IACaucus': 321, u'tweet4upatriots': 1691, u'kids': 1237, u'CrookedHillary': 197, u'Tuesday': 703, u'military': 1312, u'NOW': 456, u'fantastic': 1074, u'secure': 1531, u'SaveAmericanLives': 607, u'Jeb': 348, u'4TH': 43, u'counts': 964, u'total': 1669, u'would': 1786, u'June': 357, u'negative': 1343, u'Stay': 630, u'call': 901, u'ANHQDC': 68, u'LikeWhoa134': 391, u'25th': 30, u'tell': 1634, u'supporters': 1615, u'successful': 1611, u'phony': 1414, u'V': 716, u'hold': 1175, u'must': 1330, u'me': 1298, u'bizman': 869, u'join': 1227, u'room': 1510, u'work': 1776, u'Rubio': 575, u'FoxNewsInsider': 269, u'TMAC7771': 651, u'MAKING': 405, u'my': 1331, u'CNNPolitics': 147, u'give': 1120, u'MEMEoryHead': 409, u'want': 1733, u'keep': 1234, u'worse': 1784, u'end': 1034, u'Phoenix': 530, u'turn': 1688, u'song': 1573, u'ONE': 486, u'how': 1182, u'amazing': 809, u'Mike_Pence': 436, u'interview': 1213, u'disappoint': 1002, u'ConcordNHPatch': 189, u'ChangeTheWorldIn5Words': 165, u'mess': 1307, u'after': 794, u'Will': 763, u'wrong': 1787, u'president': 1444, u'law': 1246, u'All': 83, u'ELECT': 239, u'wins': 1766, u'ultimate': 1697, u'REFORMS': 547, u'every': 1054, u'order': 1381, u'updates': 1707, u'office': 1371, u'PEOPLE': 507, u'over': 1392, u'MakeAmericaGreatAgain': 420, u'ticket': 1655, u'before': 853, u'some': 1568, u'personal': 1409, u'fix': 1092, u'SAF': 582, u'better': 863, u'donors': 1013, u'them': 1641, u'Kids': 368, u'safe': 1517, u'break': 888, u'patty_laughlin': 1406, u'they': 1645, u'schools': 1528, u'Pandorasandy1': 516, u'Four': 267, u'skills': 1557, u'victory': 1717, u'each': 1021, u'financial': 1088, u'Kellyannepolls': 366, u'dumping': 1019, u'Wow': 770, u'vote': 1723, u'DONALD': 205, u'PUPPET': 514, u'Factor': 256, u'mandated': 1289, u'message': 1308, u'open': 1377, u'got': 1130, u'Super': 640, u'Must': 443, u'Join': 354, u'MEDIA': 407, u'yesterday': 1791, u'vets': 1716, u'angiecallahan4': 816, u'Iran': 336, u'wanted': 1734, u'certified': 919, u'Via': 727, u'Clinton': 179, u'National': 460, u'days': 980, u'creates': 967, u'TIME': 650, u'onto': 1376, u'already': 805, u'DonaldTrump2016': 230, u'Please': 533, u'primary': 1445, u'another': 821, u'JULY': 344, u'service': 1542, u'top': 1668, u'approximately': 828, u'TrumpPence16': 700, u'needed': 1341, u'syoka68': 1621, u'master': 1294, u'too': 1666, u'bitter': 868, u'MintzShire': 437, u'serve': 1541, u'took': 1667, u'negotiating': 1346, u'Summit': 638, u'tperkins': 1672, u'Kaine': 360, u'begins': 856, u'immigrants': 1193, u'negotiator': 1348, u'MAJORITY': 403, u'See': 613, u'VincentKunicki': 729, u'kevcirilli': 1235, u'Chicago': 168, u'mind': 1315, u'mine': 1316, u'spent': 1583, u'selflessness': 1538, u'talking': 1626, u'seen': 1535, u'seek': 1534, u'Then': 675, u'strength': 1606, u'NEVER': 450, u"Let's": 386, u'They': 677, u'KatesLaw': 362, u'even': 1051, u'Stevekwebb': 631, u'LEGAL': 375, u'VAST': 718, u'Typical': 706, u'neighborhoods': 1350, u'released': 1489, u'metal': 1309, u'swamp': 1617, u'points': 1423, u'enterprise': 1044, u'voting': 1727, u'came': 903, u'saying': 1527, u'Baltimore': 111, u'meetings': 1302, u'solutions': 1566, u'specialists': 1580, u'Big': 120, u'C2GTHR': 139, u'Republicans': 567, u'Free': 270, u"Obama's": 492, u'sunquist007': 1613, u'LIVE': 3 ...

# %% [markdown]
# NOTE: Consider removing the random characters that appear at the end and may only confuse the model

# %%
n_words = len(words)
n_vocab = len(unique_words)
print "Total Words: ", n_words
print "Total Vocab: ", n_vocab
# Out:
# Total Words:  11487
# Total Vocab:  1796

# %% [markdown]
# NOTE: Typical book length that generates good results is around 150,000 characters (when doing a character by character RNN generation)

# %% [markdown]
# ## Build training set

# %% [markdown]
# ### Version 1: Separate by tweet
#
# * Creates training set of sum of the lengths of all tweets - num_tweets * seq_length
# * This produces a smaller data set, but I hypothesize a data set of more value because of the grouping of words discreetly by tweet (thematically discreet training)

# %%
#words = array of all words and punctuation in the corpus 
#n_words = # of total words in text 
#n_vocab = # of unique words in text 

seq_length = 10

num = 0
for tweet in tweets_tokenized:
    if len(tweet) > seq_length: 
        num += len(tweet) - seq_length
#print num

X_version_bytweet = numpy.zeros((num, seq_length, n_vocab))
y_version_bytweet = numpy.zeros((num, seq_length, n_vocab))

index = 0;
for tweet in tweets_tokenized:
    #print '------------NEXT TWEET--------------'
    n_words = len(tweet)
    #print n_words
    
    #print 'limit: ', n_words-seq_length
    for i in range(0, n_words-seq_length, 1):
        #print index
        X_sequence = tweet[i:i+seq_length]
        X_sequence_ix = [word_to_int[value] for value in X_sequence]
        input_sequence = numpy.zeros((seq_length, n_vocab))
        for j in range(seq_length):
            input_sequence[j][X_sequence_ix[j]] = 1.
        X_version_bytweet[index] = input_sequence

        y_sequence = tweet[i+1:i+seq_length+1]
        y_sequence_ix = [word_to_int[value] for value in y_sequence]
        target_sequence = numpy.zeros((seq_length, n_vocab))
        for j in range(seq_length):
            target_sequence[j][y_sequence_ix[j]] = 1.
        y_version_bytweet[index] = target_sequence

        index += 1
        #print 'input seq: ', X_sequence
        #print 'output seq: ', y_sequence
        

n_patterns = len(X_version_bytweet)
print "Total Patterns: ", n_patterns
# Out:
# Total Patterns:  6902

# %% [markdown]
# ### Version 2: No distinction between tweets
#
# * Creates training set of length n_words - seq_length
# * The training set for this version is longer, but potentially less coherent since tweets can run into each other

# %%
#words = array of all words and punctuation in the corpus 
#n_words = # of total words in text 
#n_vocab = # of unique words in text 

seq_length = 8

X_version_byalltext = numpy.zeros((n_words-seq_length, seq_length, n_vocab))
y_version_byalltext = numpy.zeros((n_words-seq_length, seq_length, n_vocab))

#print n_words

for i in range(0, n_words-seq_length-1, 1):
    X_sequence = words[i:i+seq_length]
    X_sequence_ix = [word_to_int[value] for value in X_sequence]
    input_sequence = numpy.zeros((seq_length, n_vocab))
    for j in range(seq_length):
        input_sequence[j][X_sequence_ix[j]] = 1.
    X_version_byalltext[i] = input_sequence

    y_sequence = words[i+1:i+seq_length+1]
    y_sequence_ix = [word_to_int[value] for value in y_sequence]
    target_sequence = numpy.zeros((seq_length, n_vocab))
    for j in range(seq_length):
        target_sequence[j][y_sequence_ix[j]] = 1.
    y_version_byalltext[i] = target_sequence
    
    #print 'input seq: ', X_sequence
    #print 'output seq: ', y_sequence
    #print i

n_patterns = len(X_version_byalltext)
print "Total Patterns: ", n_patterns
# Out:
# Total Patterns:  11479

# %% [markdown]
# ## Generate Tweets from a model!

# %%
def generate_words(model):
    max_length = get_tweet_length() # in characters
    
    ix = [numpy.random.randint(n_vocab)]
    y_char = [int_to_word[ix[-1]]]
    X = numpy.zeros((1, max_length, n_vocab))
    
    punct_chars = set('.,;?!')
    
    char_length = len(y_char[0])
    i = 0
    while char_length < max_length:
        X[0, i, :][ix[-1]] = 1
        #print(int_to_word[ix[-1]])
        ix = numpy.argmax(model.predict(X[:, :i+1, :])[0], 1)
        next_word = int_to_word[ix[-1]]
        y_char.append(next_word)
        
        if next_word in punct_chars: 
            char_length += len(next_word)
        else: 
            char_length += len(next_word) + 1
        i += 1
    print 'total chars: ', char_length
    return y_char

# %%
def join_punctuation(seq, characters='.,;?!"', twitter_characters='@#"'):
    characters = set(characters)
    twitter_characters = set(twitter_characters)
    seq = iter(seq)
    current = next(seq)

    for nxt in seq:
        if current in twitter_characters:
            current += nxt
        elif nxt in characters:
            current += nxt
        else:
            yield current
            current = nxt

    yield current

def output_as_sentence(words):
    print ' '.join(join_punctuation(words))

# %% [markdown]
# ## Train Model

# %%
def create_model(HIDDEN_DIM, LAYER_NUM):
    #HIDDEN_DIM = 700
    #LAYER_NUM = 3

    model = Sequential()
    model.add(LSTM(HIDDEN_DIM, input_shape=(None, n_vocab), return_sequences=True))
    for i in range(LAYER_NUM - 1):
        model.add(LSTM(HIDDEN_DIM, return_sequences=True))
    model.add(TimeDistributed(Dense(n_vocab)))
    model.add(Activation('softmax'))
    model.compile(loss="categorical_crossentropy", optimizer="rmsprop")
    
    return model

# %% [markdown]
# ### Model 1

# %%
BATCH_SIZE = 128
HIDDEN_DIM = 700
LAYER_NUM = 3 
nb_epoch = 0

model1 = create_model(HIDDEN_DIM, LAYER_NUM)

# %%
for i in range (0,200):
    print('\n\n')
    model1.fit(X_version_bytweet, y_version_bytweet, batch_size=BATCH_SIZE, verbose=1, nb_epoch=1)
    nb_epoch += 1
    output_as_sentence(generate_words(model1))
    if nb_epoch % 10 == 0:
        model1.save_weights('model1/checkpoint_{}_epoch_{}.hdf5'.format(HIDDEN_DIM, nb_epoch))
        model1.save('model1/checkpoint_{}_epoch_{}.h5'.format(HIDDEN_DIM, nb_epoch))
# Out:
# Epoch 1/1
# 7886/7886 [==============================] - 180s - loss: 6.0150
# total chars:  34
# statement the.....................
#
#
#
# Epoch 1/1
# 7886/7886 [==============================] - 5650s - loss: 5.5184
# total chars:  132
# know................................................................................................................................
#
#
#
# Epoch 1/1
# 7886/7886 [==============================] - 17186s - loss: 5.0374
# total chars:  100
# crimes........... the Dems, the the,,,,,,,,,,, the........... the Dems, the the,,,,,,,,,, that was..
#
#
#
# Epoch 1/1
# 7886/7886 [==============================] - 8785s - loss: 4.5400
# total chars:  146
# TuckerCarlson, the Administration that the Comey investigation, the Comey story, 000, the FBI and.................................................
#
#
#
# Epoch 1/1
# 7886/7886 [==============================] - 178s - loss: 4.1052
# total chars:  139
# learning the election. What have a wrong and hacking equipment, Russia.....................................................................
#
#
#
# Epoch 1/1
# 7886/7886 [==============================] - 177s - loss: 3.6961
# total chars:  87
# a FBI Media Sweden the Obama thing that ever happened to the FBI the the Administration
#
#
#
# Epoch 1/1
# 7886/7886 [==============================] - 170s - loss: 3.2665
# total chars:  137
# FILES the FBI itself. Totally illegal the advantage to Electoral!!!!??...................................................................
#
#
#
# Epoch 1/1
# 7886/7886 [==============================] - 168s - loss: 2.8672
# total chars:  118
# things the phony story. " will it it it?..............................................................................
#
#
#
# Epoch 1/1
# 7886/7886 [==============================] - 168s - loss: 2.4800
# total chars:  114
# hacks election....................................................................................................
#
#
#
# Epoch 1/1
# 7886/7886 [==============================] - 167s - loss: 2.1350
# total chars:  91
# gone to the Social Media Guidelines that they installed to many say that Russia was no hasn
#
#
#
# Epoch 1/1
# 7886/7886 [==============================] - 169s - loss: 1.8332
# total chars:  142
# thank years Hillary Clinton have been released from prison, is now!!!!!!!!!!!!! and and and and and................ B book book book Hunt book
#
#
#
# Epoch 1/1
# 7886/7886 [==============================] - 167s - loss: 1.5783
# total chars:  140
# he was a free pass for many bad deeds!!!!!!! and and FBI FBI FBI his A. These illegal information, " like praise of Russia deal, and and and
#
#
#
# Epoch 1/1
# 7886/7886 [==============================] - 179s - loss: 1.3711
# total chars:  56
# FakeNews, and did. We. Based on the a VERY weak position
#
#
#
# Epoch 1/1
# 7886/7886 [==============================] - 165s - loss: 1.2045
# total chars:  94
# Todd and @ NBCNews start talking about the Obama Administration has about why why why they not
#
#
#
# Epoch 1/1
# 7886/7886 [==============================] - 165s - loss: 1.0757
# total chars:  155
# idea to Unfair to get the sanctions on Russia lifted? obstruct. Did have even lost?................. gave gave gave gave gave gave gave gave gave gave gave
#
#
#
# Epoch 1/1
# 7886/7886 [==============================] - 165s - loss: 0.9759
# total chars:  128
# Rigged month went down by 12 billion vs a 200 billion increase in Obama Obama? Jail meddling?........... Hunt Hunt Hunt gave GPS
#
#
#
# Epoch 1/1
# 7886/7886 [==============================] - 166s - loss: 0.8869
# total chars:  225
# low has President Obama gone to tapp my phones during the a election loss..................... gave. gave................ 33. 33. 33. 33. 33. 33. 33. 33. 33. 33. 33. 33. 33. 33. 33. 33. 33. 33. 33. 33. 33. 33. 33. 33. 33. 33.
#
#
#
# Epoch 1/1
# 7886/7886 [==============================] - 182s - loss: 0.8278
# total chars:  148
# don t appreciate how " kind " President Obama was to the DNC the the FBI and the FBI and be FBI still still still his even..................... gave
#
#
#
# Epoch 1/1
# 7886/7886 [==============================] - 165s - loss: 0.7807
# total chars:  140
# Putin, have no deals in Russia, and the failed. I lost the... Major! paid!...... have have have have have gave gave gave gave gave gave gave
#
#
#
# Epoch 1/1
# 7886/7886 [==============================] - 165s - loss: 0.7426
# total chars:  126
# Do you believe it? interference 3 years ago but he did????!!!!!!!!!!!. s s s book book book book book book book book book book
#
#
#
# Epoch 1/1
# 7886/7886 [==============================] - 165s - loss: 0.7128
# total chars:  146
# did not want to " rock the boat. " He didn t the House Intelligence Committee looking into the newspapers soon after she explained it to Democrats
#
#
#
# Epoch 1/1
# 7886/7886 [==============================] - 164s - loss: 0.6899
# total chars:  139
# massive unfunded liability and non existent sources, remain in business in? for?................ paid paid paid s s paid s s s s paid s s s
#
#
#
# Epoch 1/1
# 7886/7886 [==============================] - 165s - loss: 0.6726
# total chars:  173
# tears itself apart over a Democrat EXCUSE for losing the election!!!!!!..................... have have!!!!!!!!! me! me!!!!!!!!!!! information information....................
#
#
#
# Epoch 1/1
# 7886/7886 [==============================] - 165s - loss: 0.6596
# total chars:  124
# receiving the answers to the debate? Just information???????????????????????????????????!!!!!!!!!!!! and and and information
#
#
#
# Epoch 1/1
# 7886/7886 [==============================] - 165s - loss: 0.6513
# total chars:  140
# but herself for her election loss. She lost? Focus!!, ".. and...............................................................................
#
#
#
# Epoch 1/1
# 7886/7886 [==============================] - 164s - loss: 0.6428
# total chars:  142
# LEAKERS in the intelligence community.........................................................................................................
#
#
#
# Epoch 1/1
# 7886/7886 [==============================] - 165s - loss: 0.6346
# total chars:  86
# proof, so now they go for obstruction of justice on the phony story. "................
#
#
#
# Epoch 1/1
# 7886/7886 [==============================] - 164s - loss: 0.6292
# total chars:  143
# whereas Crooked Hillary Clinton deleted acid washed her 33, 000 deleted for deleted!!!,,,,,,,,,,,,,,,!!!!!!!!!!!!!!!! down! down down down down
#
#
#
# Epoch 1/1
# 7886/7886 [==============================] - 164s - loss: 0.6254
# total chars:  144
# e mails to the media authorities whereas Crooked Hillary Clinton deleted Dems and all that this is a big big trouble which is why they cancelled
#
#
#
# Epoch 1/1
# 7886/7886 [==============================] - 164s - loss: 0.6222
# total chars:  284
# fired they PRETEND to be aggrieved. Phony!!!................................................................................................................................................................................................................................................
#
#
#
# Epoch 1/1
# 7886/7886 [==============================] - 166s - loss: 0.6178
# total chars:  55
# FILES to be opened. He vehemently denied it. I. already
#
#
#
# Epoch 1/1
# 7886/7886 [==============================] - 164s - loss: 0.6180
# total chars:  131
# Classified information. Must find leaker now!........................!!!!!!!....!!!!!!!!... I I. from from from from from book book
#
#
#
# Epoch 1/1
# 7886/7886 [==============================] - 165s - loss: 0.6135
# total chars:  47
# next week on............................. I I I
#
#
#
# Epoch 1/1
# 7886/7886 [==============================] - 165s - loss: 0.6118
# total chars:  59
# grip on reality. The real story... was, was................
#
#
#
# Epoch 1/1
# 7886/7886 [==============================] - 164s - loss: 0.6088
# total chars:  138
# info after it was supposedly hacked by Russia.............................................................................................
#
#
#
# Epoch 1/1
# 7886/7886 [==============================] - 167s - loss: 0.6087
# total chars:  77
# Laundering where is our Justice Department? SnoopDogg, failing career and all
#
#
#
# Epoch 1/1
# 7886/7886 [==============================] - 165s - loss: 0.6068
# total chars:  139
# ads on Facebook. What about the deleted E mails, classified JFK FILES for be lost!.........................................................
#
#
#
# Epoch 1/1
# 7886/7886 [==============================] - 164s - loss: 0.6042
# total chars:  143
# service. He came to the c during my run c c go????????????????????????????????!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!! for!! for for!
#
#
#
# Epoch 1/1
# 7886/7886 [==============================] - 164s - loss: 0.6040
# total chars:  139
# He came to the c during my run against Crooked??????????????????????????????????????!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#
#
#
# Epoch 1/1
# 7886/7886 [==============================] - 165s - loss: 0.6013
# total chars:  62
# subscribers for the poor reporting it did on my election! Lets
#
#
#
# Epoch 1/1
# 7886/7886 [==============================] - 164s - loss: 0.6003
# total chars:  133
# Barron Trump Russia,.................................................................................................................
#
#
#
# Epoch 1/1
# 7886/7886 [==============================] - 164s - loss: 0.5984
# total chars:  161
# other words, Russia was against Trump in the 2016?...............................................................................................................
#
#
#
# Epoch 1/1
# 7886/7886 [==============================] - 164s - loss: 0.5975
# total chars:  140
# That are have illegal leaks coming out of Washington? Will answer!. ". out,,,,,,,,,,,.................................................,,,,,,
#
#
#
# Epoch 1/1
# 7886/7886 [==============================] - 164s - loss: 0.5958
# total chars:  24
# Former Homeland Security
#
#
#
# Epoch 1/1
# 7886/7886 [==============================] - 164s - loss: 0.5947
# total chars:  118
# Nixon Watergate. Bad or sick guy!!! hold,!!!!! leaks..................................................................
#
#
#
# Epoch 1/1
# 7886/7886 [==============================] - 164s - loss: 0.5943
# total chars:  125
# allowed to so collude? Unfair to Bernie!! go!!!!?............................................................................
#
#
#
# Epoch 1/1
# 7886/7886 [==============================] - 164s - loss: 0.5921
# total chars:  140
# From @ FoxNews " Bombshell In 2016, Obama dismissed paid, Russia will respect us far more. the debates and?,,,..............................
#
#
#
# Epoch 1/1
# 7886/7886 [==============================] - 164s - loss: 0.5925
# total chars:  137
# other information. It is a total " witch hunt! " @ FoxNews...............................................................................
#
#
#
# Epoch 1/1
# 7886/7886 [==============================] - 164s - loss: 0.5892
# total chars:  136
# reporters went Rogue! @ foxandfriends. " Spied on before nomination. " Classified!!!!! and and!!!!............??????????????????????????
#
#
#
# Epoch 1/1
# 7886/7886 [==============================] - 165s - loss: 0.5893
# total chars:  99
# Sweden was in reference to a story that was was was never. " Major etc. "!!!!!!!!!!!...............
#
#
#
# Epoch 1/1
# 7886/7886 [==============================] - 165s - loss: 0.5874
# total chars:  126
# Many.................................................................................................................,,,,,,,,,
#
#
#
# Epoch 1/1
# 7886/7886 [==============================] - 164s - loss: 0.5858
# total chars:  137
# E mails DNC server Intel leakers!!,, of,,,,,,,??!!,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
#
#
#
# Epoch 1/1
# 7886/7886 [==============================] - 166s - loss: 0.5844
# total chars:  147
# Korea unfunded liability and non existent sources, remain in business??? name!!! Witch Witch me!!!!!!! Witch and and and!!! Witch Witch Witch Witch
#
#
#
# Epoch 1/1
# 7886/7886 [==============================] - 165s - loss: 0.5845
# total chars:  129
# absolute right to do, facts pertaining........ Hillary Hillary with with with with with................ of of with with with with
#
#
#
# Epoch 1/1
# 7886/7886 [==============================] - 165s - loss: 0.5831
# total chars:  141
# thank Steve Bannon for his service. He! in to than as as as with......... Russia. Russia, with grand Russia, of Russia of of of of of of with
#
#
#
# Epoch 1/1
# 7886/7886 [==============================] - 164s - loss: 0.5821
# total chars:  144
# else with knowledge of the witch hunt, with of of our election. Russia, with,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
#
#
#
# Epoch 1/1
# 7886/7886 [==============================] - 165s - loss: 0.5808
# total chars:  148
# withholding key documents and an FBI witness which could shed light on Russia the Clinton grand Clinton the Russia Russia Hillary Russia with crimes
#
#
#
# Epoch 1/1
# 7886/7886 [==============================] - 165s - loss: 0.5800
# total chars:  86
# Trump c " quietly working to boost Clinton. " President Obama was was great so Advisor
#
#
#
# Epoch 1/1
# 7886/7886 [==============================] - 165s - loss: 0.5791
# total chars:  142
# worst and biggest loser of all time. She just can t " stop, our have " " " " " economy obstruction, " like,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
#
#
#
# Epoch 1/1
# 7886/7886 [==============================] - 165s - loss: 0.5774
# total chars:  52
# Steve Bannon for his service. He came to the on with
#
#
#
# Epoch 1/1
# 7886/7886 [==============================] - 165s - loss: 0.5769
# total chars:  132
# wanted to share with Russia at an openly scheduled W. Russians......................................................................
#
#
#
# Epoch 1/1
# 7886/7886 [==============================] - 184s - loss: 0.5755
# total chars:  137
# dishonest Media coverage in favor of Crooked Hillary?..........................................................................,,,,,,,,,,
#
#
#
# Epoch 1/1
# 7886/7886 [==============================] - 182s - loss: 0.5747
# total chars:  63
# let the FBI in to look? look which! President a big worse since
#
#
#
# Epoch 1/1
# 7886/7886 [==============================] - 205s - loss: 0.5730
# total chars:  145
# everybody and every thing but herself for her election loss. They have nothing going?........................................,,,, with, with with
#
#
#
# Epoch 1/1
# 7886/7886 [==============================] - 182s - loss: 0.5731
# total chars:  145
# close ties to Russia, and the the and stole....... book........................ or or or Russia to Russia to Russia to Russia to Russia of Russia
#
#
#
# Epoch 1/1
# 7886/7886 [==============================] - 190s - loss: 0.5720
# total chars:  77
# stories about Trump his Administration. " @ FoxNews It is actually much worse
#
#
#
# Epoch 1/1
# 7886/7886 [==============================] - 173s - loss: 0.5705
# total chars:  132
# Should Stop Tweeting about Russia. Well, so win. We have was........................................................................
#
#
#
# Epoch 1/1
# 7886/7886 [==============================] - 181s - loss: 0.5690
# total chars:  140
# That is so illegal! go for a Comey leaks coming made? other information? The his gave gave his!??????????!!!!! President the the a a a wrong
#
#
#
# Epoch 1/1
# 7886/7886 [==============================] - 182s - loss: 0.5690
# total chars:  152
# Subcommittee next week on........................................,,,,,,,, the the the the,,,,,,,,,,,,,, got, but got, but got, got got, got my that that
#
#
#
# Epoch 1/1
# 7886/7886 [==============================] - 179s - loss: 0.5673
# total chars:  144
# cover up the many mistakes made in Hillary Clinton s her!!! stop!!!!! do!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!?????????????????????????
#
#
#
# Epoch 1/1
# 7886/7886 [==============================] - 183s - loss: 0.5657
# total chars:  93
# within the FBI itself. Classified information is being given to media that could have a phony
#
#
#
# Epoch 1/1
# 7886/7886 [==============================] - 180s - loss: 0.5660
# total chars:  145
# sick have worse since the election. Every story dishonesty head about the his the the Social Media wrong or other Comey other?????????? that that
#
#
#
# Epoch 1/1
# 7886/7886 [==============================] - 189s - loss: 0.5648
# total chars:  59
# purely political reasons. They have nothing going but to I!
#
#
#
# Epoch 1/1
# 7886/7886 [==============================] - 183s - loss: 0.5618
# total chars:  266
# 2016 Election that the Russians were meddling, why no action? Focus on them, asked..... course course Sanders...............,, with with with with to to to to to to to to to to to to to to to to to to to to to to to to to to to to to to to to to to to to to to to to
#
#
#
# Epoch 1/1
# 7886/7886 [==============================] - 189s - loss: 0.5641
# total chars:  145
# zero proof, so now they go for obstruction of justice on the phony story s!!? " Who gave gave have have " " " " " " " " " " " President President
#
#
#
# Epoch 1/1
# 7886/7886 [==============================] - 190s - loss: 0.5619
# total chars:  147
# Spied on before nomination. " The real story...................... is is is of of of of of of of of the the Crooked Crooked Crooked Crooked Crooked
#
#
#
# Epoch 1/1
# 7886/7886 [==============================] - 198s - loss: 0.5600
# total chars:  146
# Amazon Washington Post, this time against A. G. Hillary s................... Facebook with with Crooked Crooked or acid Dems of Crooked. Wrong....
#
#
#
# Epoch 1/1
# 7886/7886 [==============================] - 184s - loss: 0.5608
# total chars:  137
# its subscribers, right after the election, because all totally why no " " like candy. President President was,...........................
#
#
#
# Epoch 1/1
# 7886/7886 [==============================] - 165s - loss: 0.5596
# total chars:  49
# make a deal with Iran, 1 in that the intelligence
#
#
#
# Epoch 1/1
# 7886/7886 [==============================] - 181s - loss: 0.5585
# total chars:  119
# son Donald openly gave his e mails to the media authorities!!!!!,,,,,,,,,,,,,,,, Russia, of Russia, of of biased asking
#
#
#
# Epoch 1/1
# 7886/7886 [==============================] - 195s - loss: 0.5588
# total chars:  294
# Schumer, of Pelosi for her close ties to Russia, the the Dems was never have sure even sure going sure going excuse loss going going???? going? going??????????!!!!!!!!!!!!!!!!!!!!!!!???????????????????????????????????????????????????????,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
#
#
#
# Epoch 1/1
# 7886/7886 [==============================] - 334s - loss: 0.5565
# total chars:  140
# 1 in terror, no problem!!! Bernie Sanders. negative. information............................................................................
#
#
#
# Epoch 1/1
# 7886/7886 [==============================] - 280s - loss: 0.5568
# total chars:  137
# Donna B s new book. Crooked Hillary Clinton and her representatives. A. A. A. negative...................................................
#
#
#
# Epoch 1/1
# 7886/7886 [==============================] - 307s - loss: 0.5557
# total chars:  168
# an excuse for losing the election! Russia, and Russia,,,,,,,,,,,,,,,,,,,,,, help,, of the,,,,,,,,,,,,,, of, of, of of being that being that being that hacked that,,,,,,
#
#
#
# Epoch 1/1
# 7886/7886 [==============================] - 297s - loss: 0.5543
# total chars:  138
# 400, 000 really? from DNC....... going the their wrong at who who! who!!!??????????????????????????? was was was was was was was was is is
#
#
#
# Epoch 1/1
# 7886/7886 [==============================] - 323s - loss: 0.5539
# total chars:  140
# lack of investigation on Clinton made Fake Dossier now 12, 000, Fusion deleted!,, the,,,,,,,,,,,,,,,,,,,,,,,,,,,,...........................
#
#
#
# Epoch 1/1
# 7886/7886 [==============================] - 337s - loss: 0.5530
# total chars:  118
# credibility after many of their COSTLY looking, that there is the the, the the the the the the the the the the the the
#
#
#
# Epoch 1/1
# 7886/7886 [==============================] - 368s - loss: 0.5514
# total chars:  141
# Sleazy Adam Schiff, the totally biased Congressman! witch " continues, "! or the or or the rigged. He rigged...... Hunt.. Hunt Hunt Hunt Hunt
#
#
#
# Epoch 1/1
# 7886/7886 [==============================] - 219s - loss: 0.5507
# total chars:  147
# stuff. Deep State. Give this information Very...... with the with Russia with Russia of the Russian Russian the Russian Russian our the Russian the
#
#
#
# Epoch 1/1
# 7886/7886 [==============================] - 184s - loss: 0.5502
# total chars:  72
# replace Acting FBI Director Andrew McCabe, a Comey friend who was a weak
#
#
#
# Epoch 1/1
# 7886/7886 [==============================] - 188s - loss: 0.5503
# total chars:  96
# RNC has and why have they not have they " give the the grip? Facebook was on????????????????? in
#
#
#
# Epoch 1/1
# 7886/7886 [==============================] - 179s - loss: 0.5493
# total chars:  163
# doubled it in only 8 years!! Hunt!! continues, 11 got into to Hillary the the Clinton after after after after after after after after after after to to to to to to
#
#
#
# Epoch 1/1
# 7886/7886 [==============================] - 175s - loss: 0.5493
# total chars:  144
# Intelligence Committee looking into the Bill Hillary Clinton Clinton c Obama Administration? The Obama Administration agreed to has made a wrong
#
#
#
# Epoch 1/1
# 7886/7886 [==============================] - 184s - loss: 0.5481
# total chars:  129
# Look what Hillary Clinton may have gotten away with. G for Dem deal that leaks " E " candy. A total " collusion " stop stop? stop
#
#
#
# Epoch 1/1
# 7886/7886 [==============================] - 190s - loss: 0.5481
# total chars:  128
# Election and why not, I want strong military low! The his Witch..........................???????????????????????????????????????
#
#
#
# Epoch 1/1
# 7886/7886 [==============================] - 180s - loss: 0.5450
# total chars:  138
# last minute. THEY SAW A MOVEMENT LIKE NEVER BEFORE did " Russia, " spends all of all illegal protected? I. have have " " " " "............
#
#
#
# Epoch 1/1
# 7886/7886 [==============================] - 165s - loss: 0.5459
# total chars:  138
# looks like James Comey exonerated Hillary Clinton long long the @ Dems?? stop?????????????????????????????????????????????????????????????
#
#
#
# Epoch 1/1
# 7886/7886 [==============================] - 173s - loss: 0.5462
# total chars:  146
# lying about it. Tell that after about the Obama SCANDAL and every election Look. V. show. I. G. A. G. President. A. G. tears? s. Putin. A. Council
#
#
#
# Epoch 1/1
# 7886/7886 [==============================] - 184s - loss: 0.5451
# total chars:  139
# two groups are laughing at this excuse for!!!?......... and and???????????????????????????????????????????????????!!!!!!!!!!!!!!!!! for for
#
#
#
# Epoch 1/1
# 7886/7886 [==============================] - 188s - loss: 0.5444
# total chars:  140
# HAPPENED " " How Team Hillary played the press the Fake the @ @ foxandfriends???????????????? will? will?? will? will?? will? will will will
#
#
#
# Epoch 1/1
# 7886/7886 [==============================] - 191s - loss: 0.5429
# total chars:  51
# LEAKERS in the intelligence community..............
#
#
#
# Epoch 1/1
# 7886/7886 [==============================] - 191s - loss: 0.5426
# total chars:  136
# Deep State. Give this information NOW! @ FoxNews MOVEMENT money from he is the long he was great was was, President, who was big big as,
#
#
#
# Epoch 1/1
# 7886/7886 [==============================] - 174s - loss: 0.5422
# total chars:  139
# Israel, writes. Weak! @ Democrat now?. the??? Clinton?????????????????? have have have have have have have have have will have wrong! wrong
#
#
#
# Epoch 1/1
# 7886/7886 [==============================] - 166s - loss: 0.5417
# total chars:  111
# HAVE NOTHING TO DO WITH RUSSIA NO DEALS, NO who who have have have wrong is for for for for and and and and and
#
#
#
# Epoch 1/1
# 7886/7886 [==============================] - 191s - loss: 0.5435
# total chars:  43
# Dems dealings with Russia are not looked at
#
#
#
# Epoch 1/1
# 7886/7886 [==============================] - 183s - loss: 0.5402
# total chars:  125
# losing the election, Russia, Russia, Russia, Russia, Russia....................................................... team. team
#
#
#
# Epoch 1/1
# 7886/7886 [==============================] - 206s - loss: 0.5400
# total chars:  65
# Phony Schumer, of Pelosi for her close ties to Democrats, 000 and
#
#
#
# Epoch 1/1
# 7886/7886 [==============================] - 205s - loss: 0.5399
# total chars:  212
# electronic surveillance, intercepts, unmasking and illegal leaking of all, all! his!!!!!!! go! go go go go go go!!!?? NOW!!!????????????????????????????????????????????????????????????????????????????????????????
#
#
#
# Epoch 1/1
# 7886/7886 [==============================] - 201s - loss: 0.5401
# total chars:  132
# Social Media Guidelines that they installed to preserve some credibility after it, Uranium confirms, or Obama oath, there for a lost
#
#
#
# Epoch 1/1
# 7886/7886 [==============================] - 183s - loss: 0.5370
# total chars:  51
# EXCUSE for losing the election. It s all a election
# Epoch 1/1
# 7886/7886 [==============================] - 175s - loss: 0.5402
# total chars:  139
# knows how classified information got into the newspapers soon after she explained it to Democrats. A. A. G.,,,, Russia,,...................
#
#
#
# Epoch 1/1
# 7886/7886 [==============================] - 176s - loss: 0.5367
# total chars:  147
# who should never have been released from prison, is the Comey, and, Obama,,,,,,.... and and and information.. and and Hunt Hunt Hunt Hunt Hunt Hunt
#
#
#
# Epoch 1/1
# 7886/7886 [==============================] - 179s - loss: 0.5373
# total chars:  66
# inventing stories about Trump his Administration. Witch Hunt. Next
#
#
#
# Epoch 1/1
# 7886/7886 [==============================] - 174s - loss: 0.5360
# total chars:  71
# allowed big Uranium to go to Russia, Russian time. A. collusion he?.!..
#
#
#
# Epoch 1/1
# 7886/7886 [==============================] - 165s - loss: 0.5363
# total chars:  219
# these leaks be happening as I deal on N. Korea s Administration, got was to Russia, NOW collusion with respect at a no election. A. Major s.. book...,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,, the the on on on the to to to to
#
#
#
# Epoch 1/1
# 7886/7886 [==============================] - 166s - loss: 0.5377
# total chars:  87
# actually much worse than this!!!!!... but.....................,,,, at,,,,,,,,,,,,,,,,,,
#
#
#
# Epoch 1/1
# 7886/7886 [==============================] - 164s - loss: 0.5352
# total chars:  126
# Witch Hunt continues, two groups are laughing at talking Obama Obama would now in 8 information. It. Sessions. Council! excuse
#
#
#
# Epoch 1/1
# 7886/7886 [==============================] - 164s - loss: 0.5369
# total chars:  124
# interviews, speeches and social media. I................................................ the the the the the the the the the
#
#
#
# Epoch 1/1
# 7886/7886 [==============================] - 164s - loss: 0.5360
# total chars:  258
# excuse for losing the election, Russia, Russia,,,,,,, not they big big far the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the
#
#
#
# Epoch 1/1
# 7886/7886 [==============================] - 164s - loss: 0.5347
# total chars:  138
# way, if Russia was working so hard on the 2016 Election,,,,, and and and????????.?????????????????????????? DNC DNC? DNC DNC DNC? DNC DNC?
#
#
#
# Epoch 1/1
# 7886/7886 [==============================] - 165s - loss: 0.5346
# total chars:  140
# even requested an examination of the computer servers? going. Who going? going? never even they " never never never? never?? " me? gave gave
#
#
#
# Epoch 1/1
# 7886/7886 [==============================] - 164s - loss: 0.5348
# total chars:  139
# HOAX. Based on the information they had in? Russian c........... requested t Fmr out more more more more more more more more more more more
#
#
#
# Epoch 1/1
# 7886/7886 [==============================] - 165s - loss: 0.5329
# total chars:  36
# dismissed idea that anyone could rig
#
#
#
# Epoch 1/1
# 7886/7886 [==============================] - 164s - loss: 0.5329
# total chars:  91
# will be far more prevalent than anyone ever thought!!......................................
#
#
#
# Epoch 1/1
# 7886/7886 [==============================] - 175s - loss: 0.5313
# total chars:  120
# answer was, " I hope so! "! Team the 12 c on,, the the,,,,,,,,,,,, " collusion " unmasking " candy " collusion unmasking
#
#
#
# Epoch 1/1
# 7886/7886 [==============================] - 174s - loss: 0.5301
# total chars:  137
# SCANDAL and stop with the Fake Trump Russia was never going talking talking about about were never big wrong for excuse??????????????????
#
#
#
# Epoch 1/1
# 7886/7886 [==============================] - 174s - loss: 0.5331
# total chars:  125
# deal with Iran, 1 in terror, no total scheme against total worse! for?. Major continues, the,,,,, but but but but but but but
#
#
#
# Epoch 1/1
# 7886/7886 [==============================] - 176s - loss: 0.5316
# total chars:  137
# Man hasn t worked in 25 years, why have have have have they stop never do information have be a months months???????????????????????????!
#
#
#
# Epoch 1/1
# 7886/7886 [==============================] - 175s - loss: 0.5311
# total chars:  171
# further information, I will be allowing, I President Obama, is refusing was idea collusion... s all " all at all at the Clinton c and investigation was hacked.............
#
#
#
# Epoch 1/1
# 7886/7886 [==============================] - 174s - loss: 0.5300
# total chars:  130
# Focus on them, not T!!?... information to meddling,?... Russia, with Hillary, Russia..............................................
#
#
#
# Epoch 1/1
# 7886/7886 [==============================] - 174s - loss: 0.5322
# total chars:  117
# Podesta paid big money to get the sanctions on Russia...... Was. Was.................................................
#
#
#
# Epoch 1/1
# 7886/7886 [==============================] - 174s - loss: 0.5298
# total chars:  152
# Every story is badly slanted. where are going crazy! the nytimes which got gave? We well..................................... continues. Witch continues
#
#
#
# Epoch 1/1
# 7886/7886 [==============================] - 174s - loss: 0.5313
# total chars:  140
# dishonesty going on with Crooked Hillary the Dems...........................................................................................
#
#
#
# Epoch 1/1
# 7886/7886 [==============================] - 174s - loss: 0.5282
# total chars:  120
# next week on.............................................. allowing.. asked American him American him allowing. allowing
#
#
#
# Epoch 1/1
# 7886/7886 [==============================] - 174s - loss: 0.5285
# total chars:  136
# Will these leaks be happening as I deal, herself, go? Hillary, Russia was Clinton. He. s................................................
#
#
#
# Epoch 1/1
# 7886/7886 [==============================] - 174s - loss: 0.5293
# total chars:  142
# pass and protection. Totally illegal! Very!!!!!! FBI! FBI! FBI!!!? that that? that,,, the they the and and Obama Obama Obama Obama Obama Obama
#
#
#
# Epoch 1/1
# 7886/7886 [==============================] - 174s - loss: 0.5264
# total chars:  147
# told me to fire the FBI Director! Witch Hunt! Next!, the Comey,,?!!!! as into,,,,,,,,,? Hillary? Hillary Hillary... others,,, from, from,,,,,,,,,,,
#
#
#
# Epoch 1/1
# 7886/7886 [==============================] - 174s - loss: 0.5278
# total chars:  64
# been released from prison, is now calling President Obama a weak
#
#
#
# Epoch 1/1
# 7886/7886 [==============================] - 178s - loss: 0.5292
# total chars:  110
# requested an examination of the computer servers? What is going? Clinton going??....... months months acts DNC
#
#
#
# Epoch 1/1
# 7886/7886 [==============================] - 182s - loss: 0.5258
# total chars:  114
# went down by 12 billion vs a 200 billion increase in Obama? The they excuse for! in @.............................
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-486-254a79da797e> in <module>()
#      13     if nb_epoch % 10 == 0:
#      14         model1.save_weights('model1/checkpoint_{}_epoch_{}.hdf5'.format(HIDDEN_DIM, nb_epoch))
# ---> 15         model1.save('model1/checkpoint_{}_epoch_{}.h5'.format(HIDDEN_DIM, nb_epoch))
#
# /Users/pascalequeralt/anaconda/lib/python2.7/site-packages/keras/engine/topology.pyc in save(self, filepath, overwrite, include_optimizer)
#    2551         """
#    2552         from ..models import save_model
# -> 2553         save_model(self, filepath, overwrite, include_optimizer)
#    2554
#    2555     def save_weights(self, filepath, overwrite=True):
#
# /Users/pascalequeralt/anaconda/lib/python2.7/site-packages/keras/models.pyc in save_model(model, filepath, overwrite, include_optimizer)
#     175                         else:
#     176                             param_dset[:] = val
# --> 177         f.flush()
#     178
#     179
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper (/Users/ilan/minonda/conda-bld/h5py_1490026561416/work/h5py/_objects.c:2846)()
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper (/Users/ilan/minonda/conda-bld/h5py_1490026561416/work/h5py/_objects.c:2804)()
#
# /Users/pascalequeralt/anaconda/lib/python2.7/site-packages/h5py/_hl/files.pyc in __exit__(self, *args)
#     315     def __exit__(self, *args):
#     316         if self.id:
# --> 317             self.close()
#     318
#     319     @with_phil
#
# /Users/pascalequeralt/anaconda/lib/python2.7/site-packages/h5py/_hl/files.pyc in close(self)
#     297             for id_ in file_list:
#     298                 while id_.valid:
# --> 299                     h5i.dec_ref(id_)
#     300
#     301             self.id.close()
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper (/Users/ilan/minonda/conda-bld/h5py_1490026561416/work/h5py/_objects.c:2846)()
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper (/Users/ilan/minonda/conda-bld/h5py_1490026561416/work/h5py/_objects.c:2804)()
#
# h5py/h5i.pyx in h5py.h5i.dec_ref (/Users/ilan/minonda/conda-bld/h5py_1490026561416/work/h5py/h5i.c:2497)()
#
# RuntimeError: Can't decrement id ref count (Unable to extend file properly, errno = 28, error message = 'no space left on device')

# %% [markdown]
# ### Model 2

# %%
BATCH_SIZE = 128
HIDDEN_DIM = 700
LAYER_NUM = 3 
nb_epoch = 0

model2 = create_model(HIDDEN_DIM, LAYER_NUM)

# %%
for i in range (0,200):
    print('\n\n')
    model2.fit(X_version_bytweet, y_version_bytweet, batch_size=BATCH_SIZE, verbose=1, nb_epoch=1)
    nb_epoch += 1
    output_as_sentence(generate_words(model2))
    if nb_epoch % 10 == 0:
        model2.save_weights('model2/checkpoint_{}_epoch_{}.hdf5'.format(HIDDEN_DIM, nb_epoch))
# Out:
# /Users/pascalequeralt/anaconda/lib/python2.7/site-packages/keras/models.py:848: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
#   warnings.warn('The `nb_epoch` argument in `fit` '
# Epoch 1/1
# 9093/9093 [==============================] - 243s - loss: 5.7770
# total chars:  68
# past to MAKE AMERICA GREAT AGAIN AGAIN AGAIN AGAIN AGAIN AGAIN AGAIN
#
#
#
# Epoch 1/1
# 9093/9093 [==============================] - 249s - loss: 4.9216
# total chars:  139
# Luv. going will make America AGAIN!!!!!!!. will will make AMERICA AGAIN!!!!!!!. will will make AMERICA AGAIN!!!!!!!. will will make AMERICA
#
#
#
# Epoch 1/1
# 9093/9093 [==============================] - 229s - loss: 4.4198
# total chars:  101
# cleopattrausa@ realDonaldTrump. Let s make America AGAIN!"." will". Trump2016. down. MAKE AMERICA
#
#
#
# Epoch 1/1
# 9093/9093 [==============================] - 241s - loss: 4.0350
# total chars:  104
# Amazing country. We will make America great!.. we will make America great again. you the country and the
#
#
#
# Epoch 1/1
# 9093/9093 [==============================] - 264s - loss: 3.6713
# total chars:  137
# booming to make America great again, we will make America great again to make America make America make America make America make America
#
#
#
# Epoch 1/1
# 9093/9093 [==============================] - 219s - loss: 3.3408
# total chars:  118
# Typical realDonaldTrump MAKE AMERICA GREAT AGAIN! AmericaFirst... we will never, and God, God, God and God and God and
#
#
#
# Epoch 1/1
# 9093/9093 [==============================] - 187s - loss: 3.0454
# total chars:  133
# NEW realDonaldTrump@ realDonaldTrump we need a realDonaldTrump silent. We will make America great again.! We will make America great
#
#
#
# Epoch 1/1
# 9093/9093 [==============================] - 178s - loss: 2.7572
# total chars:  141
# Lincoln and, MAKE AMERICA GREAT AGAIN!....." I I can vote"!"!"!"!"!"!!!!!!!!!!!!!!!!!!!!!!!!!! and and and and and and and and and and
#
#
#
# Epoch 1/1
# 9093/9093 [==============================] - 177s - loss: 2.5035
# total chars:  77
# impact country! MAKE AMERICA GREAT AGAIN!!! We We Will Make America AGAIN!!"
#
#
#
# Epoch 1/1
# 9093/9093 [==============================] - 177s - loss: 2.2721
# total chars:  133
# lead@ realDonaldTrump Make America Great Again.@ realDonaldTrump@ realDonaldTrump is I will make America great again. we will work
#
#
#
# Epoch 1/1
# 9093/9093 [==============================] - 178s - loss: 2.0586
# total chars:  143
# back, and God Bless. We are need ready to unlock America to the great American people. We will make America great again."""" BigLeagueTruth
#
#
#
# Epoch 1/1
# 9093/9093 [==============================] - 176s - loss: 1.8726
# total chars:  141
# Lets MAKE AMERICA GREAT AGAIN!. AmericaFirst in in a the the great great great great day a great great again. again. again. great again great
#
#
#
# Epoch 1/1
# 9093/9093 [==============================] - 176s - loss: 1.7050
# total chars:  102
# V. M. It is time to break with the bitter failures of the American American American American American
#
#
#
# Epoch 1/1
# 9093/9093 [==============================] - 176s - loss: 1.5658
# total chars:  128
# economy and never let you down. Make America Great Again. Again. Again.. GREAT, AMERICA, AMERICA, to be and special us beginning
#
#
#
# Epoch 1/1
# 9093/9093 [==============================] - 176s - loss: 1.4468
# total chars:  113
# GREAT AGAIN! It will be done. Like Reagan you Trump." They make AMERICA GREAT!!!!!" FANTASTIC!!!!!!!!!!!!!! for
#
#
#
# Epoch 1/1
# 9093/9093 [==============================] - 175s - loss: 1.3425
# total chars:  142
# Good be in the new house people!!!!!!!!!!!!!! in in in the the the the the the the the the the the the our your your the the the. MAKE AMERICA
#
#
#
# Epoch 1/1
# 9093/9093 [==============================] - 176s - loss: 1.2578
# total chars:  138
# or the stamina to MAKE AMERICA GREAT AGAIN!!!!! AGAIN AGAIN AGAIN.............. AGAIN! AGAIN! AGAIN! AGAIN AND AND AGAIN AGAIN AGAIN AGAIN
#
#
#
# Epoch 1/1
# 9093/9093 [==============================] - 176s - loss: 1.1878
# total chars:  142
# ELECT@ realDonaldTrump@ troyconway Donald get big business! we can make America great again!!!!!!!!!!!! I I I I t t that your your your your
#
#
#
# Epoch 1/1
# 9093/9093 [==============================] - 175s - loss: 1.1221
# total chars:  137
# awful, Trump and Pence are the ticket............... MAKE MAKE MAKE MAKE MAKE MAKE MAKE MAKE MAKE MAKE MAKE MAKE MAKE MAKE MAKE MAKE MAKE
#
#
#
# Epoch 1/1
# 9093/9093 [==============================] - 176s - loss: 1.0744
# total chars:  141
# minutes, Make America Great Again!" debate" debate"@ realDonaldTrump@@ about@ realDonaldTrump to@ politicians to to GREAT GREAT GREAT
#
#
#
# Epoch 1/1
# 9093/9093 [==============================] - 175s - loss: 1.0311
# total chars:  135
# hosting! Let s Make America Great Again! Mr....... of of of of.... of of of of of of of of over over over over over over over over over
#
#
#
# Epoch 1/1
# 9093/9093 [==============================] - 176s - loss: 0.9920
# total chars:  102
# whole forget and make America great again!" Trump2016" Trump BigLeagueTruth Trump Trump the about in
#
#
#
# Epoch 1/1
# 9093/9093 [==============================] - 175s - loss: 0.9592
# total chars:  116
# took outsider for our country so their hands. Vote now today, and MAKE AMERICA GREAT AGAIN! TRUMP 36. a wall to MAKE
#
#
#
# Epoch 1/1
# 9093/9093 [==============================] - 175s - loss: 0.9346
# total chars:  137
# anouncment. You have my vote." Make America Great Again!" Thanks." debate"."."."........ s. s.....................................
#
#
#
# Epoch 1/1
# 9093/9093 [==============================] - 175s - loss: 0.9089
# total chars:  139
# Augustine, Florida! Lets DrainTheSwamp MAKE AMERICA GREAT AGAIN! Trump2016!" Thanks.@ realDonaldTrump.. Trump. your the you. MAKE AMERICA
#
#
#
# Epoch 1/1
# 9093/9093 [==============================] - 175s - loss: 0.8892
# total chars:  124
# every neglected part of this nation will make are make America make America great again,, that that that your your your your
#
#
#
# Epoch 1/1
# 9093/9093 [==============================] - 175s - loss: 0.8712
# total chars:  135
# mission to make America great again!!!!!!! in the the the the the the the the the your your your your being being! to to to to to to to
#
#
#
# Epoch 1/1
# 9093/9093 [==============================] - 175s - loss: 0.8584
# total chars:  126
# create One American Nation. Together, we will MAKE AMERICA GREAT again!. Trump2016 to record to to....................... Make
#
#
#
# Epoch 1/1
# 9093/9093 [==============================] - 175s - loss: 0.8446
# total chars:  139
# Chocolate3Way I have never loved a candidate as much as I will be in Iowa and never and MAKE to you to you to to to to make to make to make
#
#
#
# Epoch 1/1
# 9093/9093 [==============================] - 175s - loss: 0.8364
# total chars:  137
# she who hesitates is lost MAKE AMERICA GREAT AGAIN!...... MAKE MAKE MAKE MAKE MAKE MAKE MAKE MAKE MAKE MAKE MAKE MAKE MAKE MAKE MAKE MAKE
#
#
#
# Epoch 1/1
# 9093/9093 [==============================] - 175s - loss: 0.8245
# total chars:  103
# DEPrimary run is president already. sweet Jesus just run. Time to get to." Make America great. AMERICA
#
#
#
# Epoch 1/1
# 9093/9093 [==============================] - 175s - loss: 0.8160
# total chars:  128
# Why do u keep trying to attack Trump. MAKE AMERICA............. MAKE MAKE MAKE MAKE MAKE MAKE MAKE MAKE MAKE MAKE Make Make Make
#
#
#
# Epoch 1/1
# 9093/9093 [==============================] - 175s - loss: 0.8097
# total chars:  140
# Chicago, for Baltimore, and for every neglected part of this nation and I Make America Great Again! We We we we we our the the the the great
#
#
#
# Epoch 1/1
# 9093/9093 [==============================] - 176s - loss: 0.8021
# total chars:  41
# parent who dreams for their children, and
#
#
#
# Epoch 1/1
# 9093/9093 [==============================] - 175s - loss: 0.7963
# total chars:  138
# part of this nation and I will fight to Make America Great Again. We will to the the the the the the the the the the make first make first
#
#
#
# Epoch 1/1
# 9093/9093 [==============================] - 175s - loss: 0.7893
# total chars:  132
# Thanksgiving to all. Have a great day and have a really of in Nashua from@ place@ place I said" They""" They"""""""""
#
#
#
# Epoch 1/1
# 9093/9093 [==============================] - 175s - loss: 0.7855
# total chars:  118
# worse almost ZERO growth this@ FoxNews with@ time.. We will be the White American their their their heroes interests
#
#
#
# Epoch 1/1
# 9093/9093 [==============================] - 175s - loss: 0.7832
# total chars:  97
# Morning_Joe@ FoxNews Never thought much of Carl.." Make America MAKE AMERICA to to MAKE to MAKE
#
#
#
# Epoch 1/1
# 9093/9093 [==============================] - 176s - loss: 0.7776
# total chars:  51
# song have made such a difference. MAKE AMERICA MAKE
#
#
#
# Epoch 1/1
# 9093/9093 [==============================] - 175s - loss: 0.7746
# total chars:  144
# Dinner. We can bring common sense to DC Make America Great Again. And We s Make AMERICA GREAT MAKE AMERICA GREAT GREAT...... own own Fake! AGAIN
#
#
#
# Epoch 1/1
# 9093/9093 [==============================] - 175s - loss: 0.7702
# total chars:  255
# vote for you, we are going to MAKE AMERICA GREAT AGAIN!... I I I to to to to to to to to to to to to to to to to to to to to can can can can can can can can can can can can can can can can can make can make can make can make!!!! to to to I I I I I I I I I
#
#
#
# Epoch 1/1
# 9093/9093 [==============================] - 174s - loss: 0.7674
# total chars:  136
# Sam Clovis intro! Let s Make America Great Again!@!@@@@@ I I I I@@ I@@ I I I I to to to to to to to to to to to to to to to to
#
#
#
# Epoch 1/1
# 9093/9093 [==============================] - 174s - loss: 0.7643
# total chars:  139
# staggering influence. Stay True! Great and savvy bizman! America Great Again!@ this we for the the the the the the the the the the the the
#
#
#
# Epoch 1/1
# 9093/9093 [==============================] - 174s - loss: 0.7608
# total chars:  143
# justrunbaby Trump2016 Don t disappoint. There isn t another way Land for you MAKE I I I I I I MAKE MAKE MAKE MAKE MAKE MAKE MAKE MAKE MAKE MAKE
#
#
#
# Epoch 1/1
# 9093/9093 [==============================] - 175s - loss: 0.7603
# total chars:  134
# NH poll released! We are getting ready to Make America Great Again. Let s Make Make Make Make the the the the make need make make make
#
#
#
# Epoch 1/1
# 9093/9093 [==============================] - 174s - loss: 0.7569
# total chars:  119
# debate!" We must win and make America great again. Trump2016" So a the jobs, great the future of the right by@ new@
#
#
#
# Epoch 1/1
# 9093/9093 [==============================] - 176s - loss: 0.7539
# total chars:  137
# question on Iraq. They will NEVER make AMERICA MAKE to MAKE to MAKE to MAKE MAKE MAKE MAKE MAKE MAKE embrace their their their their that
#
#
#
# Epoch 1/1
# 9093/9093 [==============================] - 174s - loss: 0.7527
# total chars:  85
# Chris Cox and Bikers for Trump We need a bold new direction. Let s Make America GREAT
#
#
#
# Epoch 1/1
# 9093/9093 [==============================] - 174s - loss: 0.7487
# total chars:  148
# lowell mass speech. Awesome. Great crowd. Make America Great Again. We must make AMERICA make AMERICA AMERICA Make AMERICA GREAT GREAT!!!!! children
#
#
#
# Epoch 1/1
# 9093/9093 [==============================] - 174s - loss: 0.7483
# total chars:  142
# WilliamPetroski" Trump I can make America great again!!! Would@ only@ your@ the your your your the the the the the the the the the the the
#
#
#
# Epoch 1/1
# 9093/9093 [==============================] - 174s - loss: 0.7469
# total chars:  128
# gmail. Vote by today, and a time to take the country to do make AMERICA make the make America great great again! with with on on
#
#
#
# Epoch 1/1
# 9093/9093 [==============================] - 174s - loss: 0.7448
# total chars:  134
# blonde I will work hard and never let you you, we will make are make Make Make Make are meetthepress meetthepress the the, the the the
#
#
#
# Epoch 1/1
# 9093/9093 [==============================] - 176s - loss: 0.7431
# total chars:  85
# ELECT@ realDonaldTrump We need to PRAY to God s. We." I I I I I I I I do do t t t t
#
#
#
# Epoch 1/1
# 9093/9093 [==============================] - 175s - loss: 0.7407
# total chars:  86
# rebuild our inner cities, and rebuild our country, and of American American people. It
#
#
#
# Epoch 1/1
# 9093/9093 [==============================] - 175s - loss: 0.7412
# total chars:  145
# DrainTheSwamp in Washington, D. C. We need a bold new direction. Let s Make America GREAT AGAIN. GREAT GREAT GREAT AND AMERICA GREAT MAKE AMERICA
#
#
#
# Epoch 1/1
# 9093/9093 [==============================] - 174s - loss: 0.7373
# total chars:  125
# politizine" Trump We ll Make America Great Again" but look back to our DT. MAKE AMERICA... Make America great again!" June
#
#
#
# Epoch 1/1
# 9093/9093 [==============================] - 175s - loss: 0.7367
# total chars:  124
# Rsherfy@ realDonaldTrump@ macresslertech@ FoxNews@ thought not Iowa for I to I I I I I I I I I A A A you our you our our
#
#
#
# Epoch 1/1
# 9093/9093 [==============================] - 175s - loss: 0.7358
# total chars:  144
# able to MAKE AMERICA GREAT AGAIN! TRUMP 36. MAKE AMERICA GREAT GREAT"" Make AMERICA Make Make need Make are get H H Let are Make America great
#
#
#
# Epoch 1/1
# 9093/9093 [==============================] - 176s - loss: 0.7332
# total chars:  140
# 12PM! Let s Make America Great Again!!!!!! I I your a the the the the the the the the the the the the the the the the the your your A Debate
#
#
#
# Epoch 1/1
# 9093/9093 [==============================] - 174s - loss: 0.7333
# total chars:  128
# right leadership. Let s Make America Great Again!!!! I we we we the the one on on one one a a a a back back a back great a great
#
#
#
# Epoch 1/1
# 9093/9093 [==============================] - 175s - loss: 0.7300
# total chars:  142
# I will be in South Carolina all week. Saturday is BIG, BIG! MAKE AMERICA GREAT AGAIN! MAKE AMERICA GREAT AGAIN! Trump2016 VoteTrump. VoteTrump
#
#
#
# Epoch 1/1
# 9093/9093 [==============================] - 175s - loss: 0.7287
# total chars:  129
# rise, and new factories will come rushing done a borders! every I I I I I I I I I I I I I I I I I I I I I I I I I I I I I I I I I
#
#
#
# Epoch 1/1
# 9093/9093 [==============================] - 174s - loss: 0.7264
# total chars:  124
# Watch on NBC at 3 00 P. M. on@ FoxNews, a.. do the our our our jobs. an be total proven proven. from this@ Again Again! 16
#
#
#
# Epoch 1/1
# 9093/9093 [==============================] - 175s - loss: 0.7263
# total chars:  92
# Keep it up! Make America Great Again!!!!" Make!"" I I I I I do in in in in in in in in in
#
#
#
# Epoch 1/1
# 9093/9093 [==============================] - 174s - loss: 0.7243
# total chars:  123
# back at this election, and say this is by far the country, and and and we will will will will will will will will will will
#
#
#
# Epoch 1/1
# 9093/9093 [==============================] - 176s - loss: 0.7230
# total chars:  131
# beat Hillary Clinton and I havn t even Democrats, her immigration, with, the the the the the@ accurate the Poll,@ realDonaldTrump
#
#
#
# Epoch 1/1
# 9093/9093 [==============================] - 174s - loss: 0.7226
# total chars:  135
# ELECT@ FoxNews@ megynkelly int. on@ Reince@ realDonaldTrump We Will Make GREAT AGAIN!!.... Make Make Make Make Make Make to Make to
#
#
#
# Epoch 1/1
# 9093/9093 [==============================] - 175s - loss: 0.7208
# total chars:  153
# gov t to do the same, we will make America great again,, we will will,,,,,,,,,,,,,,,,,,,,,, leegreenwood83 leegreenwood83 TheLeeGreenwood TheLeeGreenwood
#
#
#
# Epoch 1/1
# 9093/9093 [==============================] - 174s - loss: 0.7208
# total chars:  65
# Being a great president requires great negotiating skills. Trump,
#
#
#
# Epoch 1/1
# 9093/9093 [==============================] - 175s - loss: 0.7183
# total chars:  110
# candidate as much as I love@ realDonaldTrump, I will MAKE AMERICA MAKE AMERICA MAKE AMERICA MAKE AMERICA Make
#
#
#
# Epoch 1/1
# 9093/9093 [==============================] - 175s - loss: 0.7174
# total chars:  129
# 12 noon! MAKE AMERICA GREAT AGAIN!" Make America Great Again!!!!, in in in in in in in in in in we we we we we we we we we we we
#
#
#
# Epoch 1/1
# 9093/9093 [==============================] - 175s - loss: 0.7154
# total chars:  39
# greatest hope that the Republican Party
#
#
#
# Epoch 1/1
# 9093/9093 [==============================] - 175s - loss: 0.7159
# total chars:  132
# orders. I will deliver. Let s Make America Great Again!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!! Make!! Make! Make 1 1 1 1 patriots next next
#
#
#
# Epoch 1/1
# 9093/9093 [==============================] - 177s - loss: 0.7134
# total chars:  128
# angiecallahan4@ realDonaldTrump We need to PRAY to God to we to to I I I I I to to to to to to to to to to to to to to to to to
#
#
#
# Epoch 1/1
# 9093/9093 [==============================] - 175s - loss: 0.7141
# total chars:  110
# We will discard the failed policies and division of the past of our jobs and knows wages Making and with these
#
#
#
# Epoch 1/1
# 9093/9093 [==============================] - 175s - loss: 0.7124
# total chars:  142
# POTUS, negotiations making America great again! Trump2016 to support jobs the its back our you you you you you you you you you the the the the
#
#
#
# Epoch 1/1
# 9093/9093 [==============================] - 174s - loss: 0.7106
# total chars:  138
# OgreUasshole@ realDonaldTrump I can t wait for your inauguration!! We we Make! I Social This This We 16 We!!!!!!!!!!,, MAKE we we we MAKE
#
#
#
# Epoch 1/1
# 9093/9093 [==============================] - 186s - loss: 0.7094
# total chars:  142
# VoteTrumpPence16 on 11 8 16 and together and we will MAKE AMERICA GREAT AGAIN.... lose yesterday our Country every any the@@@@@@@@@@
#
#
#
# Epoch 1/1
# 9093/9093 [==============================] - 183s - loss: 0.7082
# total chars:  124
# corrupt establishment knows that we are an existential threat to business business MAKE to MAKE MAKE MAKE MAKE MAKE MAKE....
#
#
#
# Epoch 1/1
# 9093/9093 [==============================] - 183s - loss: 0.7088
# total chars:  127
# ChangeTheWorldIn5Words for the New Year. Make America Great Again!!!!!!!!!!! Trump Trump,,,,,,,,,,,, and a a a a a a a a in and
#
#
#
# Epoch 1/1
# 9093/9093 [==============================] - 181s - loss: 0.7064
# total chars:  142
# tremendous praise for you this morning on@ foxandfriends. It to Nebraska to we we we we we we we we we we we we MAKE MAKE MAKE MAKE MAKE MAKE
#
#
#
# Epoch 1/1
# 9093/9093 [==============================] - 181s - loss: 0.7068
# total chars:  147
# us! We can get it done. Let s Make America Great great!!!!!!!!!!! MAKE to MAKE to MAKE to MAKE to MAKE MAKE MAKE MAKE MAKE MAKE MAKE MAKE MAKE MAKE
#
#
#
# Epoch 1/1
# 9093/9093 [==============================] - 181s - loss: 0.7065
# total chars:  143
# bless you. Together, we will MAKE AMERICA GREAT AGAIN! Trump2016"" must"." Make to Make to make to make to make to make to make GREAT GREAT
#
#
#
# Epoch 1/1
# 9093/9093 [==============================] - 181s - loss: 0.7051
# total chars:  120
# BE AT VARIOUS CAUCUS SITES. MAKE AMERICA. GREAT! MAKE MAKE to MAKE MAKE MAKE MAKE MAKE MAKE MAKE to to to to to to to to
#
#
#
# Epoch 1/1
# 9093/9093 [==============================] - 181s - loss: 0.7032
# total chars:  117
# 30 P. M. NEVADA. I make America make be make are MAKE!!!!!!"!"!"!!!!!!!!!!!!!!""" best Strength! dumb dumb dumb
#
#
#
# Epoch 1/1
# 9093/9093 [==============================] - 181s - loss: 0.7025
# total chars:  101
# seen before. Together, we will MAKE AMERICA GREAT AGAIN!. 37 next to the you to MAKE AMERICA GREAT to
#
#
#
# Epoch 1/1
# 9093/9093 [==============================] - 182s - loss: 0.7021
# total chars:  103
# digit lead! Thank you, we will MAKE AMERICA GREAT AGAIN!. be to to to MAKE to make to make to make make
#
#
#
# Epoch 1/1
# 9093/9093 [==============================] - 181s - loss: 0.7017
# total chars:  96
# creates opportunity and growth. We just need to of MAKE to MAKE to GREAT GREAT to Make Make Make
#
#
#
# Epoch 1/1
# 9093/9093 [==============================] - 180s - loss: 0.7011
# total chars:  121
# past, and to embrace a new, inclusive and inclusive and MAKE to MAKE AMERICA MAKE to MAKE to MAKE to make to make to make
#
#
#
# Epoch 1/1
# 9093/9093 [==============================] - 180s - loss: 0.7003
# total chars:  132
# action. Washington can only be fixed by an!" Make America Great Again!!!!!!!!!" Make. great going,,,,,,,,,,, men men men show show
#
#
#
# Epoch 1/1
# 9093/9093 [==============================] - 184s - loss: 0.6945
# total chars:  83
# TODAY WE MAKE AMERICA GREAT AGAIN! Trump2016 37 support to MAKE AMERICA GREAT AGAIN
#
#
#
# Epoch 1/1
# 9093/9093 [==============================] - 182s - loss: 0.6980
# total chars:  135
# 25th back to the USA to MAKE AMERICA GREAT AGAIN! Trump2016 to for Trump to make America GREAT""" but I need"" Trump" Trump Trump
#
#
#
# Epoch 1/1
# 9093/9093 [==============================] - 181s - loss: 0.6978
# total chars:  111
# context. You will make America great again!!!!!!!!!!!!! in in one one one one one one one your your, your,,,,,,
#
#
#
# Epoch 1/1
# 9093/9093 [==============================] - 189s - loss: 0.6960
# total chars:  144
# Time to get Tough making America great again. A. MAKE AMERICA Make will Make will will will will will will will will will will will will primary
#
#
#
# Epoch 1/1
# 9093/9093 [==============================] - 175s - loss: 0.6965
# total chars:  140
# AB1132@ realDonaldTrump it s the only way we can make America make will make will Make will Make 00 00 00 service quest flag House I I with
#
#
#
# Epoch 1/1
# 9093/9093 [==============================] - 174s - loss: 0.6942
# total chars:  69
# did give tremendous praise for you this morning on@, we to Make will
#
#
#
# Epoch 1/1
# 9093/9093 [==============================] - 182s - loss: 0.6958
# total chars:  37
# VoteTrump on Tuesday, April 5th! MAKE
#
#
#
# Epoch 1/1
# 9093/9093 [==============================] - 183s - loss: 0.6932
# total chars:  113
# ticket.. no more lies, we are!"" to MAKE AMERICA......,,,,,, and we, we and we we and and our and we MAKE, MAKE
#
#
#
# Epoch 1/1
# 9093/9093 [==============================] - 180s - loss: 0.6924
# total chars:  133
# Numerous patriots will be coming to Bedminster together as 30PM Make.. We interesting ever so one,,,, one one one one one one one one
#
#
#
# Epoch 1/1
# 9093/9093 [==============================] - 176s - loss: 0.6898
# total chars:  136
# CHANCE TAKE Virginia, we are going to MAKE AMERICA GREAT AGAIN! MAKE AMERICA GREAT AGAIN!" Make to Make to Make to the the in your your
#
#
#
# Epoch 1/1
# 9093/9093 [==============================] - 177s - loss: 0.6916
# total chars:  62
# V. P. Debate. Very exciting! MAKE AMERICA MAKE to MAKE to Make
#
#
#
# Epoch 1/1
# 9093/9093 [==============================] - 175s - loss: 0.6911
# total chars:  143
# person who can! H..... children. no every new,, MAKE will MAKE. MAKE......... we we we,,, we we never never,,,,, never ever ever ever ever ever
#
#
#
# Epoch 1/1
# 9093/9093 [==============================] - 176s - loss: 0.6896
# total chars:  139
# New H vote today MAKE AMERICA GREAT AGAIN!" going. Make America Great Again!!!!!!!!!!!!!!!!,,@ working, one must your your your your your
#
#
#
# Epoch 1/1
# 9093/9093 [==============================] - 175s - loss: 0.6878
# total chars:  118
# PPP national result is the best yet. The silent was the momentum it up" Mr. Trump. elected. Big, big big all talk and
#
#
#
# Epoch 1/1
# 9093/9093 [==============================] - 176s - loss: 0.6892
# total chars:  85
# mine! I want to make America great again again again, and I and I.. people. Make Make
#
#
#
# Epoch 1/1
# 9093/9093 [==============================] - 175s - loss: 0.6892
# total chars:  48
# rebuilding this country and making America great
#
#
#
# Epoch 1/1
# 9093/9093 [==============================] - 175s - loss: 0.6869
# total chars:  120
# Establishment! We are no longer silent. We will Make America Great Again! You will make America Make America great again
#
#
#
# Epoch 1/1
# 9093/9093 [==============================] - 175s - loss: 0.6875
# total chars:  143
# Massachusetts, was amazing. 10, 000 people going and MAKE to MAKE to Make Make Make Make Make Make Make Make Make Make Make Make Make Make Make
#
#
#
# Epoch 1/1
# 9093/9093 [==============================] - 175s - loss: 0.6864
# total chars:  28
# Amercian, really, can impact
#
#
#
# Epoch 1/1
# 9093/9093 [==============================] - 174s - loss: 0.6859
# total chars:  142
# proven.@ realDonaldTrump will make America great again. make America great again we will will will will will will will will we will will will
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-80-11e0bd867262> in <module>()
#       5     output_as_sentence(generate_words(model2))
#       6     if nb_epoch % 10 == 0:
# ----> 7         model2.save_weights('model2/checkpoint_{}_epoch_{}.hdf5'.format(HIDDEN_DIM, nb_epoch))
#
# /Users/pascalequeralt/anaconda/lib/python2.7/site-packages/keras/models.pyc in save_weights(self, filepath, overwrite)
#     736
#     737         f = h5py.File(filepath, 'w')
# --> 738         topology.save_weights_to_hdf5_group(f, layers)
#     739         f.flush()
#     740         f.close()
#
# /Users/pascalequeralt/anaconda/lib/python2.7/site-packages/keras/engine/topology.pyc in save_weights_to_hdf5_group(f, layers)
#    2863                 param_dset[()] = val
#    2864             else:
# -> 2865                 param_dset[:] = val
#    2866
#    2867
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper (/Users/ilan/minonda/conda-bld/h5py_1490026561416/work/h5py/_objects.c:2846)()
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper (/Users/ilan/minonda/conda-bld/h5py_1490026561416/work/h5py/_objects.c:2804)()
#
# /Users/pascalequeralt/anaconda/lib/python2.7/site-packages/h5py/_hl/dataset.pyc in __setitem__(self, args, val)
#     628         mspace = h5s.create_simple(mshape_pad, (h5s.UNLIMITED,)*len(mshape_pad))
#     629         for fspace in selection.broadcast(mshape):
# --> 630             self.id.write(mspace, fspace, val, mtype, dxpl=self._dxpl)
#     631
#     632     def read_direct(self, dest, source_sel=None, dest_sel=None):
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper (/Users/ilan/minonda/conda-bld/h5py_1490026561416/work/h5py/_objects.c:2846)()
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper (/Users/ilan/minonda/conda-bld/h5py_1490026561416/work/h5py/_objects.c:2804)()
#
# h5py/h5d.pyx in h5py.h5d.DatasetID.write (/Users/ilan/minonda/conda-bld/h5py_1490026561416/work/h5py/h5d.c:3700)()
#
# h5py/_proxy.pyx in h5py._proxy.dset_rw (/Users/ilan/minonda/conda-bld/h5py_1490026561416/work/h5py/_proxy.c:2028)()
#
# h5py/_proxy.pyx in h5py._proxy.H5PY_H5Dwrite (/Users/ilan/minonda/conda-bld/h5py_1490026561416/work/h5py/_proxy.c:1738)()
#
# IOError: Can't prepare for writing data (File write failed: time = sat dec  9 23:27:38 2017
# , filename = 'model2/checkpoint_700_epoch_110.hdf5', file descriptor = 89, errno = 28, error message = 'no space left on device', buf = 0x1765ac2e0, total write size = 3446848, bytes this sub-write = 3446848, bytes actually written = 18446744073709551615, offset = 60641280)

# %% [markdown]
# ### Model 3
# version 1 training data, seq=10

# %%
BATCH_SIZE = 128
HIDDEN_DIM = 700
LAYER_NUM = 3 
nb_epoch = 0

model3 = create_model(HIDDEN_DIM, LAYER_NUM)

# %%
for i in range (0,200):
    print('\n\n')
    model3.fit(X_version_bytweet, y_version_bytweet, batch_size=BATCH_SIZE, verbose=1, nb_epoch=1)
    nb_epoch += 1
    output_as_sentence(generate_words(model3))
    if nb_epoch % 10 == 0:
        model3.save_weights('model3/checkpoint_{}_epoch_{}.hdf5'.format(HIDDEN_DIM, nb_epoch))
# Out:
# /usr/local/lib/python2.7/dist-packages/keras/models.py:939: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
#   warnings.warn('The `nb_epoch` argument in `fit` '
# Epoch 1/1
# 6803/6803 [==============================] - 32s 5ms/step - loss: 5.9630
# total chars:  139
# citizen,,,,,,..............................................................................................................................
#
#
#
# Epoch 1/1
# 6803/6803 [==============================] - 22s 3ms/step - loss: 5.4273
# total chars:  108
# TimeToGetTough.,,,, a a of,,, MAKE America GREAT AGAIN!!!. Make America GREAT Again!!! America America GREAT
#
#
#
# Epoch 1/1
# 6803/6803 [==============================] - 22s 3ms/step - loss: 4.6185
# total chars:  48
# negative.. and will will will MAKE America GREAT
#
#
#
# Epoch 1/1
# 6803/6803 [==============================] - 22s 3ms/step - loss: 3.9711
# total chars:  140
# beat@ realDonaldTrump. I will going to MAKE AMERICA GREAT AGAIN! maybe AmericaFirst.!!!!!!!!!! Let s Make America Great Again!"!!!!!!!!!!!
#
#
#
# Epoch 1/1
# 6803/6803 [==============================] - 22s 3ms/step - loss: 3.4364
# total chars:  131
# forever realDonaldTrump. We will MAKE AMERICA GREAT AGAIN! TRUMP..!!!!!!!!!!!"" TRUMP"""@ realDonaldTrump@ realDonaldTrump@
#
#
#
# Epoch 1/1
# 6803/6803 [==============================] - 22s 3ms/step - loss: 2.9871
# total chars:  141
# 000@ FoxNews@ realDonaldTrump@ realDonaldTrump@ realDonaldTrump@ realDonaldTrump@ realDonaldTrump@ realDonaldTrump@ realDonaldTrump@
#
#
#
# Epoch 1/1
# 6803/6803 [==============================] - 22s 3ms/step - loss: 2.5850
# total chars:  98
# Drudge. We will make America great again. We s time to"!!!"!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#
#
#
# Epoch 1/1
# 6803/6803 [==============================] - 22s 3ms/step - loss: 2.2129
# total chars:  143
# Then. We will make America wealthy again. We will make America safe again, we will make America safe again, we will make America safe again, we
#
#
#
# Epoch 1/1
# 6803/6803 [==============================] - 22s 3ms/step - loss: 1.9038
# total chars:  126
# taking, the African nothing. We must going to Make America Great Again!!!!!!!""""""""" Trump"""""""" look far
#
#
#
# Epoch 1/1
# 6803/6803 [==============================] - 22s 3ms/step - loss: 1.6281
# total chars:  140
# People, under One God, saluting One American Flag. It is time to break with the bitter failures of the past, and to embrace a new, inclusive
#
#
#
# Epoch 1/1
# 6803/6803 [==============================] - 22s 3ms/step - loss: 1.4075
# total chars:  141
# Ever realDonaldTrump are t worry president make America great again. Thank you, and God and... VOTE on on 11 8, 2016. Lets MAKE AMERICA GREAT
#
#
#
# Epoch 1/1
# 6803/6803 [==============================] - 22s 3ms/step - loss: 1.2255
# total chars:  138
# use, Nevada! Lets MAKE AMERICA SAFE AND GREAT AGAIN! ImWithYou AmericaFirst..... VOTE VOTE TrumpPence16 on 11 8 16. Together, we will MAKE
#
#
#
# Epoch 1/1
# 6803/6803 [==============================] - 22s 3ms/step - loss: 1.0805
# total chars:  140
# back. Together, We can going it MAKE AMERICA GREAT AGAIN! It s time to make America great again. Let s make America great again. Let s do!!!
#
#
#
# Epoch 1/1
# 6803/6803 [==============================] - 22s 3ms/step - loss: 0.9612
# total chars:  139
# NoSanctuaryForCriminalsAct, we will make America great again. Thank you, you.".""""""""""" Trump Trump. Trump, Trump,,,,,,, the
#
#
#
# Epoch 1/1
# 6803/6803 [==============================] - 22s 3ms/step - loss: 0.8726
# total chars:  149
# tax American American Flag. It is time to break with the bitter failures of the past, and to embrace a new, inclusive and prosperous American future.
#
#
#
# Epoch 1/1
# 6803/6803 [==============================] - 22s 3ms/step - loss: 0.7862
# total chars:  135
# fast. We Will Make America Strong Again. We Will Make s And We Will Make America Safe Again. And Will Make America Safe Again. And Will
#
#
#
# Epoch 1/1
# 6803/6803 [==============================] - 22s 3ms/step - loss: 0.7230
# total chars:  132
# Pandorasandy1@ realDonaldTrump we need Donald Trump to make America great again.!!""!!""!!""!!""!"" make re, for for for!
#
#
#
# Epoch 1/1
# 6803/6803 [==============================] - 22s 3ms/step - loss: 0.6661
# total chars:  89
# April TRUMP! Let s Make America Great Again!.!..!"""""" Mr,,, and this the sake and
#
#
#
# Epoch 1/1
# 6803/6803 [==============================] - 22s 3ms/step - loss: 0.6233
# total chars:  142
# meaningless, however, if we don t WIN IT ALL and Make America Great Again!.." no even watch Dem debate!"." Lets"""" t look Trump. Trump
#
#
#
# Epoch 1/1
# 6803/6803 [==============================] - 22s 3ms/step - loss: 0.5849
# total chars:  83
# ratings are up 75 because it s" all Trump, all the the time. We are the America to
#
#
#
# Epoch 1/1
# 6803/6803 [==============================] - 22s 3ms/step - loss: 0.5499
# total chars:  119
# MAGA@ OANN Trump is the only one who can make America great again. Carson s sleepy, Jeb low energy."" t t t t answer
#
#
#
# Epoch 1/1
# 6803/6803 [==============================] - 22s 3ms/step - loss: 0.5276
# total chars:  139
# good me alone in 2nd place, closely behind Jeb Bush but Bush will NEVER Make America Great Again!" debate" Thank you, I will vote for you
#
#
#
# Epoch 1/1
# 6803/6803 [==============================] - 22s 3ms/step - loss: 0.5022
# total chars:  141
# corrupt establishment knows that we are an existential threat to their criminal enterprise. We Will make America Safe Again. And We Will Make
#
#
#
# Epoch 1/1
# 6803/6803 [==============================] - 22s 3ms/step - loss: 0.4847
# total chars:  144
# thugs and paid protesters are proving the point of the millions of people who voted to MAKE AMERICA GREAT AGAIN! Politicians to to talk and vote
#
#
#
# Epoch 1/1
# 6803/6803 [==============================] - 22s 3ms/step - loss: 0.4671
# total chars:  134
# joining me on Monday. Big crowds. MAKE AMERICA GREAT AGAIN! MAGA..... VOTE VOTE VOTE TrumpPence16 on 11 8 2016. Together, WE WILL MAKE
#
#
#
# Epoch 1/1
# 6803/6803 [==============================] - 22s 3ms/step - loss: 0.4549
# total chars:  142
# person I have Ever Supported Running 4 the White house U WILL MAKE AMERICA GREAT AGAIN! Trump2016..."""""" t 16th."" t t t t t ifAgain
#
#
#
# Epoch 1/1
# 6803/6803 [==============================] - 22s 3ms/step - loss: 0.4428
# total chars:  102
# DaveInKeno Mr. Trump, Sir, this country is, and has been, on a path. self, and you. MAKE AMERICA GREAT
#
#
#
# Epoch 1/1
# 6803/6803 [==============================] - 22s 3ms/step - loss: 0.4329
# total chars:  78
# tcloer11@ realDonaldTrump@ cvpayne let s make America Great Again! Trump2016
#
#
#
# Epoch 1/1
# 6803/6803 [==============================] - 22s 3ms/step - loss: 0.4241
# total chars:  103
# context. And We Will Make America Great Again. Thank you, and God Bless!!!!!!! Make America Great Again
#
#
#
# Epoch 1/1
# 6803/6803 [==============================] - 22s 3ms/step - loss: 0.4179
# total chars:  174
# fix America requires SUPERMAN but there is ONE BETTER DJT" We must put America to bring us all together as Americans. Imagine what our country could accomplish if we started
#
#
#
# Epoch 1/1
# 6803/6803 [==============================] - 22s 3ms/step - loss: 0.4113
# total chars:  144
# ANHQDC segment with@ CharlesHurt" Breaking Down the Trump Factor" Let s Make America Great Again!"." you never""""""" Mr. Trump, for
#
#
#
# Epoch 1/1
# 6803/6803 [==============================] - 22s 3ms/step - loss: 0.4070
# total chars:  109
# leftists on here makes me nauseated. We SO NEED YOU, MR. TRUMP! Make America Great Again!" Thanks."""""
#
#
#
# Epoch 1/1
# 6803/6803 [==============================] - 22s 3ms/step - loss: 0.4021
# total chars:  142
# 2nd place, closely behind Jeb Bush but Bush will NEVER Make America Great Again!!!!!!" Make America Great Again!" Thanks to Volunteer!! MAKE
#
#
#
# Epoch 1/1
# 6803/6803 [==============================] - 22s 3ms/step - loss: 0.3980
# total chars:  139
# BE AT VARIOUS CAUCUS SITES. MAKE AMERICA GREAT AGAIN! MAGA... VOTE VOTE VOTE VOTE!""""" look"""""""""" make can ever running
#
#
#
# Epoch 1/1
# 6803/6803 [==============================] - 22s 3ms/step - loss: 0.3934
# total chars:  137
# Numerologynow In my 37 years of Life U are the 1st person I have Ever Supported Running 4 the White house U WILL MAKE AMERICA GREAT AGAIN
#
#
#
# Epoch 1/1
# 6803/6803 [==============================] - 22s 3ms/step - loss: 0.3915
# total chars:  144
# TimeToGetTough on seanhannity! I will win and Make America Great Again!" Thank you, and God Bless!.. He will make America SAFE again... He will
#
#
#
# Epoch 1/1
# 6803/6803 [==============================] - 22s 3ms/step - loss: 0.3891
# total chars:  75
# Why do u keep trying to attack Trump? Really dumb strategy! U lose, he wins
#
#
#
# Epoch 1/1
# 6803/6803 [==============================] - 22s 3ms/step - loss: 0.3876
# total chars:  136
# doing this because we re going to make America great again. Thank you, and God Bless!... no more lies, we are going to see America Great
#
#
#
# Epoch 1/1
# 6803/6803 [==============================] - 22s 3ms/step - loss: 0.3831
# total chars:  88
# TheBrodyFile was fantastic tonight on@ CNN. Thank you, we will MAKE AMERICA GREAT AGAIN
#
#
#
# Epoch 1/1
# 6803/6803 [==============================] - 22s 3ms/step - loss: 0.3816
# total chars:  77
# respected by our allies feared by our enemies. Let s Make America Great Again
#
#
#
# Epoch 1/1
# 6803/6803 [==============================] - 22s 3ms/step - loss: 0.3814
# total chars:  142
# discussing how politicians have failed us Making America Great Again! Thanks. You to Volunteer!"" Make America Great Again". Typical pol no
#
#
#
# Epoch 1/1
# 6803/6803 [==============================] - 22s 3ms/step - loss: 0.3781
# total chars:  155
# Our biggest problems are solved by growth. We need a President who is a job creator. Let s Make America Great Again! FITN on@ FoxNews on@ realDonaldTrump
#
#
#
# Epoch 1/1
# 6803/6803 [==============================] - 22s 3ms/step - loss: 0.3772
# total chars:  134
# Hollywood are killing America. MAKE AMERICA GREAT AGAIN!@ realDonaldTrump. I will vote for this country. We will make America wealthy
#
#
#
# Epoch 1/1
# 6803/6803 [==============================] - 22s 3ms/step - loss: 0.3750
# total chars:  145
# praise for you this morning on@ foxandfriends. Keep it up! Make America Great Again!" Thanks!""""" look far more forward to making America
#
#
#
# Epoch 1/1
# 6803/6803 [==============================] - 22s 3ms/step - loss: 0.3739
# total chars:  63
# running the country in order to MAKE AMERICA GREAT AGAIN! While
#
#
#
# Epoch 1/1
# 6803/6803 [==============================] - 22s 3ms/step - loss: 0.3729
# total chars:  135
# debate" but look far more forward to making America great again. It can happen! Let s" They, Bush and Obama. Let s Make America Great
#
#
#
# Epoch 1/1
# 6803/6803 [==============================] - 22s 3ms/step - loss: 0.3723
# total chars:  55
# or the one with the red make America or that woman with
#
#
#
# Epoch 1/1
# 6803/6803 [==============================] - 22s 3ms/step - loss: 0.3703
# total chars:  129
# these words to you tonight I m with you, I will fight for you, and I will win for you. Together, We will MAKE AMERICA GREAT AGAIN
#
#
#
# Epoch 1/1
# 6803/6803 [==============================] - 22s 3ms/step - loss: 0.3700
# total chars:  142
# robust let s Make America Great Again! iluvamerica4trump2016@ gmail. com"" Make America Great Again." debate BigLeagueTruth." true no God
#
#
#
# Epoch 1/1
# 6803/6803 [==============================] - 22s 3ms/step - loss: 0.3686
# total chars:  59
# Bowl is very boring not nearly as exciting as politics MAKE
#
#
#
# Epoch 1/1
# 6803/6803 [==============================] - 22s 3ms/step - loss: 0.3685
# total chars:  140
# join my c to Make America Great Again! Sign up to Volunteer!!!! Make America Great Again!""""""""""""""""""""" but look
#
#
#
# Epoch 1/1
# 6803/6803 [==============================] - 22s 3ms/step - loss: 0.3671
# total chars:  159
# Mr. Trump, Sir, this country is, and has been, on a path of self destruction and needs you to MAKE AMERICA GREAT AGAIN!".".".".".". MAKE. GREAT AGAIN!!!!
#
#
#
# Epoch 1/1
# 6803/6803 [==============================] - 22s 3ms/step - loss: 0.3666
# total chars:  139
# alone in 2nd place, closely behind Jeb Bush but Bush will NEVER Make America Great Again!" Thanks. Trump"" action". action action.. God
#
#
#
# Epoch 1/1
# 6803/6803 [==============================] - 22s 3ms/step - loss: 0.3656
# total chars:  51
# . We Will Make America Safe Again. And We Will Make
#
#
#
# Epoch 1/1
# 6803/6803 [==============================] - 22s 3ms/step - loss: 0.3641
# total chars:  143
# biggest problems are solved by growth. We need a President who is a job creator. Let s Make America Great Again! FITN beginning at Saint Andrew
#
#
#
# Epoch 1/1
# 6803/6803 [==============================] - 22s 3ms/step - loss: 0.3641
# total chars:  104
# candidacy the only one who can make America great again. Carson s sleepy, Jeb low energy." Make America
#
#
#
# Epoch 1/1
# 6803/6803 [==============================] - 22s 3ms/step - loss: 0.3622
# total chars:  137
# Government can be efficient with the right leadership. Let s Make America Great Again! Trump2016!" this!!"""""" Mr. Trump. You for
#
#
#
# Epoch 1/1
# 6803/6803 [==============================] - 22s 3ms/step - loss: 0.3617
# total chars:  84
# Democrat excuse for losing the election, Russia, Russia, Russia. Despite this I have
#
#
#
# Epoch 1/1
# 6803/6803 [==============================] - 22s 3ms/step - loss: 0.3616
# total chars:  130
# STRONG AGAIN! TRUMP 37 CRUZ 11 This is at the top of Drudge! Let s Make America Great Again! Thanks. Thanks to not talk! no action
#
#
#
# Epoch 1/1
# 6803/6803 [==============================] - 22s 3ms/step - loss: 0.3596
# total chars:  140
# Peace through Strength! Let s Make America Great Again! Trump2016!" not mandated!.... beginning, help VOTE want to MAKE AMERICA GREAT AGAIN
#
#
#
# Epoch 1/1
# 6803/6803 [==============================] - 22s 3ms/step - loss: 0.3600
# total chars:  141
# Bush and Rubio couldn t answer simple question on Iraq. They will NEVER make America great again! Trump2016!" Thanks!"""""" fears make
#
#
#
# Epoch 1/1
# 6803/6803 [==============================] - 22s 3ms/step - loss: 0.3578
# total chars:  123
# somebody in that room like this guy right here, right, or that guy with the blue make America great again hat on or the one
#
#
#
# Epoch 1/1
# 6803/6803 [==============================] - 22s 3ms/step - loss: 0.3582
# total chars:  128
# changing our future. Together, we will MAKE AMERICA SAF.... He will make America LEGAL again... He will make America GREAT again
#
#
#
# Epoch 1/1
# 6803/6803 [==============================] - 22s 3ms/step - loss: 0.3579
# total chars:  143
# LikeWhoa134 I just hope@ realDonaldTrump is our next president" Make America great again!" Thanks. Trump!"!!" Thanks. Trump" You can help
#
#
#
# Epoch 1/1
# 6803/6803 [==============================] - 22s 3ms/step - loss: 0.3567
# total chars:  29
# leadership now more than ever
#
#
#
# Epoch 1/1
# 6803/6803 [==============================] - 22s 3ms/step - loss: 0.3556
# total chars:  83
# robust God will Make America Great Again". Typical pol no imagination!"."" Safe
#
#
#
# Epoch 1/1
# 6803/6803 [==============================] - 22s 3ms/step - loss: 0.3551
# total chars:  146
# House and defeat CrookedHillary. Let s Make America Great Again! FITN beginning Clinton and her cronies. Let s Make America Great Again! Trump2016
#
#
#
# Epoch 1/1
# 6803/6803 [==============================] - 22s 3ms/step - loss: 0.3546
# total chars:  68
# prosperous American future. Jobs will return, incomes will rise, and
#
#
#
# Epoch 1/1
# 6803/6803 [==============================] - 22s 3ms/step - loss: 0.3539
# total chars:  66
# MAJORITY Make America Great Again. The corrupt establishment knows
#
#
#
# Epoch 1/1
# 6803/6803 [==============================] - 22s 3ms/step - loss: 0.3537
# total chars:  142
# desperate to run is using my line" Make America Great Again". Trump. Make America Great Again!!!!!!!!!!""""""" devotion devotion SAFE
#
#
#
# Epoch 1/1
# 6803/6803 [==============================] - 22s 3ms/step - loss: 0.3526
# total chars:  140
# helping to MAKE AMERICA GREAT AGAIN! TRUMP 37 CRUZ 11 This is at the top of Drudge!"!!" They are afraid to make America great again." run
#
#
#
# Epoch 1/1
# 6803/6803 [==============================] - 22s 3ms/step - loss: 0.3520
# total chars:  149
# CBNNews by@ TheBrodyFile" Donald Trump We Must Make America Great Again". Typical pol no imagination!" Make America Great Again"."." June 16th
#
#
#
# Epoch 1/1
# 6803/6803 [==============================] - 22s 3ms/step - loss: 0.3517
# total chars:  141
# WAKE UP. MAKE AMERICA GREAT AGAIN! We must save America ELECT@ America!!!!!!" Make America Great Again!""" Make America Great AGAIN"."
#
#
#
# Epoch 1/1
# 6803/6803 [==============================] - 22s 3ms/step - loss: 0.3513
# total chars:  140
# PATRIOTS country. We will, together, MAKE AMERICA GREAT AGAIN! Watch..... He will make America GREAT again! Trump2016 USA" Thanks are doing
#
#
#
# Epoch 1/1
# 6803/6803 [==============================] - 22s 3ms/step - loss: 0.3502
# total chars:  100
# 2nd place, closely behind Jeb Bush but Bush will NEVER Make America Great Again!!!!!!" Make America
#
#
#
# Epoch 1/1
# 6803/6803 [==============================] - 22s 3ms/step - loss: 0.3496
# total chars:  139
# Thank you for your support! We will MAKE AMERICA SAFE AND GREAT AGAIN! ImWithYou AmericaFirst.... VOTE TrumpPence16 on 11 8 2016. Together,
#
#
#
# Epoch 1/1
# 6803/6803 [==============================] - 22s 3ms/step - loss: 0.3493
# total chars:  143
# HAPPY 4TH OF JULY TO EVERYONE! MAKE AMERICA GREAT AGAIN! LAST CHANCE TO MAKE AMERICA GREAT AGAIN, LAST CHANCE TO MAKE AMERICA GREAT AGAIN, LAST
#
#
#
# Epoch 1/1
# 6803/6803 [==============================] - 22s 3ms/step - loss: 0.3479
# total chars:  89
# longer be silent. We can take our country back! Let s Make America Great Again! Trump2016
#
#
#
# Epoch 1/1
# 6803/6803 [==============================] - 22s 3ms/step - loss: 0.3480
# total chars:  78
# everywhere. New H really special! We will win big and MAKE AMERICA GREAT AGAIN
#
#
#
# Epoch 1/1
# 6803/6803 [==============================] - 22s 3ms/step - loss: 0.3486
# total chars:  143
# tperkins for the New Year. Make America Great Again!" Thanks."""" Make America Great Again". Typical pol no imagination!"""" action"
#
#
#
# Epoch 1/1
# 6803/6803 [==============================] - 22s 3ms/step - loss: 0.3467
# total chars:  139
# privilege to be in this country. Not a right. Make America great again!"" So true this VOTE." The 16th. We are need to change Washington
#
#
#
# Epoch 1/1
# 6803/6803 [==============================] - 22s 3ms/step - loss: 0.3458
# total chars:  39
# BIG, BIG! Get out and vote MAKE AMERICA
#
#
#
# Epoch 1/1
# 6803/6803 [==============================] - 22s 3ms/step - loss: 0.3457
# total chars:  236
# line" Make America Great Again". Typical pol no imagination!" We will win and MAKE AMERICA GREAT AGAIN!!"."."" factories are fighting waiting for you to make America great again. Please run!" June 16th. We are fighting to unlock
#
#
#
# Epoch 1/1
# 6803/6803 [==============================] - 22s 3ms/step - loss: 0.3458
# total chars:  136
# pnicastro1@ WayneNewtonMrLV He did give tremendous praise for you this morning on@ foxandfriends. Keep it up! Make America Great Again
#
#
#
# Epoch 1/1
# 6803/6803 [==============================] - 22s 3ms/step - loss: 0.3437
# total chars:  142
# 12!! MAKE AMERICA GREAT AGAIN! Trump2016"."""" look all of the Trump Rallies today. Amazing support. We will all MAKE AMERICA GREAT AGAIN
#
#
#
# Epoch 1/1
# 6803/6803 [==============================] - 22s 3ms/step - loss: 0.3446
# total chars:  145
# inclusive and prosperous American future. Jobs will return, incomes will rise, and new factories will come rushing back to our shores. Government
#
#
#
# Epoch 1/1
# 6803/6803 [==============================] - 22s 3ms/step - loss: 0.3445
# total chars:  147
# weak on illegal immigration, with the worst voting record in the U. S. Senate in many years. He will never MAKE AMERICA GREAT AGAIN! It s not going
#
#
#
# Epoch 1/1
# 6803/6803 [==============================] - 22s 3ms/step - loss: 0.3442
# total chars:  139
# philmonaco67@ realDonaldTrump 100 Donald Trump Supporter Go Trump Make AMERICA GREAT AGAIN" Thanks."" Thanks for the MAKE AMERICA GREAT
#
#
#
# Epoch 1/1
# 6803/6803 [==============================] - 22s 3ms/step - loss: 0.3434
# total chars:  137
# onto our shores. Once more, we will have a government of, by and for the people. We Will Make America Wealthy Again. We Will Make America
#
#
#
# Epoch 1/1
# 6803/6803 [==============================] - 22s 3ms/step - loss: 0.3440
# total chars:  127
# easily beat Hillary Clinton and I havn t even focused on her yet. On our way MAKE AMERICA GREAT AGAIN! Trump2016!" Thanks. You
#
#
#
# Epoch 1/1
# 6803/6803 [==============================] - 22s 3ms/step - loss: 0.3410
# total chars:  139
# silent. We can take our country back! Let s Make America Great Again! Trump2016!!!!""" Trump"" Make America Great Again"."" not""
#
#
#
# Epoch 1/1
# 6803/6803 [==============================] - 22s 3ms/step - loss: 0.3417
# total chars:  107
# put new American steel into the spine of this country. I will fight for every neglected part of this nation
#
#
#
# Epoch 1/1
# 6803/6803 [==============================] - 22s 3ms/step - loss: 0.3410
# total chars:  139
# metal into the spine of this country. I will fight for every neglected part of this nation and I will fight to bring us all together as One
#
#
#
# Epoch 1/1
# 6803/6803 [==============================] - 22s 3ms/step - loss: 0.3425
# total chars:  109
# tax code, our incompetent leaders, Iran and making America Great Again! Sign up to Volunteer! We need someone
#
#
#
# Epoch 1/1
# 6803/6803 [==============================] - 22s 3ms/step - loss: 0.3392
# total chars:  127
# Being a great president requires great negotiating skills. Trump, a master negotiator, can make America great again." True!".
#
#
#
# Epoch 1/1
# 6803/6803 [==============================] - 22s 3ms/step - loss: 0.3400
# total chars:  137
# environmental agenda will be guided by true specialists in conservation, not those with radical political agendas. It will be a future of
#
#
#
# Epoch 1/1
# 6803/6803 [==============================] - 22s 3ms/step - loss: 0.3398
# total chars:  141
# Chris Wallace at 2 00 P. M. on@ FoxNews Turn off the football for 15 minutes, Make America Great Again! iluvamerica4trump2016@ gmail. com"
#
#
#
# Epoch 1/1
# 6803/6803 [==============================] - 22s 3ms/step - loss: 0.3392
# total chars:  138
# thank you! Together, we are going to MAKE AMERICA GREAT AGAIN! ICYMI watch rally here....... MAKE AMERICA GREAT AGAIN! Trump2016!" Thanks
#
#
#
# Epoch 1/1
# 6803/6803 [==============================] - 22s 3ms/step - loss: 0.3388
# total chars:  79
# fighting for every citizen who believes that government should serve the people
#
#
#
# Epoch 1/1
# 6803/6803 [==============================] - 22s 3ms/step - loss: 0.3395
# total chars:  131
# praise for you this morning on@ foxandfriends. Keep it up! Make America Great Again!" Thanks.@ going to make America great again
#
#
#
# Epoch 1/1
# 6803/6803 [==============================] - 22s 3ms/step - loss: 0.3391
# total chars:  140
# very simple, I want to MAKE AMERICA GREAT AGAIN!!!"."""!"" no action.. Make America Great Again!" Thanks.". Make America Great Again
#
#
#
# Epoch 1/1
# 6803/6803 [==============================] - 22s 3ms/step - loss: 0.3380
# total chars:  113
# enthusiasm. This is now a movement to MAKE AMERICA GREAT AGAIN! Trump2016!" beginning! help" neighborhoods. God
#
#
#
# Epoch 1/1
# 6803/6803 [==============================] - 22s 3ms/step - loss: 0.3363
# total chars:  132
# Rephrase quote Al Davis. justrunbaby Trump2016 Don t disappoint. There isn t another way 2 make America great again" Thanks. Thanks
#
#
#
# Epoch 1/1
# 6803/6803 [==============================] - 22s 3ms/step - loss: 0.3377
# total chars:  125
# that the polling establishment doesn t put me in polls, but put in folks who hardly register. MAKE AMERICA GREAT AGAIN!!!!!"
#
#
#
# Epoch 1/1
# 6803/6803 [==============================] - 22s 3ms/step - loss: 0.3378
# total chars:  138
# call you hard working American patriots, and together we are going to save this country and we are going to make America great again. over
#
#
#
# Epoch 1/1
# 6803/6803 [==============================] - 22s 3ms/step - loss: 0.3375
# total chars:  133
# Nebraska, we will MAKE AMERICA GREAT AGAIN! ICYMI watch rally here..... MAKE AMERICA GREAT AGAIN! MAGA.... He will make America GREAT
#
#
#
# Epoch 1/1
# 6803/6803 [==============================] - 22s 3ms/step - loss: 0.3378
# total chars:  81
# Peace through Strength! Let s Make America Great Again! You Can Help Stop Crooked
#
#
#
# Epoch 1/1
# 6803/6803 [==============================] - 22s 3ms/step - loss: 0.3361
# total chars:  136
# CrookedHillary. Let s Make America Great Again!" Thanks. You,. God. God the time.". Together, we are going to make America great again
#
#
#
# Epoch 1/1
# 6803/6803 [==============================] - 22s 3ms/step - loss: 0.3357
# total chars:  50
# gonna make America doesn t sound nice, but we have
#
#
#
# Epoch 1/1
# 6803/6803 [==============================] - 22s 3ms/step - loss: 0.3351
# total chars:  95
# Leaders who negotiate smart trade deals. Only one knows The Art of The Deal. Let s Make America
#
#
#
# Epoch 1/1
# 6803/6803 [==============================] - 22s 3ms/step - loss: 0.3335
# total chars:  139
# Stay True! Great and savvy bizman! America GREAT!!!"!!" June asset. I m on results tonight VOTE more all, action make America great again
#
#
#
# Epoch 1/1
# 6803/6803 [==============================] - 22s 3ms/step - loss: 0.3348
# total chars:  109
# CNNPolitics We need Trump Now!!!" Make America Great Again Mr. Trump"" not"."." Lets make America great
#
#
#
# Epoch 1/1
# 6803/6803 [==============================] - 22s 3ms/step - loss: 0.3349
# total chars:  110
# united again, we will make America proud again, we will make America safe again and we will make America great
#
#
#
# Epoch 1/1
# 6803/6803 [==============================] - 22s 3ms/step - loss: 0.3344
# total chars:  71
# Social onto our shores. Once more, we will have a government of, by and
#
#
#
# Epoch 1/1
# 6803/6803 [==============================] - 22s 3ms/step - loss: 0.3338
# total chars:  134
# Sam Clovis tomorrow at@ MorningsideEdu in Sioux City at 10AM CT! Let s Make America Great Again! iluvamerica4trump2016@ gmail. com"
#
#
#
# Epoch 1/1
# 6803/6803 [==============================] - 22s 3ms/step - loss: 0.3334
# total chars:  137
# Addressing record crowd@ Madison County Iowa GOP Dinner. We can bring common sense to DC Make America Great Again!" Thanks. Thanks..".
#
#
#
# Epoch 1/1
# 6803/6803 [==============================] - 22s 3ms/step - loss: 0.3324
# total chars:  141
# policies and division of the past, and embrace true American change to rebuild our economy, rebuild our inner cities, and rebuild our country
#
#
#
# Epoch 1/1
# 6803/6803 [==============================] - 22s 3ms/step - loss: 0.3330
# total chars:  137
# TheEconomist has me in 1st. place by a lot. A great honor but we have a long way to go to MAKE AMERICA GREAT AGAIN! AmericaFirst...... is
#
#
#
# Epoch 1/1
# 6803/6803 [==============================] - 22s 3ms/step - loss: 0.3325
# total chars:  141
# reality. Together, we will have a government of, by and for the people. We will make America wealthy again. We will make America strong again
#
#
#
# Epoch 1/1
# 6803/6803 [==============================] - 22s 3ms/step - loss: 0.3320
# total chars:  103
# she WE WILL MAKE AMERICA GREAT AGAIN! AmericaFirst...... MAKE AMERICA GREAT AGAIN! It will be AND FIRST
#
#
#
# Epoch 1/1
# 6803/6803 [==============================] - 22s 3ms/step - loss: 0.3312
# total chars:  143
# fix DC from the inside. Let s Make America Great Again! iluvamerica4trump2016@ gmail. com"" never THINKBIG along.." June 16th. We will make
#
#
#
# Epoch 1/1
# 6803/6803 [==============================] - 22s 3ms/step - loss: 0.3321
# total chars:  130
# Middle School! Thanks to@ straffordnhgop for hosting! Let s Make America Great Again! iluvamerica4trump2016@ gmail. com"" look
#
#
#
# Epoch 1/1
# 6803/6803 [==============================] - 22s 3ms/step - loss: 0.3315
# total chars:  141
# guided by true specialists in conservation, not those with radical political agendas. It will be a future of conservation, of prosperity, and
#
#
#
# Epoch 1/1
#  384/6803 [>.............................] - ETA: 21s - loss: 0.3157
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-29-5ac21b17a073> in <module>()
#       1 for i in range (0,200):
#       2     print('\n\n')
# ----> 3     model3.fit(X_version_bytweet, y_version_bytweet, batch_size=BATCH_SIZE, verbose=1, nb_epoch=1)
#       4     nb_epoch += 1
#       5     output_as_sentence(generate_words(model3))
#
# /usr/local/lib/python2.7/dist-packages/keras/models.pyc in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#     958                               initial_epoch=initial_epoch,
#     959                               steps_per_epoch=steps_per_epoch,
# --> 960                               validation_steps=validation_steps)
#     961
#     962     def evaluate(self, x, y, batch_size=32, verbose=1,
#
# /usr/local/lib/python2.7/dist-packages/keras/engine/training.pyc in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1655                               initial_epoch=initial_epoch,
#    1656                               steps_per_epoch=steps_per_epoch,
# -> 1657                               validation_steps=validation_steps)
#    1658
#    1659     def evaluate(self, x=None, y=None,
#
# /usr/local/lib/python2.7/dist-packages/keras/engine/training.pyc in _fit_loop(self, f, ins, out_labels, batch_size, epochs, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps)
#    1211                     batch_logs['size'] = len(batch_ids)
#    1212                     callbacks.on_batch_begin(batch_index, batch_logs)
# -> 1213                     outs = f(ins_batch)
#    1214                     if not isinstance(outs, list):
#    1215                         outs = [outs]
#
# /usr/local/lib/python2.7/dist-packages/keras/backend/tensorflow_backend.pyc in __call__(self, inputs)
#    2355         session = get_session()
#    2356         updated = session.run(fetches=fetches, feed_dict=feed_dict,
# -> 2357                               **self.session_kwargs)
#    2358         return updated[:len(self.outputs)]
#    2359
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in run(self, fetches, feed_dict, options, run_metadata)
#     887     try:
#     888       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 889                          run_metadata_ptr)
#     890       if run_metadata:
#     891         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1118     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1119       results = self._do_run(handle, final_targets, final_fetches,
# -> 1120                              feed_dict_tensor, options, run_metadata)
#    1121     else:
#    1122       results = []
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1315     if handle is None:
#    1316       return self._do_call(_run_fn, self._session, feeds, fetches, targets,
# -> 1317                            options, run_metadata)
#    1318     else:
#    1319       return self._do_call(_prun_fn, self._session, handle, feeds, fetches)
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _do_call(self, fn, *args)
#    1321   def _do_call(self, fn, *args):
#    1322     try:
# -> 1323       return fn(*args)
#    1324     except errors.OpError as e:
#    1325       message = compat.as_text(e.message)
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1300           return tf_session.TF_Run(session, options,
#    1301                                    feed_dict, fetch_list, target_list,
# -> 1302                                    status, run_metadata)
#    1303
#    1304     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %% [markdown]
# ### Model 4
# Version 2 of training data , seq=10

# %%
BATCH_SIZE = 128
HIDDEN_DIM = 700
LAYER_NUM = 3 
nb_epoch = 0

model4 = create_model(HIDDEN_DIM, LAYER_NUM)

# %%
for i in range (0,200):
    print('\n\n')
    model4.fit(X_version_byalltext, y_version_byalltext, batch_size=BATCH_SIZE, verbose=1, nb_epoch=1)
    nb_epoch += 1
    output_as_sentence(generate_words(model4))
    if nb_epoch % 10 == 0:
        model4.save_weights('model4/checkpoint_{}_epoch_{}.hdf5'.format(HIDDEN_DIM, nb_epoch))
# Out:
# /usr/local/lib/python2.7/dist-packages/keras/models.py:939: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
#   warnings.warn('The `nb_epoch` argument in `fit` '
# Epoch 1/1
# 11847/11847 [==============================] - 46s 4ms/step - loss: 5.6780
# total chars:  145
# Abraham.... America America AGAIN!!" @!!! @@ @@ @@ @@ @@ @@ @@ Dr closely closely closely closely closely closely closely closely closely
#
#
#
# Epoch 1/1
# 11847/11847 [==============================] - 38s 3ms/step - loss: 4.5484
# total chars:  148
# Turn @realDonaldTrump @realDonaldTrump @realDonaldTrump @realDonaldTrump @realDonaldTrump @realDonaldTrump @realDonaldTrump @realDonaldTrump
#
#
#
# Epoch 1/1
# 11847/11847 [==============================] - 38s 3ms/step - loss: 3.6126
# total chars:  142
# nation. I will work hard and never let you down. Make America Great Again!" @Knight276 @realDonaldTrump @realDonaldTrump @realDonaldTrump
#
#
#
# Epoch 1/1
# 11847/11847 [==============================] - 38s 3ms/step - loss: 2.9505
# total chars:  88
# 4TH realDonaldTrump on the 8 16. Together, we will MAKE AMERICA GREAT AGAIN! #Trump2016
#
#
#
# Epoch 1/1
# 11847/11847 [==============================] - 38s 3ms/step - loss: 2.3918
# total chars:  126
# Patriots and want to MAKE AMERICA GREAT AGAIN! Thank you West Virginia! MAKE AMERICA GREAT AGAIN! Thank you West Virginia! All
#
#
#
# Epoch 1/1
# 11847/11847 [==============================] - 38s 3ms/step - loss: 1.9192
# total chars:  31
# doing @realDonaldTrump at been
#
#
#
# Epoch 1/1
# 11847/11847 [==============================] - 38s 3ms/step - loss: 1.5468
# total chars:  144
# cases. It s time to break with the bitter failures of the past, and to embrace a new, inclusive and prosperous American future. Jobs will return
#
#
#
# Epoch 1/1
# 11847/11847 [==============================] - 38s 3ms/step - loss: 1.2668
# total chars:  143
# s Make America Great Again! I m with YOU. I will work hard and never let you down. Make America Great Again! I m with you! I will work hard and
#
#
#
# Epoch 1/1
# 11847/11847 [==============================] - 38s 3ms/step - loss: 1.0676
# total chars:  105
# michell33841372 your Hillary to you for the government of and by and for the people. We will make America
#
#
#
# Epoch 1/1
# 11847/11847 [==============================] - 38s 3ms/step - loss: 0.9356
# total chars:  102
# travis_temple Make America Great Again!" @Knight276 @realDonaldTrump @amstaffbru I have confidence
#
#
#
# Epoch 1/1
# 11847/11847 [==============================] - 38s 3ms/step - loss: 0.8404
# total chars:  65
# her cronies. Let s Make America Great Again! I m with YOU. I will
#
#
#
# Epoch 1/1
# 11847/11847 [==============================] - 38s 3ms/step - loss: 0.7692
# total chars:  134
# Iran and defeat Hillary Clinton and her cronies. Let s Make America Great Again! I m with YOU. I will work hard and never let you down
#
#
#
# Epoch 1/1
# 11847/11847 [==============================] - 38s 3ms/step - loss: 0.7115
# total chars:  70
# place, not successful primary c is very simple, I want to MAKE AMERICA
#
#
#
# Epoch 1/1
# 11847/11847 [==============================] - 38s 3ms/step - loss: 0.6704
# total chars:  140
# Doing great deals. It s time to Make America Great Again! Big crowds, standing ovations in South Carolina MAKE AMERICA GREAT AGAIN! A strong
#
#
#
# Epoch 1/1
# 11847/11847 [==============================] - 38s 3ms/step - loss: 0.6337
# total chars:  80
# Trump! I will be 100 in your corner if you choose to make America great again!!!
#
#
#
# Epoch 1/1
# 11847/11847 [==============================] - 38s 3ms/step - loss: 0.6069
# total chars:  33
# SHALL make America great again."
#
#
#
# Epoch 1/1
# 11847/11847 [==============================] - 38s 3ms/step - loss: 0.5849
# total chars:  144
# TimeToGetTough on China! @realDonaldTrump will do that! I now see John Kasich from Ohio who is desperate to run is using my line" Make America
#
#
#
# Epoch 1/1
# 11847/11847 [==============================] - 38s 3ms/step - loss: 0.5661
# total chars:  112
# overseas" Let s Make America Great Again! My @msnbc int w @krystalball at #WHCD on my 2016 timetable, saving
#
#
#
# Epoch 1/1
# 11847/11847 [==============================] - 38s 3ms/step - loss: 0.5498
# total chars:  149
# borders. We will make America strong again. We will make America safe again. And we must make America great again. America fist, again! America first
#
#
#
# Epoch 1/1
# 11847/11847 [==============================] - 38s 3ms/step - loss: 0.5371
# total chars:  142
# learn a thing or two from @realDonaldTrump about making America great again We must build a wall to secure our border. We will bring back our
#
#
#
# Epoch 1/1
# 11847/11847 [==============================] - 38s 3ms/step - loss: 0.5265
# total chars:  146
# UNITED TO MAKE AMERICA GREAT AGAIN #Trump" @PattyDs50 @FoxNews We want Donald!! Yah next president! #TrumpTrain #TrumpForPresident" We will
#
#
#
# Epoch 1/1
# 11847/11847 [==============================] - 40s 3ms/step - loss: 0.5181
# total chars:  145
# angiecallahan4 @realDonaldTrump We need to PRAY to God for this to happen. God please make America great again. Amen!" MAKE AMERICA GREAT AGAIN
#
#
#
# Epoch 1/1
# 11847/11847 [==============================] - 50s 4ms/step - loss: 0.5111
# total chars:  91
# were great on @seanhannity last night. Thanks for the nice words. MAKE AMERICA GREAT AGAIN
#
#
#
# Epoch 1/1
# 11847/11847 [==============================] - 47s 4ms/step - loss: 0.5044
# total chars:  143
# SaveAmericanLives MAKE AMERICA GREAT AGAIN! Together, we are going to MAKE AMERICA GREAT AGAIN! Join us #AmericaFirst Thank you Ohio. Together
#
#
#
# Epoch 1/1
# 11847/11847 [==============================] - 46s 4ms/step - loss: 0.4988
# total chars:  139
# military and EVERYTHING else, it will be AMERICA FIRST! This will quickly lead to our ultimate goal MAKE AMERICA GREAT AGAIN! #Trump2016"
#
#
#
# Epoch 1/1
# 11847/11847 [==============================] - 46s 4ms/step - loss: 0.4933
# total chars:  84
# exclusive @realDonaldTrump updates! We will Make America Great Again!. @CNN is the
#
#
#
# Epoch 1/1
# 11847/11847 [==============================] - 46s 4ms/step - loss: 0.4891
# total chars:  141
# think numbers could be in the 50 s. Together, WE will MAKE AMERICA GREAT AGAIN! Thank you Pennsylvania I am forever grateful for your amazing
#
#
#
# Epoch 1/1
# 11847/11847 [==============================] - 46s 4ms/step - loss: 0.4843
# total chars:  146
# outta bed, you gotta get up, you gotta vote. Together we will make America wealthy again, we will make America wealthy again. We will make America
#
#
#
# Epoch 1/1
# 11847/11847 [==============================] - 46s 4ms/step - loss: 0.4814
# total chars:  97
# TO MAKE AMERICA GREAT Thank you @CharlesHurt for the nice words on @seanhannity. I will win and
#
#
#
# Epoch 1/1
# 11847/11847 [==============================] - 46s 4ms/step - loss: 0.4785
# total chars:  140
# washingtonpost 38. MAKE AMERICA GREAT AGAIN! Our VISA system is broken, like so much else in our country. We better get it fixed really fast
#
#
#
# Epoch 1/1
# 11847/11847 [==============================] - 46s 4ms/step - loss: 0.4756
# total chars:  143
# election, Russia, Russia, Russia. Despite this I have the economy booming and have possibly done more than any 10 month President. MAKE AMERICA
#
#
#
# Epoch 1/1
# 11847/11847 [==============================] - 46s 4ms/step - loss: 0.4736
# total chars:  123
# Happy Thanksgiving to all. Have a great day and look forward to the future. We will MAKE AMERICA GREAT AGAIN!" @LifeZette
#
#
#
# Epoch 1/1
# 11847/11847 [==============================] - 46s 4ms/step - loss: 0.4712
# total chars:  97
# morning on @foxandfriends. Keep it up! Make America Great Again!"" @sjbatis @realDonaldTrump
#
#
#
# Epoch 1/1
# 11847/11847 [==============================] - 45s 4ms/step - loss: 0.4684
# total chars:  137
# endorse our speaker of the House, Paul Ryan. We are going to make America great again. We re going to make America safe again. But never,
#
#
#
# Epoch 1/1
# 11847/11847 [==============================] - 46s 4ms/step - loss: 0.4677
# total chars:  82
# if we started working together as One People, under One God, saluting One American
#
#
#
# Epoch 1/1
# 11847/11847 [==============================] - 46s 4ms/step - loss: 0.4655
# total chars:  99
# many great people! Melania is joining me on Monday. Big crowds. MAKE AMERICA GREAT AGAIN! Thank you
#
#
#
# Epoch 1/1
# 11847/11847 [==============================] - 46s 4ms/step - loss: 0.4636
# total chars:  63
# Free and I know that DonaldTrump will cut through the confusion
#
#
#
# Epoch 1/1
# 11847/11847 [==============================] - 45s 4ms/step - loss: 0.4624
# total chars:  107
# swing states, and lost. The voters wanted to MAKE AMERICA GREAT AGAIN! Thank you Pennsylvania! Together, we
#
#
#
# Epoch 1/1
# 11847/11847 [==============================] - 45s 4ms/step - loss: 0.4611
# total chars:  94
# guy with the blue make America great again hat on or the one with the red make America or that
#
#
#
# Epoch 1/1
# 11847/11847 [==============================] - 45s 4ms/step - loss: 0.4594
# total chars:  94
# 5 and O! All the Fake News, all the money spent 0 The MAKE AMERICA GREAT AGAIN agenda is doing
#
#
#
# Epoch 1/1
# 11847/11847 [==============================] - 45s 4ms/step - loss: 0.4579
# total chars:  129
# able to make America wealthy again, to make America strong again, to make America safe again, and to make America great again. We
#
#
#
# Epoch 1/1
# 11847/11847 [==============================] - 45s 4ms/step - loss: 0.4570
# total chars:  80
# trade deals. Only one knows The Art of The Deal. Let s Make America Great Again!
#
#
#
# Epoch 1/1
# 11847/11847 [==============================] - 45s 4ms/step - loss: 0.4548
# total chars:  71
# environmental agenda will be guided by true specialists in conservation
#
#
#
# Epoch 1/1
# 11847/11847 [==============================] - 45s 4ms/step - loss: 0.4549
# total chars:  140
# Top searched candidate by state, as seen in the #GOPDebate media filing center. WE WILL MAKE AMERICA GREAT AGAIN! In the just out @FoxNews
#
#
#
# Epoch 1/1
# 11847/11847 [==============================] - 45s 4ms/step - loss: 0.4534
# total chars:  68
# With your vote, we are just 10 days away from the change you ve been
#
#
#
# Epoch 1/1
# 11847/11847 [==============================] - 46s 4ms/step - loss: 0.4519
# total chars:  146
# 1 30PM tomorrow in Nashua at @NHGOP @FITNsummit!. Let s Make America Great Again! #FITN For America to be strong again, the ways of politicians
#
#
#
# Epoch 1/1
# 11847/11847 [==============================] - 45s 4ms/step - loss: 0.4508
# total chars:  111
# ifAgain! Never forget you have support!" I will be on @FoxNews live, with members of my family, at 11 50 P. M
#
#
#
# Epoch 1/1
# 11847/11847 [==============================] - 44s 4ms/step - loss: 0.4500
# total chars:  84
# negotiating skills. Trump, a master negotiator, can make America great again." True
#
#
#
# Epoch 1/1
# 11847/11847 [==============================] - 45s 4ms/step - loss: 0.4487
# total chars:  143
# build a wall to secure our border. It will save lives and help Make America Great Again!" @bluestarwindow @realDonaldTrump @realDonaldTrump
#
#
#
# Epoch 1/1
# 11847/11847 [==============================] - 44s 4ms/step - loss: 0.4482
# total chars:  129
# MEMEoryHead I m one of your biggest fans Mr Trump and I can t wait for you to Make America Great Again! You Can Help Stop Crooked
#
#
#
# Epoch 1/1
# 11847/11847 [==============================] - 45s 4ms/step - loss: 0.4471
# total chars:  96
# Why do u keep trying to attack Trump? Really dumb strategy! U lose, he wins! #lets make America
#
#
#
# Epoch 1/1
# 11847/11847 [==============================] - 44s 4ms/step - loss: 0.4461
# total chars:  138
# realdonaldtrump @cleopattrausa Donald you are the next Ronald Reagan. Make America great again." Thank you. Politicians are all talk and
#
#
#
# Epoch 1/1
# 11847/11847 [==============================] - 44s 4ms/step - loss: 0.4450
# total chars:  101
# have a government of, by and for the people. We Will Make America Wealthy Again. We Will Make America
#
#
#
# Epoch 1/1
# 11847/11847 [==============================] - 44s 4ms/step - loss: 0.4437
# total chars:  114
# nation and I will fight to bring us all together as One American People. Imagine what our country could accomplish
#
#
#
# Epoch 1/1
# 11847/11847 [==============================] - 44s 4ms/step - loss: 0.4435
# total chars:  131
# TAKE OUR COUNTRY BACK AND MAKE AMERICA GREAT AGAIN! It is time to take back our country and MAKE AMERICA GREAT AGAIN! #Trump2016"
#
#
#
# Epoch 1/1
# 11847/11847 [==============================] - 44s 4ms/step - loss: 0.4422
# total chars:  137
# greta int. on @FoxNews with @MELANIATRUMP at OPO discussing my potential candidacy making America great again My @FoxNews @megynkelly
#
#
#
# Epoch 1/1
# 11847/11847 [==============================] - 44s 4ms/step - loss: 0.4413
# total chars:  55
# waiting for you to make America great again. Please run
#
#
#
# Epoch 1/1
# 11847/11847 [==============================] - 44s 4ms/step - loss: 0.4408
# total chars:  137
# destroy Hillary in a debate!" We must win and make America great again!" @Knight276 @realDonaldTrump @HCannonball not being a career
#
#
#
# Epoch 1/1
# 11847/11847 [==============================] - 44s 4ms/step - loss: 0.4407
# total chars:  90
# INPrimary #VoteTrump I will be in Indiana on Sunday and Monday at four MAKE AMERICA GREAT
#
#
#
# Epoch 1/1
# 11847/11847 [==============================] - 43s 4ms/step - loss: 0.4402
# total chars:  42
# Stop Crooked Hillary Clinton! #NeverTrump
#
#
#
# Epoch 1/1
# 11847/11847 [==============================] - 44s 4ms/step - loss: 0.4395
# total chars:  139
# Sam Clovis intro! Let s Make America Great Again! I am in Iowa today, great STATE, fantastic PEOPLE! Many speeches, big crowds all sold out
#
#
#
# Epoch 1/1
# 11847/11847 [==============================] - 44s 4ms/step - loss: 0.4383
# total chars:  79
# Rallies today. Amazing support. We will all MAKE AMERICA GREAT AGAIN! Thank you
#
#
#
# Epoch 1/1
# 11847/11847 [==============================] - 44s 4ms/step - loss: 0.4378
# total chars:  136
# are going to MAKE AMERICA GREAT AGAIN! Making America Safe is my number one priority. We will not admit those into our country we cannot
#
#
#
# Epoch 1/1
# 11847/11847 [==============================] - 44s 4ms/step - loss: 0.4370
# total chars:  65
# fraction of this 25k crowd in. The movement to Make America Great
#
#
#
# Epoch 1/1
# 11847/11847 [==============================] - 44s 4ms/step - loss: 0.4365
# total chars:  93
# Made all of my points. MAKE AMERICA GREAT AGAIN! I started this c to Make America Great Again
#
#
#
# Epoch 1/1
# 11847/11847 [==============================] - 44s 4ms/step - loss: 0.4359
# total chars:  146
# sacrifices to make america great again!" We are going to WIN and MAKE AMERICA GREAT AGAIN, maybe greater than ever before!" @tvegan DonaldTrump
#
#
#
# Epoch 1/1
# 11847/11847 [==============================] - 44s 4ms/step - loss: 0.4364
# total chars:  141
# send someone from the outside to fix DC from the inside. Let s Make America Great Again! We are going to have a great time in Cleveland. Will
#
#
#
# Epoch 1/1
# 11847/11847 [==============================] - 44s 4ms/step - loss: 0.4348
# total chars:  111
# ifAgain! Never forget you have support!" I will be on @FoxNews live, with members of my family, at 11 50 P. M
#
#
#
# Epoch 1/1
# 11847/11847 [==============================] - 44s 4ms/step - loss: 0.4339
# total chars:  145
# troyconway Donald get big business back and #MAKE AMERICA GREAT AGAIN FOR 2016" The rally in Lowell, Massachusetts, was amazing. 10, 000 people
#
#
#
# Epoch 1/1
# 11847/11847 [==============================] - 43s 4ms/step - loss: 0.4340
# total chars:  110
# aldeguer_elsa @American1st @ofccadjust @AnnCoulter @JebBush HISPANICS UNITED TO MAKE AMERICA GREAT AGAIN #
#
#
#
# Epoch 1/1
# 11847/11847 [==============================] - 43s 4ms/step - loss: 0.4339
# total chars:  99
# DAUGHT IVANKA" I can just say without equivocation, my father will make America great again."" @
#
#
#
# Epoch 1/1
# 11847/11847 [==============================] - 43s 4ms/step - loss: 0.4326
# total chars:  134
# United Nations. So many interesting leaders. America First will MAKE AMERICA GREAT AGAIN! RT @glamourizes @realDonaldTrump Only true
#
#
#
# Epoch 1/1
# 11847/11847 [==============================] - 43s 4ms/step - loss: 0.4325
# total chars:  143
# grateful for your amazing support. Lets MAKE AMERICA GREAT AGAIN! #MAGA..... Thank you! Four new #DebateNight polls with the MOVEMENT winning
#
#
#
# Epoch 1/1
# 11847/11847 [==============================] - 43s 4ms/step - loss: 0.4316
# total chars:  140
# NevadaCaucus THANK YOU Atlanta, Georgia! Leaving for Nevada now. Lets MAKE AMERICA SAFE AND GREAT AGAIN! A... It will be AMERICA FIRST! MAKE
#
#
#
# Epoch 1/1
# 11847/11847 [==============================] - 43s 4ms/step - loss: 0.4314
# total chars:  144
# inside reality. MAKE AMERICA GREAT with TRUMP" My message, MAKE AMERICA GREAT AGAIN, is beginning to take hold. Bring back our jobs, strengthen
#
#
#
# Epoch 1/1
# 11847/11847 [==============================] - 43s 4ms/step - loss: 0.4310
# total chars:  132
# where the crowd is amazing. Dr. Robert Jeffress will make the introduction. Make America Great Again! My @msnbc int w @krystalball
#
#
#
# Epoch 1/1
# 11847/11847 [==============================] - 43s 4ms/step - loss: 0.4304
# total chars:  100
# winning. Together, we will MAKE AMERICA SAFE GREAT AGAIN!... ratings are head to bring back our jobs
#
#
#
# Epoch 1/1
# 11847/11847 [==============================] - 43s 4ms/step - loss: 0.4284
# total chars:  126
# begins. We will, together, MAKE AMERICA GREAT AGAIN! President Obama c hard and personally in the very important swing states,
#
#
#
# Epoch 1/1
# 11847/11847 [==============================] - 42s 4ms/step - loss: 0.4297
# total chars:  130
# thing or two from @realDonaldTrump about making America great again We must build a wall to secure our border. It will save lives
#
#
#
# Epoch 1/1
# 11847/11847 [==============================] - 42s 4ms/step - loss: 0.4285
# total chars:  142
# cleopattrausa Donald you are the next Ronald Reagan. Make America great again." Thank you. Politicians are all talk and no action. Washington
#
#
#
# Epoch 1/1
# 11847/11847 [==============================] - 42s 4ms/step - loss: 0.4278
# total chars:  118
# fixed by an outsider. Let s make America great again! Washington needs common sense conservative solutions. Let s make
#
#
#
# Epoch 1/1
# 11847/11847 [==============================] - 42s 4ms/step - loss: 0.4270
# total chars:  140
# even watch Dem debate except Donald is tweeting about it!" @MintzShire @realDonaldTrump @007lLisav @CNN @CNNPolitics We need Trump Now
#
#
#
# Epoch 1/1
# 11847/11847 [==============================] - 42s 4ms/step - loss: 0.4269
# total chars:  139
# Summit on Saturday at 12PM! Let s Make America Great Again!" @CBNNews by @TheBrodyFile" Donald Trump We Must Make America Great Again"
#
#
#
# Epoch 1/1
# 11847/11847 [==============================] - 42s 4ms/step - loss: 0.4266
# total chars:  146
# small fraction of this 25k crowd in. The movement to Make America Great Again is unbelievable! I will be in beautiful Burlington, Vermont, tonight
#
#
#
# Epoch 1/1
# 11847/11847 [==============================] - 42s 4ms/step - loss: 0.4257
# total chars:  42
# MEDIA WANTS A PUPPET. WE WANT DONALD TRUMP
#
#
#
# Epoch 1/1
# 11847/11847 [==============================] - 42s 4ms/step - loss: 0.4256
# total chars:  91
# Knight276 @realDonaldTrump @amstaffbru I have confidence trump can turn a negative into a
#
#
#
# Epoch 1/1
# 11847/11847 [==============================] - 43s 4ms/step - loss: 0.4252
# total chars:  39
# jobs, higher wages, and amazing schools
#
#
#
# Epoch 1/1
# 11847/11847 [==============================] - 42s 4ms/step - loss: 0.4248
# total chars:  134
# ABC @washingtonpost 38. MAKE AMERICA GREAT AGAIN! Our VISA system is broken, like so much else in our country. We better get it fixed
#
#
#
# Epoch 1/1
# 11847/11847 [==============================] - 42s 4ms/step - loss: 0.4246
# total chars:  128
# else. Just arrived in Las Vegas for a packed house speech tomorrow. Big poll results today, Leading big everywhere. MAKE AMERICA
#
#
#
# Epoch 1/1
# 11847/11847 [==============================] - 42s 4ms/step - loss: 0.4240
# total chars:  142
# attack Trump? Really dumb strategy! U lose, he wins! #lets make America great again!!!!!!!" Thanks!" @Roolaloo Joined twitter tonight JUST
#
#
#
# Epoch 1/1
# 11847/11847 [==============================] - 41s 3ms/step - loss: 0.4238
# total chars:  98
# Sarasota, Florida, today for a big rally with amazing people! I have one goal on mind MAKE AMERICA
#
#
#
# Epoch 1/1
# 11847/11847 [==============================] - 41s 3ms/step - loss: 0.4226
# total chars:  145
# again. We will make America safe again. And we are going to make America great again. You re going to look back at this election, and say this is
#
#
#
# Epoch 1/1
# 11847/11847 [==============================] - 42s 4ms/step - loss: 0.4225
# total chars:  141
# time to break with the bitter failures of the past, and to embrace a new, inclusive and prosperous American future. Jobs will return, incomes
#
#
#
# Epoch 1/1
# 11847/11847 [==============================] - 42s 4ms/step - loss: 0.4225
# total chars:  146
# next president" Make America great again!" @fackinpeter @realDonaldTrump cant believe ted cruz stole your c slogan. Only you can really" make
#
#
#
# Epoch 1/1
# 11847/11847 [==============================] - 42s 4ms/step - loss: 0.4224
# total chars:  89
# nobody has ever seen before. Together, we are going to MAKE AMERICA SAFE AND GREAT AGAIN!
#
#
#
# Epoch 1/1
# 11847/11847 [==============================] - 41s 3ms/step - loss: 0.4216
# total chars:  140
# master negotiator, can make America great again." True!" @angiecallahan4 @realDonaldTrump We need to PRAY to God for this to happen. God
#
#
#
# Epoch 1/1
# 11847/11847 [==============================] - 41s 3ms/step - loss: 0.4209
# total chars:  115
# STATE, fantastic PEOPLE! Many speeches, big crowds all sold out! MAKE AMERICA GREAT AGAIN! Looking forward to being
#
#
#
# Epoch 1/1
# 11847/11847 [==============================] - 42s 4ms/step - loss: 0.4204
# total chars:  138
# jobs, great schools, and great neighborhoods. We will keep our children safe which includes steadfast support for American law enforcement
#
#
#
# Epoch 1/1
# 11847/11847 [==============================] - 41s 3ms/step - loss: 0.4205
# total chars:  140
# fought and died for our great American Flag we MUST honor and respect it! MAKE AMERICA GREAT AGAIN! Big meetings today at the United Nations
#
#
#
# Epoch 1/1
# 11847/11847 [==============================] - 41s 3ms/step - loss: 0.4199
# total chars:  140
# speeches, big crowds all sold out! MAKE AMERICA GREAT AGAIN! Looking forward to being interviewed by Sam Clovis tomorrow at @MorningsideEdu
#
#
#
# Epoch 1/1
# 11847/11847 [==============================] - 41s 3ms/step - loss: 0.4204
# total chars:  115
# Republican Leadership Summit on Saturday at 12PM! Let s Make America Great Again!" @marybnall01 @realDonaldTrump
#
#
#
# Epoch 1/1
# 11847/11847 [==============================] - 41s 3ms/step - loss: 0.4196
# total chars:  36
# ask me why I may run for President I
#
#
#
# Epoch 1/1
# 11847/11847 [==============================] - 41s 3ms/step - loss: 0.4199
# total chars:  108
# HAS NO STRENGTH OR STAMINA, both of which are needed to MAKE AMERICA GREAT AGAIN!" @lee_richter TRUMP will
#
#
#
# Epoch 1/1
# 11847/11847 [==============================] - 41s 3ms/step - loss: 0.4201
# total chars:  80
# Again! I m with YOU. I will work hard and never let you down. Make America Great
#
#
#
# Epoch 1/1
# 11847/11847 [==============================] - 42s 4ms/step - loss: 0.4190
# total chars:  130
# momentum going Mr. Trump. All the best to you for the New Year. Make America Great Again! I m with YOU. I will work hard and never
#
#
#
# Epoch 1/1
# 11847/11847 [==============================] - 41s 3ms/step - loss: 0.4184
# total chars:  141
# 5 and O! All the Fake News, all the money spent 0 The MAKE AMERICA GREAT AGAIN agenda is doing very well despite the distraction of the Witch
#
#
#
# Epoch 1/1
# 11847/11847 [==============================] - 41s 4ms/step - loss: 0.4179
# total chars:  141
# stops, many great people! Melania is joining me on Monday. Big crowds. MAKE AMERICA GREAT AGAIN! Thank you Eau Claire, Wisconsin. #VoteTrump
#
#
#
# Epoch 1/1
# 11847/11847 [==============================] - 41s 3ms/step - loss: 0.4187
# total chars:  126
# So many great polls like Reuters big leads everywhere. New H really special! We will win big and MAKE AMERICA GREAT AGAIN!" @
#
#
#
# Epoch 1/1
# 11847/11847 [==============================] - 41s 3ms/step - loss: 0.4184
# total chars:  120
# earliest supporters. Like Reagan, it s time to Make America Great Again! Big crowds, standing ovations in South Carolina
#
#
#
# Epoch 1/1
# 11847/11847 [==============================] - 41s 3ms/step - loss: 0.4182
# total chars:  129
# Doing really well. Great Thanksgiving or Christmas present!" @burgettn @AB1132 @realDonaldTrump it s the only way we can make
#
#
#
# Epoch 1/1
# 11847/11847 [==============================] - 41s 3ms/step - loss: 0.4172
# total chars:  128
# traits that we need to make America great again. We will make America strong again. We will make America safe again. And we will
#
#
#
# Epoch 1/1
# 11847/11847 [==============================] - 41s 3ms/step - loss: 0.4180
# total chars:  142
# fight for every neglected part of this nation and I will fight to bring us all together as One American People. Imagine what our country could
#
#
#
# Epoch 1/1
# 11847/11847 [==============================] - 41s 3ms/step - loss: 0.4176
# total chars:  130
# when a podium speaker is for Trump! VAST MAJORITY want Make America Great Again! We are going to MAKE AMERICA GREAT AGAIN! Join me
#
#
#
# Epoch 1/1
# 11847/11847 [==============================] - 41s 3ms/step - loss: 0.4168
# total chars:  138
# traits that we need to make America great again. We are going to make America great again. We re going to make America great again. Great.
#
#
#
# Epoch 1/1
# 11847/11847 [==============================] - 42s 4ms/step - loss: 0.4171
# total chars:  131
# winning. Together, we will MAKE AMERICA SAFE GREAT AGAIN! Thank you Pennsylvania I D, TRUMP! MAKE AMERICA GREAT AGAIN! MAKE AMERICA
#
#
#
# Epoch 1/1
# 11847/11847 [==============================] - 42s 4ms/step - loss: 0.4158
# total chars:  139
# V. P. Debate. Very exciting! MAKE AMERICA GREAT AGAIN! Thank you ARIZONA! This is a MOVEMENT like nobody has ever seen before. Together, we
#
#
#
# Epoch 1/1
# 11847/11847 [==============================] - 42s 4ms/step - loss: 0.4154
# total chars:  116
# neglected part of this nation and I will fight to bring us all together as Americans. Imagine what our country could
#
#
#
# Epoch 1/1
# 11847/11847 [==============================] - 42s 4ms/step - loss: 0.4159
# total chars:  137
# Nice!" @ccorreia401 @realDonaldTrump @blewthebigone well said. We the people want the truth. We the people want to make America great
#
#
#
# Epoch 1/1
# 11847/11847 [==============================] - 41s 3ms/step - loss: 0.4146
# total chars:  121
# under One God, saluting One American Flag. It is time to break with the bitter failures of the past, and to embrace a new
#
#
#
# Epoch 1/1
# 11847/11847 [==============================] - 42s 4ms/step - loss: 0.4142
# total chars:  123
# inside reality. MAKE AMERICA GREAT with TRUMP" My message, MAKE AMERICA GREAT AGAIN, is beginning to take hold. Bring back
#
#
#
# Epoch 1/1
# 11847/11847 [==============================] - 42s 4ms/step - loss: 0.4149
# total chars:  115
# So, now that you see that Hillary was a big mistake, change your vote to MAKE AMERICA GREAT AGAIN!" @videosigninc
#
#
#
# Epoch 1/1
# 11847/11847 [==============================] - 42s 4ms/step - loss: 0.4144
# total chars:  143
# Dr. Robert Jeffress will make the introduction. Make America Great Again! RT @williebosshog Make America Great Again! #Trump2016 Top searched
#
#
#
# Epoch 1/1
# 11847/11847 [==============================] - 42s 4ms/step - loss: 0.4138
# total chars:  81
# beat me on the economy and jobs. MAKE AMERICA GREAT AGAIN Thank you! WE will MAKE
#
#
#
# Epoch 1/1
# 11847/11847 [==============================] - 42s 4ms/step - loss: 0.4143
# total chars:  98
# LEADER to LEAD. Let s make America great again! VOTE TRUMP 2016"" @pnicastro1 @WayneNewtonMrLV
#
#
#
# Epoch 1/1
# 11847/11847 [==============================] - 42s 4ms/step - loss: 0.4137
# total chars:  138
# Pennsylvania! Together, we are going to MAKE AMERICA GREAT AGAIN! Join us #CARE REFORMS THAT! MAKE AMERICA GREAT AGAIN! New York, we will
#
#
#
# Epoch 1/1
# 11847/11847 [==============================] - 41s 3ms/step - loss: 0.4135
# total chars:  137
# Rules Committee by a vote of 87 12. MAKE AMERICA GREAT AGAIN! MAKE AMERICA GREAT AGAIN! MAKE AMERICA SAFE AGAIN! MAKE AMERICA GREAT AGAIN
#
#
#
# Epoch 1/1
# 11847/11847 [==============================] - 42s 4ms/step - loss: 0.4142
# total chars:  88
# African American vote once again. Together, we will have a government of, by and for the
#
#
#
# Epoch 1/1
# 11847/11847 [==============================] - 42s 4ms/step - loss: 0.4142
# total chars:  131
# days away from the change you ve been waiting for your entire life. Together, We Will Make America JUST Again. We Will Make America
#
#
#
# Epoch 1/1
# 11847/11847 [==============================] - 41s 3ms/step - loss: 0.4141
# total chars:  141
# make America great again. We re going to make America great again. This isn t about me; it s about all of you and our magnificent movement to
#
#
#
# Epoch 1/1
# 11847/11847 [==============================] - 41s 3ms/step - loss: 0.4115
# total chars:  140
# the people. We will make America wealthy again. We will make America strong again. We will make America safe again. And we will make America
#
#
#
# Epoch 1/1
# 11847/11847 [==============================] - 41s 3ms/step - loss: 0.4114
# total chars:  111
# thugs and paid protesters are proving the point of the millions of people who voted to MAKE AMERICA GREAT AGAIN
#
#
#
# Epoch 1/1
# 11847/11847 [==============================] - 42s 4ms/step - loss: 0.4113
# total chars:  46
# patriots in Arizona for border security! Build
#
#
#
# Epoch 1/1
# 11847/11847 [==============================] - 42s 4ms/step - loss: 0.4118
# total chars:  142
# SO NEED YOU, MR. TRUMP! Make America Great Again" We need strong, tough and brilliant leadership now more than ever! MAKE AMERICA GREAT AGAIN
#
#
#
# Epoch 1/1
# 11847/11847 [==============================] - 42s 4ms/step - loss: 0.4114
# total chars:  52
# strategy! U lose, he wins! #lets make America great
#
#
#
# Epoch 1/1
# 11847/11847 [==============================] - 42s 4ms/step - loss: 0.4121
# total chars:  140
# give tremendous praise for you this morning on @foxandfriends. Keep it up! Make America Great Again!" Don t ever forget, we will, together
#
#
#
# Epoch 1/1
# 11847/11847 [==============================] - 42s 4ms/step - loss: 0.4103
# total chars:  125
# decision on Paris Accord, Thursday at 3 00 P. M. The White House Rose Garden. MAKE AMERICA GREAT AGAIN! I will be interviewed
#
#
#
# Epoch 1/1
# 11847/11847 [==============================] - 42s 4ms/step - loss: 0.4107
# total chars:  76
# win and MAKE AMERICA GREAT AGAIN, maybe greater than ever before!" @tvegan
#
#
#
# Epoch 1/1
# 11847/11847 [==============================] - 42s 4ms/step - loss: 0.4124
# total chars:  125
# iamgavinjame To make America great again we must #THINKBIG understand that it s #TimeToGetTough on China! @realDonaldTrump
#
#
#
# Epoch 1/1
# 11847/11847 [==============================] - 42s 4ms/step - loss: 0.4100
# total chars:  119
# NCGOPcon when I said" People ask me why I may run for President I might so we can Make America Great Again! Our nation
#
#
#
# Epoch 1/1
# 11847/11847 [==============================] - 42s 4ms/step - loss: 0.4115
# total chars:  166
# make America great again. We re going to make America great again. This isn t about me; it s about all of you and our magnificent movement to make America great again
#
#
#
# Epoch 1/1
# 11847/11847 [==============================] - 42s 4ms/step - loss: 0.4113
# total chars:  106
# Governor @Mike_Pence! Lets MAKE AMERICA SAFE AND GREAT AGAIN with the spine of this country. I will fight
#
#
#
# Epoch 1/1
#  7552/11847 [==================>...........] - ETA: 15s - loss: 0.4063
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-27-c7d4578bcd71> in <module>()
#       1 for i in range (0,200):
#       2     print('\n\n')
# ----> 3     model4.fit(X_version_byalltext, y_version_byalltext, batch_size=BATCH_SIZE, verbose=1, nb_epoch=1)
#       4     nb_epoch += 1
#       5     output_as_sentence(generate_words(model4))
#
# /usr/local/lib/python2.7/dist-packages/keras/models.pyc in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#     958                               initial_epoch=initial_epoch,
#     959                               steps_per_epoch=steps_per_epoch,
# --> 960                               validation_steps=validation_steps)
#     961
#     962     def evaluate(self, x, y, batch_size=32, verbose=1,
#
# /usr/local/lib/python2.7/dist-packages/keras/engine/training.pyc in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1655                               initial_epoch=initial_epoch,
#    1656                               steps_per_epoch=steps_per_epoch,
# -> 1657                               validation_steps=validation_steps)
#    1658
#    1659     def evaluate(self, x=None, y=None,
#
# /usr/local/lib/python2.7/dist-packages/keras/engine/training.pyc in _fit_loop(self, f, ins, out_labels, batch_size, epochs, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps)
#    1211                     batch_logs['size'] = len(batch_ids)
#    1212                     callbacks.on_batch_begin(batch_index, batch_logs)
# -> 1213                     outs = f(ins_batch)
#    1214                     if not isinstance(outs, list):
#    1215                         outs = [outs]
#
# /usr/local/lib/python2.7/dist-packages/keras/backend/tensorflow_backend.pyc in __call__(self, inputs)
#    2355         session = get_session()
#    2356         updated = session.run(fetches=fetches, feed_dict=feed_dict,
# -> 2357                               **self.session_kwargs)
#    2358         return updated[:len(self.outputs)]
#    2359
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in run(self, fetches, feed_dict, options, run_metadata)
#     887     try:
#     888       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 889                          run_metadata_ptr)
#     890       if run_metadata:
#     891         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1118     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1119       results = self._do_run(handle, final_targets, final_fetches,
# -> 1120                              feed_dict_tensor, options, run_metadata)
#    1121     else:
#    1122       results = []
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1315     if handle is None:
#    1316       return self._do_call(_run_fn, self._session, feeds, fetches, targets,
# -> 1317                            options, run_metadata)
#    1318     else:
#    1319       return self._do_call(_prun_fn, self._session, handle, feeds, fetches)
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _do_call(self, fn, *args)
#    1321   def _do_call(self, fn, *args):
#    1322     try:
# -> 1323       return fn(*args)
#    1324     except errors.OpError as e:
#    1325       message = compat.as_text(e.message)
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1300           return tf_session.TF_Run(session, options,
#    1301                                    feed_dict, fetch_list, target_list,
# -> 1302                                    status, run_metadata)
#    1303
#    1304     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %% [markdown]
# ### Model 5
# Version 2 of training data , seq=3 (11484 training set)

# %%
BATCH_SIZE = 128
HIDDEN_DIM = 700
LAYER_NUM = 3 
nb_epoch = 0

model5 = create_model(HIDDEN_DIM, LAYER_NUM)

# %%
for i in range (0,200):
    print('\n\n')
    model5.fit(X_version_byalltext, y_version_byalltext, batch_size=BATCH_SIZE, verbose=1, nb_epoch=1)
    nb_epoch += 1
    output_as_sentence(generate_words(model5))
    if nb_epoch % 10 == 0:
        model5.save_weights('model5/checkpoint_{}_epoch_{}.hdf5'.format(HIDDEN_DIM, nb_epoch))
# Out:
# Epoch 1/1
# 11484/11484 [==============================] - 146s - loss: 2.2980
# total chars:  119
# WartburgCollege realDonaldTrump I am counting on your help is getting c has been equivocation. The poll 8 The Democrats
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 144s - loss: 2.1718
# total chars:  74
# whats on most of the past.......... The if The give give give now now this
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 145s - loss: 2.0542
# total chars:  79
# onto our military. You is BIG who TO TO forget is a simple is tomorrow now with
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 153s - loss: 1.9529
# total chars:  138
# He will make America great again We will be rushing working all big big big c growth, we will make America great again We can be big big c
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 146s - loss: 1.8564
# total chars:  93
# tas0727 @realDonaldTrump Make America Great Again!. America Great again.. Let's Make America
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 181s - loss: 1.7739
# total chars:  126
# donors and no action. Bush, Bush will be tough, BIG Jeb wages than crowds expected Again TIME!!!!!!!!!!!!!!!!!!!!!! @TMAC7771
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 186s - loss: 1.7009
# total chars:  143
# 2PM MST has been moved to your beautiful song have us staggering growth, by amazing more than ever political always believes growth at the show
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 184s - loss: 1.6334
# total chars:  61
# counts. @PianoBecca @realDonaldTrump Keep Again Again AGAIN
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 180s - loss: 1.5829
# total chars:  56
# bold new direction. Let's Make America Great again!...!!
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 181s - loss: 1.5360
# total chars:  140
# see today Trump your support so much in the house way MAKE AMERICA GREAT AGAIN! will will support efficient so talk talk MUST Bedminster all
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 193s - loss: 1.4937
# total chars:  82
# heroes. We will going going to make to killing. Together, MAKE AMERICA GREAT AGAIN
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 180s - loss: 1.4650
# total chars:  141
# 1 story of 2015. Imagine what our country we GREAT AGAIN!! Happy birthday. in of the the of and and America America America,,,,, we we, we we
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 180s - loss: 1.4336
# total chars:  132
# Crooked Hillary Clinton! I will work hard and and and and seek a new future FIRST Unbelievable been work us all us of by growth like
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 181s - loss: 1.4107
# total chars:  136
# She just said, Make America Great. We, Make....! AND GREAT GREAT GREAT GREAT GREAT GREAT GREAT GREAT GREAT GREAT GREAT GREAT GREAT GREAT
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 179s - loss: 1.3880
# total chars:  139
# kimguilfoyle @FoxNews he did one this c has much so much two you Mr. this One the Trump 37 much from much who a radical maybe AmericaFirst
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 181s - loss: 1.3702
# total chars:  142
# brilliant leadership now more than ever before! MAKE AMERICA GREAT GREAT... Sir business interesting interesting interesting interesting great
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 169s - loss: 1.3533
# total chars:  129
# SuperBowl and then we continue MAKE GREAT, will will will tragic again again deals gotta business great Carl total talk talk talk
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 145s - loss: 1.3381
# total chars:  109
# except for Paul Ryan! We will come rushing longer way for POTUS that MUST BIG at six who could quest to learn
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 144s - loss: 1.3283
# total chars:  142
# ALABAMA! 32, 000 supporters tonight are Clinton who want to make America great again deals in 2nd place in well despite the same to be. choose
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 144s - loss: 1.3159
# total chars:  99
# approximately 50 million for my Make America Great again!!!!!!! I now now the great America America
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 150s - loss: 1.3051
# total chars:  230
# let you down. Make America Great Great again..!!!!! Happy will wait Clinton the the new American just the the, and and,,,,,,,, we we we we we we we we we we we we we we we we we we we we we we we we and and and and and and and and
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 145s - loss: 1.2957
# total chars:  138
# EVERYONE! MAKE AMERICA GREAT AGAIN!..., BIG BIG BIG open. can make to be their more more from the an country of the you, and, we will MAKE
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 143s - loss: 1.2876
# total chars:  136
# BrianCraigShow @realDonaldTrump your country your the the American American,,, we we we we we!!!!!!!!!!!!!!! @trump2016 @the Poll and
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 143s - loss: 1.2787
# total chars:  139
# interesting leaders. America. America great honor business in business else in an Vegas from the Granite BIG tomorrow at the MorningsideEdu
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 143s - loss: 1.2703
# total chars:  48
# we are going to make America great again @@ the
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 144s - loss: 1.2651
# total chars:  97
# kevcirilli CEDAR RAPIDS TRUMP'S DAUGHT DAUGHT THAT will be admit 4 BIG Bush 000 Bush growth gotta
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 144s - loss: 1.2553
# total chars:  130
# believes that government should and the Trump by by the time, and we will MAKE will MAKE you MAKE!.. America loves order all an so
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 151s - loss: 1.2529
# total chars:  137
# leaders, Iran and that election, and embrace to make America great again. we we we we we we we we and and and and and and and and and and
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 144s - loss: 1.2475
# total chars:  55
# victory on November 8th. We America great, isn't boring
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 144s - loss: 1.2408
# total chars:  71
# stamina to MAKE AMERICA GREAT AGAIN! I and South master year order else
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 149s - loss: 1.2367
# total chars:  142
# BigLeagueTruth @Gsimmons03Ginny @realDonaldTrump.. She and and make AGAIN GREAT AND the outta the the Palm else else him can be to negotiate
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 144s - loss: 1.2333
# total chars:  67
# almost ZERO growth this quarter.. announcing business makes the BIG
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 144s - loss: 1.2294
# total chars:  52
# Kellyanne, you were that is a big big rally tonight!
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 144s - loss: 1.2256
# total chars:  88
# part of this nation, and for and we will We we... We are business great great deals, and
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 144s - loss: 1.2212
# total chars:  130
# sleepy, Jeb low energy. @@ the the the and and and and and and MAKE! MAKE WILL MAKE!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 144s - loss: 1.2158
# total chars:  122
# soon MAKE AMERICA GREAT AGAIN! Thank you for Huntington in order the conservation, and make America Make America great. We
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 144s - loss: 1.2141
# total chars:  139
# influence. Stay True! Great. We will make America great again. @@ great @leegreenwood83. He we Make Make this. @@!!!!!!!! Donate!!!!!! @
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 144s - loss: 1.2105
# total chars:  141
# Like Reagan, it's time to great!!! @be in @@ the, great again again trade trade trade,, and and and and we we we we we we we we we We We We
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 143s - loss: 1.2078
# total chars:  105
# Join us CHILD CARE REFORMS THAT has us restored for a government of the very much much WE can like Donald
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 144s - loss: 1.2060
# total chars:  142
# role, we must be in a big big rally in all of our house country! on on @MAKE AMERICA GREAT AGAIN!... away now can Mr to those those much much
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 148s - loss: 1.2037
# total chars:  119
# inclusive and prosperous American future. We will we will want don't want are want could want announcing woman believes
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 143s - loss: 1.1995
# total chars:  44
# ways of politicians must be put in Nashville
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 143s - loss: 1.1978
# total chars:  92
# New H vote today MAKE AMERICA GREAT! @@ @AmericaFirst Together, and and and and we will we
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 145s - loss: 1.1961
# total chars:  134
# more, we will make America great again! @@ and and and make America great again. We will make America great,, he, ever was was Donald
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 145s - loss: 1.1945
# total chars:  144
# Policy Polling PPP national result will be West at this job in the, and and to will will will we we will MAKE MAKE MAKE MAKE MAKE MAKE MAKE MAKE
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 144s - loss: 1.1919
# total chars:  126
# Morning America at solutions. MAKE are MAKE will will will MAKE MAKE saving specialists specialists after open again use again
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 143s - loss: 1.1899
# total chars:  72
# certified as a Trump is us all all talk by much good woman that a a a me
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 148s - loss: 1.1894
# total chars:  56
# materializes! He will make will going MAKE will MAKE and
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 144s - loss: 1.1866
# total chars:  144
# Made all of my nation and I will be forget MAKE will MAKE make America lose AMERICA GREAT again! @@ @@ @@ @@ @@ @@ @@ @@ @@ @@ @@ the
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 144s - loss: 1.1835
# total chars:  141
# into the spine of this country of all all all all all before!, I've YOU Build doing greater doing america, and! @@ @@ @@ @@ @@ will will
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 147s - loss: 1.1827
# total chars:  78
# spine of this country and Make America will will will want with with with with
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 146s - loss: 1.1804
# total chars:  135
# bdean1468 @realDonaldTrump @realDonaldTrump @time and we will we MAKE We MAKE MAKE MAKE MAKE MAKE MAKE MAKE MAKE MAKE MAKE MAKE cast
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 144s - loss: 1.1763
# total chars:  142
# Melania is joining me on saving help and VoteTrumpPence16 Accord by patriots patriots @@ @@ again. @@ @@ @@ We We We we we we we we we we
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 143s - loss: 1.1760
# total chars:  96
# border security! Let's Make America.... we worst MAKE MAKE, MAKE 30PM new one new poll poll poll
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 143s - loss: 1.1758
# total chars:  75
# Bernardino if we had in San factories is from polls good the an big all all
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 143s - loss: 1.1737
# total chars:  122
# center. WE WILL MAKE AMERICA WILL let AMERICA 4 TRUMP the @crowds @@ @@ @and and and and for and I I I I I I I I I I I
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 144s - loss: 1.1722
# total chars:  87
# June 25th back to the in the the MAKE all the past, but those a much good news in a the
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 144s - loss: 1.1711
# total chars:  138
# plan is the only way VOTE vote have have want have have have have have have have have a a a much a much a a much a a good a good Iowa Iowa
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 144s - loss: 1.1680
# total chars:  99
# Social Security Making America Great Again! is be MAKE AMERICA and, and we and we we we we we we we
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 143s - loss: 1.1666
# total chars:  142
# Pols don't get it your night a talk our education more to wish was maybe more from a talk simplifying a failed keep keep keep keep bring bring
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 147s - loss: 1.1656
# total chars:  141
# president we need your make to our our our our our our our our us an much more more more more away into November You with with with with with
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 144s - loss: 1.1639
# total chars:  140
# red make America or really big over a much a good good good good a all a all very talk a a a good good good good business good business good
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 143s - loss: 1.1624
# total chars:  60
# close enough. Make America. will MAKE MAKE Thanksgiving MAKE
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 144s - loss: 1.1613
# total chars:  140
# inner cities, and incompetent great, changing and for this that will make ever,,,,,,,,,,,,,,,,,, FINALLY,, will will make America great,,,,,
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 144s - loss: 1.1605
# total chars:  73
# however, if we make America great int @the again. many again..!!!!!! I I
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 144s - loss: 1.1583
# total chars:  140
# don't want to get to the White MAKE to Make AMERICA GREAT AGAIN GREAT GREAT GREAT GREAT must.. over giving to of so great so great good good
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 144s - loss: 1.1568
# total chars:  142
# leading big in all of the We will win 4 a government on from the New country............ You can were a a c a a c exciting as exciting as over
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 144s - loss: 1.1572
# total chars:  143
# blonde hair. I said as NO STRENGTH away Donald a great the great great in in,,,,,, Let's,!!!!!! #@ @@ @@ @@ @@ @# ## #@ @@ @@ @@ @@
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 144s - loss: 1.1531
# total chars:  145
# years of Life U are the inside, for Chicago. #MAKE you MAKE! MAKE we we we we we I will will will Make Make Make Make America great Trump. Trump
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 146s - loss: 1.1527
# total chars:  130
# donors and special interests. We will win have win fix as an much a much much much much much much much much much much much Sam Sam
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 148s - loss: 1.1514
# total chars:  96
# courage and selflessness of our personally who for this you me a a a back to back back such such
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 144s - loss: 1.1512
# total chars:  124
# children safe which includes steadfast support a of great in great debate BIG again schools that Sam guy with with with with
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 144s - loss: 1.1486
# total chars:  134
# True! @angiecallahan4 @realDonaldTrump We we Make we will Make Make great great great again again and make America great again! WILL
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 144s - loss: 1.1487
# total chars:  67
# Polling PPP national result is the my We Make Make America Mr to to
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 144s - loss: 1.1475
# total chars:  112
# Saturday is BIG, BIG! Get is we will MAKE We Great Again We, you,,, we we we we we we we we we we we we we we we
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 144s - loss: 1.1452
# total chars:  141
# Addressing record crowd @MAKE MAKE are GREAT GREAT GREAT GREAT GREAT AGAIN @@ for, to, I is I!! I! We I @@ @@ @@ @@ We we We We America
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 143s - loss: 1.1428
# total chars:  137
# off the football for 15, put J the realDonaldTrump! @@ @@ @AmericaFirst @AmericaFirst We @@ @@ and we and we and we and we we we we
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 143s - loss: 1.1426
# total chars:  119
# Bush and Rubio couldn't answer not being a back all all much much c much much an much much all all all all talk all all
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 143s - loss: 1.1404
# total chars:  138
# ch in the White House and special. will will want to Make to our Trump to to to to to will will will will will will MAKE will MAKE! I MAKE
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 144s - loss: 1.1405
# total chars:  107
# equivocation, my father will make are country We MAKE to Sioux the the the the,,.. We! @@ @@ AmericaFirst
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 147s - loss: 1.1385
# total chars:  130
# But to play that role, we to Make we MAKE will MAKE,. It. Great again He's the this this the the the @@ @@ @@ @@ @@ @@ @@ @
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 143s - loss: 1.1379
# total chars:  140
# am counting on your your movement a a rally in your a!!!!! Get!!!!!!! ## ## ## ## ## ## ## #We We We @@ @@ @@ @I I MAKE you MAKE
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 144s - loss: 1.1382
# total chars:  132
# for the people. We will make America strong again over our next President a a much a much much schools much a greater Sam the YOU!!!
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 144s - loss: 1.1354
# total chars:  106
# michell33841372 Donald keep speaking the country all of the New the! the the the the the government you!!!
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 143s - loss: 1.1337
# total chars:  139
# lee_richter TRUMP will make to going so Donald for? today your the the the the the new me me me me me me out out out out a a with with with
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 143s - loss: 1.1346
# total chars:  139
# Tough making America great again WILL is and and I will is!!!!! ## @@ @I AmericaFirst @AmericaFirst @AmericaFirst @AmericaFirst Trump
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 144s - loss: 1.1334
# total chars:  146
# care for our vets not because with 00pmE! We We We We We We We We We We We We We We We We We We We MAKE MAKE MAKE will will will will we MAKE MAKE
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 144s - loss: 1.1329
# total chars:  140
# ccorreia401 @realDonaldTrump @am out we are came Melania MAKE! MAKE MAKE We We We We We We We We We We We We We We We We We We We We We We
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 143s - loss: 1.1292
# total chars:  140
# point lead over 2nd place.... It MUST MAKE MAKE None Dr Government It It Lets Lets Record We We We We We We We We We We We State State State
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 143s - loss: 1.1309
# total chars:  152
# before! @tvegan DonaldTrump your immigration @out We We the vote VOTE VoteTrump AmericaFirst @realDonaldTrump @FoxNews P @@ @@ @@ @DrainTheSwamp
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 147s - loss: 1.1287
# total chars:  145
# however, if we make America America and One American this One jobs us back MAKE GREAT MAKE MAKE MAKE MAKE MAKE MAKE MAKE MAKE MAKE MAKE MAKE MAKE
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 143s - loss: 1.1290
# total chars:  140
# Republican Leadership Summit on Saturday is saving 8th by @# The We We we @One @@ AmericaFirst We We We MAKE are MAKE MAKE will MAKE MAKE
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 144s - loss: 1.1252
# total chars:  144
# whole deal and MAKE AMERICA GREAT MAKE will MAKE MAKE MAKE great great.. great great great great America America America America America America
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 146s - loss: 1.1258
# total chars:  141
# Vegas for a packed house speech on crowd Together MAKE. GREAT AGAIN GREAT.................. will be be make impact make make make make change
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 143s - loss: 1.1257
# total chars:  97
# Kids. Thank you, and want you! @@ @@ @I I I I I vote vote out VOTE out time going One back all
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 144s - loss: 1.1232
# total chars:  135
# you've ever cast for anyone at my 4TH 00pmE @for Together AmericaFirst Together MAKE MAKE MAKE MAKE MAKE MAKE MAKE MAKE MAKE MAKE MAKE
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 144s - loss: 1.1203
# total chars:  141
# MAGA........ to Make to Make our education our education education education together lead lead lead together together together together lose
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 143s - loss: 1.1230
# total chars:  135
# changing our future. We will MAKE MAKE MAKE MAKE.. @@ @@ @@ @@ @@ MAKE MAKE MAKE MAKE MAKE MAKE MAKE MAKE MAKE MAKE MAKE MAKE MAKE
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 144s - loss: 1.1202
# total chars:  97
# U. S. A. Make for for you MAKE Together Together MAKE MAKE I MAKE I MAKE MAKE MAKE MAKE MAKE MAKE
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 144s - loss: 1.1208
# total chars:  137
# reality. MAKE AMERICA GREAT GREAT GREAT GREAT AND GREAT.. @# ## ## MAKE #MAKE I MAKE MAKE MAKE I I MAKE MAKE MAKE MAKE MAKE MAKE MAKE
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 191s - loss: 1.1178
# total chars:  144
# Stop Crooked Hillary Clinton! #MAKE! #@ @I I I I out out out One One One One One One One One One One One One One One crowd One crowd One time
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 180s - loss: 1.1178
# total chars:  139
# Indiana to make an economy we will make by, I will with @@ @@ @@ @AmericaFirst @AmericaFirst @@ @@ @@ @@ @@ @@ @@ @@ @the one
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 181s - loss: 1.1172
# total chars:  131
# none are close enough. MAKE you MAKE MAKE MAKE MAKE MAKE. MAKE AGAIN Thank Thank Government With @momentum @@ @@ @@ @@ @@ @@
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 179s - loss: 1.1165
# total chars:  128
# big day for America. It is time to @immigration I VOTE VOTE VOTE VOTE VOTE VOTE VOTE TRUMP ## ## ## ## ## #MAKE #I I I I
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 179s - loss: 1.1157
# total chars:  48
# games, we must Help America your for and country
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 180s - loss: 1.1139
# total chars:  142
# interests. We are going to make America and #@ Trump2016 @@ @Trump2016 @@ @@ AmericaFirst @AmericaFirst @DrainTheSwamp @AmericaFirst @
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 180s - loss: 1.1133
# total chars:  143
# Something big is happening. Will to as neglected intro #@ We I We We I AmericaFirst I AmericaFirst DrainTheSwamp out @@ @@ @@ @Trump Trump
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 181s - loss: 1.1117
# total chars:  62
# been so great. Let's Make America great will be great great DC
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 179s - loss: 1.1122
# total chars:  226
# RNCinCLE I'm with you! We will going and MAKE AMERICA your to for a out out out out ##! TRUMP with with 15 and for you and MAKE to make America take to time to change? a a been a the the the the MAKE to MAKE to MAKE will MAKE
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 180s - loss: 1.1097
# total chars:  142
# tr3s3can @realDonaldTrump @realDonaldTrump time the make make make make Make Make Make Make Make Make to to will will will will will,,, MAKE
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 191s - loss: 1.1098
# total chars:  58
# rwildewrites Donald Trump I will make America Make America
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 181s - loss: 1.1085
# total chars:  110
# sacrifices to make america Let's make. solutions!!! Thank! We will we we we we we we we we we we we we and and
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 157s - loss: 1.1087
# total chars:  80
# location. We are going!! with @AmericaFirst ## VOTE #AmericaFirst @@ @@ you
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 163s - loss: 1.1071
# total chars:  96
# creator. None of the krystalball and! Fantastic CNN Together @VoteTrump @@ AmericaFirst Thank!
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 191s - loss: 1.1084
# total chars:  143
# The White House Rose Garden. MAKE AMERICA GREAT AND AND AND AND AND.......................... Let's. Let's Let's Let's It Government Government
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 190s - loss: 1.1057
# total chars:  129
# Freedomr @OANN Trump is the country numbers, have want want to to to MAKE MAKE MAKE MAKE MAKE MAKE MAKE MAKE MAKE MAKE MAKE MAKE
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 179s - loss: 1.1063
# total chars:  109
# TheLeeGreenwood. You and borders #one million @VoteTrumpPence16 cast out TRUMP TRUMP TRUMP cast TRUMP TRUMP
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 181s - loss: 1.1036
# total chars:  121
# radical political agendas. It will Together Together Together @@ @@ @@ @@ @@ @@ @@ @@ AmericaFirst @AmericaFirst
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 179s - loss: 1.1047
# total chars:  49
# four MAKE AMERICA GREAT AGAIN!! Dr. @@ @@ @# #
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 180s - loss: 1.1051
# total chars:  143
# It's time for an outsider ENDORSE TRUMP TRUMP with time for for!!!!!,!, Thank Thank Thank Thank Thank Thank Thank GREAT GREAT GREAT GREAT GREAT
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 192s - loss: 1.1018
# total chars:  113
# protesters are proving the country and for we will will will want for!!!!! MAKE will MAKE! MAKE! MAKE! MAKE! MAKE
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 179s - loss: 1.1046
# total chars:  86
# Tulsa and Charlotte are tragic to MAKE will MAKE will MAKE. MAKE. Let's. Let's........
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 180s - loss: 1.1017
# total chars:  107
# border security! Build a wall! MAKE I VOTE VOTE TRUMP J TRUMP J J J @@ @@ @@ out @out MAKE One One time
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 179s - loss: 1.1009
# total chars:  164
# PEOPLE! Many speeches, jobs, we will MAKE America Let's Trump out out out out out out out out out me out out out out out out out out out out out out out out out out
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 183s - loss: 1.1003
# total chars:  150
# business. Your children will carry that our to make to do our the the the the the the the us us us all all hold make lose make make together lose lose
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 179s - loss: 1.0989
# total chars:  113
# Life U are the American and! MAKE GREAT GREAT AND MAKE! MAKE! MAKE AND MAKE AND Let's GREAT Let's Let's MAKE AND!
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 181s - loss: 1.0984
# total chars:  46
# Just arrived in Indianapolis, closely for have
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 178s - loss: 1.0983
# total chars:  146
# outsider to clean up after Clinton a return for giving!!! MAKE! I TRUMP TRUMP TRUMP TRUMP TRUMP TRUMP TRUMP VOTE VOTE ## ## ## on #MAKE #MAKE
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 180s - loss: 1.0974
# total chars:  140
# helm. Confidence counts. @Hillary is MAKE!! TRUMP #J J #@ MAKE!!!!!!!!!!!!!!!!!!! MAKE MAKE!!!!!!!!!!!!!!!!!!!!!!! Let's MAKE Let's Let's
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 181s - loss: 1.0964
# total chars:  136
# Will Make America Safe again. Great. Let's. MAKE. Keep @J #MAKE MAKE MAKE MAKE MAKE MAKE MAKE be GREAT GREAT GREAT AND Let's AND Let's
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 199s - loss: 1.0968
# total chars:  141
# realOllieTaylor @realDonaldTrump @realDonaldTrump Rubio vote the #out got on #want to want to to to to to to to was was was a a a a a a a
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 181s - loss: 1.0971
# total chars:  143
# reality. MAKE AMERICA GREAT GREAT MAKE GREAT. Thank. It @@ @@ @@ @@ @@ @@ @@ @@ @@ @@ @@ @@ @@ @@ @@ @@ @@ @@ @MAKE. We will
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 179s - loss: 1.0962
# total chars:  134
# close enough. Make. We MAKE MAKE MAKE. MAKE are get for the your the a the in in in the the you you the the people, the to, in the new
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 183s - loss: 1.0968
# total chars:  138
# WilliamPetroski Trump I can make to make, GREAT! @@ I AmericaFirst MAKE @MAKE @@ @@ @@ just just all realDonaldTrump all need in need
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 179s - loss: 1.0943
# total chars:  113
# Middle School! Thanks to their us us us us a Sam Sam a a a more in a in in good in mandated was was was want want
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 182s - loss: 1.0932
# total chars:  143
# CARE REFORMS THAT WILL MAKE can morning by the @her #We I VOTE on on on MAKE MAKE MAKE MAKE MAKE MAKE MAKE MAKE MAKE MAKE MAKE MAKE MAKE MAKE
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 179s - loss: 1.0930
# total chars:  102
# Palm Beach, Florida,, the We YOU on I MAKE MAKE MAKE MAKE MAKE MAKE MAKE MAKE MAKE MAKE MAKE MAKE MAKE
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 181s - loss: 1.0930
# total chars:  109
# simplifying the tax code, Make great Let's One 8 @AmericaFirst We We Jobs #@ @@ @@ @@ MAKE #MAKE #MAKE
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 180s - loss: 1.0930
# total chars:  139
# get to the White, all of the Trump, MAKE AMERICA GREAT AGAIN! Build the @@ @@ @@ @@ @@ @I I I I @you and MAKE for to to Make America
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 181s - loss: 1.0912
# total chars:  82
# remember that we will MAKE AMERICA MAKE. GREAT GREAT MAKE MAKE MAKE MAKE MAKE MAKE
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 179s - loss: 1.0908
# total chars:  33
# AndyBran @realDonaldTrump @died
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 147s - loss: 1.0902
# total chars:  78
# honor and a privilege to be the 10 country! for the MAKE to MAKE MAKE... GREAT
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 144s - loss: 1.0897
# total chars:  127
# begin a conversation on MAKE you!!!!!!!!!!! @@ Together. The.... MAKE, MAKE MAKE, to to to to to to to to to to to to to to to
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 144s - loss: 1.0906
# total chars:  141
# Such incredible spirit. We MAKE will MAKE! MAKE GREAT!!! #! Thanks! #VOTE ## ## ## MAKE! WE WE WE WE WE!!! Thank! WE! WE WILL WE!..... We
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 145s - loss: 1.0896
# total chars:  140
# deliver. Let's Make America Great. Record. many many many your One One One the the VOTE VOTE VOTE VOTE VOTE VOTE VOTE VOTE VOTE Great #MAKE
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 146s - loss: 1.0885
# total chars:  115
# looking forward to being in the MAKE for!!! MAKE!!!!!!!!!!!!! MAKE. MAKE. MAKE. MAKE. MAKE. MAKE first Great.......
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 145s - loss: 1.0889
# total chars:  119
# 37 years of Life U to the @@ VOTE! MAKE MAKE MAKE MAKE MAKE MAKE MAKE MAKE for for for for out out out ## ## ## ##
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 146s - loss: 1.0897
# total chars:  121
# Schedule tickets @Stevekwebb @in not watch before! GREAT GREAT!........... MAKE MAKE MAKE MAKE MAKE MAKE MAKE MAKE MAKE
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 145s - loss: 1.0876
# total chars:  135
# minutes, Make America Great Again We MAKE again Let's Make we we We we!! @@ @@ @@ @@ @@ @@ @@ @MAKE @@ @MAKE MAKE @MAKE MAKE
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 146s - loss: 1.0896
# total chars:  141
# Public Policy Polling PPP earliest We. We. Together. We. @@ @@ @@ @@ greta @@ @@ and MAKE MAKE to #Make America Great. We. We we We We
# Epoch 1/1
# 11484/11484 [==============================] - 156s - loss: 1.0876
# total chars:  141
# Wow, @CNN is a MAKE to GREAT AGAIN GREAT AGAIN! Jobs @Let's ## ## #I I I I I I I I I I I I @and and and,,,,,,,,,,,,,,,,,,,,,,,,,, We We
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 145s - loss: 1.0861
# total chars:  143
# few days. MAKE AMERICA GREAT AGAIN! Together @Thanks @@ @# VOTE VOTE VOTE VOTE VOTE ## ## ## ## @the the #the ## out back out out out
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 144s - loss: 1.0843
# total chars:  82
# Since the first day I MAKE AMERICA GREAT AGAIN! Let's and we @# ## ## ## @@ @
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 146s - loss: 1.0865
# total chars:  81
# Committee by a vote want is getting out MODERN just just out just for to to to to
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 144s - loss: 1.0855
# total chars:  295
# IF anyone in the economy to will have make will MAKE! MAKE will MAKE! MAKE! Together Together Together Together Together @@ @Hillary Hillary Hillary Hillary Hillary TRUMP Hillary TRUMP TRUMP TRUMP TRUMP Hillary TRUMP TRUMP TRUMP TRUMP TRUMP VOTE VOTE VOTE Hillary TRUMP TRUMP TRUMP TRUMP TRUMP
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 145s - loss: 1.0880
# total chars:  129
# GREAT AGAIN! #Trump2016 #AmericaFirst @@ MAKE to MAKE AMERICA GREAT AGAIN! @the @meetings VOTE VOTE VOTE VOTE VOTE VOTE VOTE
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 146s - loss: 1.0841
# total chars:  134
# Doctor_Platek Come June July, @# MAKE I ## ## MAKE I vote to out ## #@ @@ @and I DonaldTrump #to to to MAKE will MAKE Together
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 145s - loss: 1.0850
# total chars:  81
# kids to Make America Great. Together @Together @@ @@ @@ @@ @@ @@ @@ @@ @
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 145s - loss: 1.0829
# total chars:  138
# announcing my decision on the Flag and with #TRUMP #MAKE ## ## #MAKE MAKE MAKE MAKE MAKE MAKE MAKE to MAKE MAKE! MAKE! MAKE MAKE MAKE
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 144s - loss: 1.0831
# total chars:  85
# run for President Make America Make, one crowds one @@ on @I I I I I MAKE MAKE MAKE
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 155s - loss: 1.0851
# total chars:  95
# KellyannePolls Kellyanne, you and that Trump printed Trump fantastic great great master big me,
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 146s - loss: 1.0817
# total chars:  140
# Crooked Hillary Clinton! We will MAKE! Fantastic @glamourizes ## ## #AmericaFirst #TRUMP #TRUMP #@ @@ MAKE! #@ #@ @@ @@ @@ @@!
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 144s - loss: 1.0813
# total chars:  135
# illegal immigration and protect the people, in MAKE to MAKE AMERICA to to Make the the the the the the the the the the MAKE MAKE to our
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 144s - loss: 1.0823
# total chars:  120
# MST has been moved to @and and MAKE MAKE MAKE MAKE MAKE MAKE for vote for vote TO forget TO for,, 8 8 8 tonight tonight
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 145s - loss: 1.0787
# total chars:  102
# once again have a government of the on @! Unbelievable sport... in in, to to to to make to make to, to
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 146s - loss: 1.0828
# total chars:  131
# along with @realDonaldTrump Courageous realDonaldTrump of spirit of spirit of of American spirit speeches American spirit speeches
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 144s - loss: 1.0810
# total chars:  87
# corrupt establishment knows that it's to to a future big big,,,,,,,,,,,,,, like to this
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 145s - loss: 1.0839
# total chars:  143
# Good Morning America at Keep you make we we I VOTE on!!!!!!!!! ## ## ## ## ## ## ## ## #MAKE for @@ @# #MAKE to #@ @# ## out out
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 145s - loss: 1.0817
# total chars:  138
# Maybe you don't feel good We growth for for you will MAKE will MAKE GREAT! Let's! Donate ## ## ## ## ## ## ## ## ## ## ## ## #
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 146s - loss: 1.0810
# total chars:  140
# PATRIOTS ALLOWED!! VOTE with the the the the in the MAKE! MAKE MAKE MAKE in MAKE in in! in! in!!!!!!!!! MAKE!! in!!! I MAKE in D in!!! in in
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 157s - loss: 1.0798
# total chars:  107
# both speeches. Something big I have, I @@ @@,, @,,,,,,,,,,,, in in of of of of good all of of all all all
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 144s - loss: 1.0808
# total chars:  127
# Medicaid are wrong. on a @@ VOTE #@ @@ TRUMP @@ @@ @@ @@ @@. MAKE MAKE MAKE to to GREAT. American 5PM @@ @@ @@ @@ @
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 145s - loss: 1.0799
# total chars:  140
# voice and I will will I MAKE you MAKE MAKE to @to Bedminster I in I back the great, this we we we I I I I I I I I I I I for for for for for
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 146s - loss: 1.0779
# total chars:  112
# likes to say we're is never is never November put no our our the the the.. the the the the the the across across
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 144s - loss: 1.0778
# total chars:  131
# Nobody can beat me on the the U in in in in in in a a a a a a a a a a a I I I a,,, a I a a, a, a, all,,,,,,, I I I I I I I I I good
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 145s - loss: 1.0771
# total chars:  135
# For all of my points. MAKE to MAKE AMERICA GREAT AGAIN! Together. We We @@ @@ @meetings #AmericaFirst ## @@ @@ @@ @@ @@ @@ @
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 145s - loss: 1.0821
# total chars:  81
# Public Policy Polling PPP rally one new, are to Make America Great Great highest.
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 146s - loss: 1.0772
# total chars:  143
# P. M. We will make America Pols. Let's our I!! ## #@ @@ @@ @@ MAKE to to in to to to to to MAKE to MAKE to GREAT. We Trump @@ @@ @@ @@
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 144s - loss: 1.0773
# total chars:  125
# DonaldTrump will cut through the Vermont, overseas, @, quote, the the ## MAKE to to our country our the the country us a the
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 145s - loss: 1.0764
# total chars:  129
# But never, ever forget, we will MAKE.,, our great the great the the our our back our our our our our our make make make make make
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 158s - loss: 1.0749
# total chars:  139
# own rally. It is the country, across the the,,,.... @@ @@ @@ @@ @@ @@ @@ @@ @@ @@ @@ @@ @@ @@ @@ @@ @@ and @and @@ @@ @
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 146s - loss: 1.0763
# total chars:  91
# his empire! WE WILL MAKE. Let's, @@ @@ @@ @VoteTrump on on on I I I! for for!!!!!!!! in
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 145s - loss: 1.0752
# total chars:  122
# totally unhinged Tom Steyer,! bad Doral the the the 20 the the the to talk to to to to to to to to the the the the the the
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 145s - loss: 1.0759
# total chars:  133
# Lincoln and, come time with for new in in future in very one all very accurate to to serve to you you you you to to it it it it to it
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 145s - loss: 1.0758
# total chars:  140
# phony Democrat excuse for a the the MAKE for the,, for,!!!!! MAKE! MAKE. MAKE. MAKE. I @@ @@ @@ @@ @@ @@ @@ @@ @@ @@,,, The @,,,,,
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 147s - loss: 1.0750
# total chars:  44
# What do you have MR who the MAKE to @to!!!!
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 186s - loss: 1.0738
# total chars:  116
# successful as his empire!! NEED!!! I!!!!!!!!!!!!!!!! @@ @@ @@ @@ @@ @@,, DAUGHT off in all back back back back
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 194s - loss: 1.0756
# total chars:  140
# AB1132 @realDonaldTrump it's all all of all great of great of way politicians way amazing very important very hard very hard talk talk talk
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 180s - loss: 1.0730
# total chars:  136
# send someone from the outside to vote for you!!!!! I I for you! I!!!!!!!! and and,,,, @MAKE in for in in for in in in in in in?? you by
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 180s - loss: 1.0723
# total chars:  144
# IVANKA I can just vote members in November in the in one in all of of important important talk important talk talk talk important talk important
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 194s - loss: 1.0731
# total chars:  122
# Stevekwebb @realDonaldTrump Love it Donald a an from a an amazing you an job can talk an an make make make make make make
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 180s - loss: 1.0730
# total chars:  128
# poorer in many cases. #family crowds keep words respect been ever words a and,, members feared everybody everybody everybody by
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 180s - loss: 1.0739
# total chars:  143
# rise, and new American new, one only one spine POTUS Americans back back the back the back us us country to on on on on on!!!!!!!!!!!!!!!!!!!!!
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 181s - loss: 1.0748
# total chars:  139
# Like Reagan, it's great,, we we we we we we we we we we we we we we we we we we we we we we we we we we we we we we we we we we we we we we
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 181s - loss: 1.0719
# total chars:  27
# feared by our enemies. MAKE
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 181s - loss: 1.0722
# total chars:  119
# started working together as One People, massive national and will MAKE MAKE! MAKE you MAKE! MAKE! @@ @@ @glamourizes
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 181s - loss: 1.0707
# total chars:  57
# negative into a positive approximately the to our all the
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 180s - loss: 1.0705
# total chars:  140
# havn't even focused on running the crowd!!!!!!!!!!!!!!!! @@ @@ @@ @@ @and SITES the the the the the the the the the the the the the the
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 181s - loss: 1.0705
# total chars:  64
# play that role, we a the the all the the the the the all all all
#
#
#
# Epoch 1/1
# 11484/11484 [==============================] - 184s - loss: 1.0709
# total chars:  131
# OF JULY TO EVERYONE! MAKE. Build with you! @@ @and I and MAKE you the the the the the a in to to to to to to to to to to to to in

# %% [markdown]
# ### Model 6
# Version 2 of training data , seq=8 (11484 training set)

# %%
BATCH_SIZE = 128
HIDDEN_DIM = 700
LAYER_NUM = 3 
nb_epoch = 0

model6 = create_model(HIDDEN_DIM, LAYER_NUM)

# %%
for i in range (0,200):
    print('\n\n')
    model6.fit(X_version_byalltext, y_version_byalltext, batch_size=BATCH_SIZE, verbose=1, nb_epoch=1)
    nb_epoch += 1
    output_as_sentence(generate_words(model6))
    if nb_epoch % 10 == 0:
        model6.save_weights('model6/checkpoint_{}_epoch_{}.hdf5'.format(HIDDEN_DIM, nb_epoch))
# Out:
# /usr/local/lib/python2.7/dist-packages/keras/models.py:939: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
#   warnings.warn('The `nb_epoch` argument in `fit` '
# Epoch 1/1
# 11479/11479 [==============================] - 37s 3ms/step - loss: 5.6993
# total chars:  139
# Bangor.....................................................................................................................................
#
#
#
# Epoch 1/1
# 11479/11479 [==============================] - 32s 3ms/step - loss: 4.6854
# total chars:  141
# PianoBecca. MAKE AMERICA GREAT AGAIN! #Trump2016 @realDonaldTrump @realDonaldTrump @realDonaldTrump @realDonaldTrump @realDonaldTrump @
#
#
#
# Epoch 1/1
# 11479/11479 [==============================] - 30s 3ms/step - loss: 3.8652
# total chars:  119
# child, the country, the country, Imagine the country of the country, the country, the country, the country, the country
#
#
#
# Epoch 1/1
# 11479/11479 [==============================] - 30s 3ms/step - loss: 3.2813
# total chars:  155
# WAKE realDonaldTrump. Let's Make America Great Again! @Knight276 @realDonaldTrump @realDonaldTrump @realDonaldTrump @realDonaldTrump @realDonaldTrump
#
#
#
# Epoch 1/1
# 11479/11479 [==============================] - 30s 3ms/step - loss: 2.7797
# total chars:  139
# ThePlumLineGS Make America Great Again! @williamgardanis @realDonaldTrump IF believe in the next words begins. We will make America great
#
#
#
# Epoch 1/1
# 11479/11479 [==============================] - 30s 3ms/step - loss: 2.3287
# total chars:  146
# happen! @FoxNews int. on simplifying the tax code, our U. S. A. MAKE AMERICA GREAT AGAIN! MAKE AMERICA GREAT AGAIN! #AmericaFirst #AmericaFirst
#
#
#
# Epoch 1/1
# 11479/11479 [==============================] - 30s 3ms/step - loss: 1.9522
# total chars:  96
# God and embrace embrace together to make America great again. Thank you, and Bless! We are going
#
#
#
# Epoch 1/1
# 11479/11479 [==============================] - 30s 3ms/step - loss: 1.6378
# total chars:  138
# legacy. MAKE AMERICA GREAT AGAIN! #TrumpPence16 Together, we will MAKE AMERICA SAFE AND GREAT AGAIN! #ImWithYou #AmericaFirst Together,
#
#
#
# Epoch 1/1
# 11479/11479 [==============================] - 30s 3ms/step - loss: 1.3940
# total chars:  126
# neighborhood realDonaldTrump AMERICA How to Make America Great Again. The White House will become the People's House. American
#
#
#
# Epoch 1/1
# 11479/11479 [==============================] - 30s 3ms/step - loss: 1.2122
# total chars:  150
# destruction and I will fight to bring us all together as One American People. Imagine what our country could accomplish if we started working together
#
#
#
# Epoch 1/1
# 11479/11479 [==============================] - 30s 3ms/step - loss: 1.0825
# total chars:  142
# HAS debate except but put me folks also energy for our worse almost ZERO growth this quarter. Nobody can beat me on the economy and jobs. MAKE
#
#
#
# Epoch 1/1
# 11479/11479 [==============================] - 30s 3ms/step - loss: 0.9825
# total chars:  139
# technology, new innovation, and new solutions. It will be a future of conservation, of prosperity, and of great success. It will be a great
#
#
#
# Epoch 1/1
# 11479/11479 [==============================] - 30s 3ms/step - loss: 0.9075
# total chars:  120
# take the first step in the process of making America great again! Thanks you for all of the Trump Rallies today. Amazing
#
#
#
# Epoch 1/1
# 11479/11479 [==============================] - 30s 3ms/step - loss: 0.8533
# total chars:  139
# Reedgs119 @realdonaldtrump @cleopattrausa Donald you are the next Ronald Reagan. Make America great again. @about_life @realDonaldTrump
#
#
#
# Epoch 1/1
# 11479/11479 [==============================] - 30s 3ms/step - loss: 0.8058
# total chars:  143
# BigLeagueTruth @Gsimmons03Ginny @realDonaldTrump.. Kaine is awful, Trump and Pence are the ticket.. no more lies, we are ready to see America
#
#
#
# Epoch 1/1
# 11479/11479 [==============================] - 30s 3ms/step - loss: 0.7705
# total chars:  138
# Once again, we are going to have a government of, by and for the people. We Will Make America Great Again. Thank you, we will make America
#
#
#
# Epoch 1/1
# 11479/11479 [==============================] - 30s 3ms/step - loss: 0.7396
# total chars:  140
# security. It is common sense. We must build a wall! Let's Make America Great Again! I am counting on your help to defeat Hillary Clinton and
#
#
#
# Epoch 1/1
# 11479/11479 [==============================] - 30s 3ms/step - loss: 0.7131
# total chars:  138
# podium speaker is for Trump! VAST MAJORITY want Make America Great Again! We are going to make our country so strong again, so great again
#
#
#
# Epoch 1/1
# 11479/11479 [==============================] - 30s 3ms/step - loss: 0.6919
# total chars:  152
# MEMEoryHead by Americans and her cronies. Let's Make America Great Again! We is no President back. it. Let's Make America Great Again! @williamgardanis
#
#
#
# Epoch 1/1
# 11479/11479 [==============================] - 30s 3ms/step - loss: 0.6742
# total chars:  135
# exclusive @realDonaldTrump updates! We will Make America Great Again! We need your support! We will we will MAKE AMERICA GREAT! We you
#
#
#
# Epoch 1/1
# 11479/11479 [==============================] - 31s 3ms/step - loss: 0.6584
# total chars:  74
# begin a conversation on how to make America safe again. Only this way will
#
#
#
# Epoch 1/1
# 11479/11479 [==============================] - 37s 3ms/step - loss: 0.6446
# total chars:  137
# carrillo_pete #make America great again. We need a outsider to bring class and discernment back to our nation. We need #DonaldTrump2016
#
#
#
# Epoch 1/1
# 11479/11479 [==============================] - 36s 3ms/step - loss: 0.6342
# total chars:  76
# packed house speech tomorrow. Big poll results today, Leading big everywhere
#
#
#
# Epoch 1/1
# 11479/11479 [==============================] - 36s 3ms/step - loss: 0.6236
# total chars:  136
# To fix America requires SUPERMAN but there is ONE BETTER DJT We must MAKE AMERICA GREAT AGAIN! @realDonaldTrump Addressing record crowd
#
#
#
# Epoch 1/1
# 11479/11479 [==============================] - 36s 3ms/step - loss: 0.6159
# total chars:  135
# MELANIATRUMP at OPO discussing my potential candidacy making America great again My @FoxNews @megynkelly int. on why I am considering
#
#
#
# Epoch 1/1
# 11479/11479 [==============================] - 36s 3ms/step - loss: 0.6094
# total chars:  141
# announcement on #TaxReform! Together, we are going to MAKE AMERICA GREAT AGAIN! #AmericaFirst Thank you Kirkwood Community College. Heading
#
#
#
# Epoch 1/1
# 11479/11479 [==============================] - 36s 3ms/step - loss: 0.6030
# total chars:  102
# losing the election, Russia, Russia, Russia. Despite this I have the economy booming and have possibly
#
#
#
# Epoch 1/1
# 11479/11479 [==============================] - 36s 3ms/step - loss: 0.5972
# total chars:  148
# results for our country. We will Make America Great Again! @realDonaldTrump MAKE AMERICA GREAT AGAIN! @Reedgs119 @realdonaldtrump @cleopattrausa
#
#
#
# Epoch 1/1
# 11479/11479 [==============================] - 36s 3ms/step - loss: 0.5922
# total chars:  96
# financial sacrifices to make america great again! We are going to have a great time in Cleveland
#
#
#
# Epoch 1/1
# 11479/11479 [==============================] - 36s 3ms/step - loss: 0.5862
# total chars:  90
# cases. He is so great. Because if we win tomorrow, we will be able to make America wealthy
#
#
#
# Epoch 1/1
# 11479/11479 [==============================] - 36s 3ms/step - loss: 0.5834
# total chars:  144
# election, and say this is by far the most important vote you've ever cast for anyone at any time. Once again, we are going to make America great
#
#
#
# Epoch 1/1
# 11479/11479 [==============================] - 36s 3ms/step - loss: 0.5798
# total chars:  101
# undo all of Obama's executive orders. I will deliver. Let's Make America Great Again! Our VISA system
#
#
#
# Epoch 1/1
# 11479/11479 [==============================] - 36s 3ms/step - loss: 0.5767
# total chars:  83
# Trump! VAST MAJORITY want Make America Great Again! We are no longer silent. We are
#
#
#
# Epoch 1/1
# 11479/11479 [==============================] - 36s 3ms/step - loss: 0.5737
# total chars:  147
# ASS! always believed in this Country! your going to make America Great Again! I am not in have no borders, look one all by our military and borders
#
#
#
# Epoch 1/1
# 11479/11479 [==============================] - 36s 3ms/step - loss: 0.5712
# total chars:  142
# become the People's House. American workers will be hired to do the job. We will put new American steel into the spine of this country. I will
#
#
#
# Epoch 1/1
# 11479/11479 [==============================] - 36s 3ms/step - loss: 0.5684
# total chars:  70
# Reading the comments of the leftists on here makes me nauseated. We SO
#
#
#
# Epoch 1/1
# 11479/11479 [==============================] - 35s 3ms/step - loss: 0.5671
# total chars:  142
# interviewed by Sam Clovis tomorrow at @MorningsideEdu in Sioux City at 10AM CT! Let's Make America Great Again! @Knight276 @realDonaldTrump
#
#
#
# Epoch 1/1
# 11479/11479 [==============================] - 36s 3ms/step - loss: 0.5644
# total chars:  98
# quickly lead to our ultimate goal MAKE AMERICA GREAT AGAIN! MAKE AMERICA GREAT AGAIN! MAKE AMERICA
#
#
#
# Epoch 1/1
# 11479/11479 [==============================] - 36s 3ms/step - loss: 0.5628
# total chars:  79
# CindyBl I voted 4 Reagan to make America Great. I will vote 4 @realDonaldTrump
#
#
#
# Epoch 1/1
# 11479/11479 [==============================] - 35s 3ms/step - loss: 0.5608
# total chars:  72
# ALLOWED!! VOTE VOTE VOTE TRUMP @AndyBran @realDonaldTrump @megynkelly
#
#
#
# Epoch 1/1
# 11479/11479 [==============================] - 36s 3ms/step - loss: 0.5597
# total chars:  144
# Needed Leaders who negotiate smart trade deals. Only one knows The Art of The Deal. Let's Make America Great Again! My @greta int. on @FoxNews
#
#
#
# Epoch 1/1
# 11479/11479 [==============================] - 36s 3ms/step - loss: 0.5572
# total chars:  142
# NOTHING will stop us in our quest to MAKE AMERICA SAFE AND GREAT AGAIN! #AmericaFirst... MAKE AMERICA GREAT AGAIN! Our country has tremendous
#
#
#
# Epoch 1/1
# 11479/11479 [==============================] - 36s 3ms/step - loss: 0.5554
# total chars:  123
# seen before. Together, we are going to MAKE AMERICA GREAT AGAIN! It is time to take back our country and MAKE AMERICA GREAT
#
#
#
# Epoch 1/1
# 11479/11479 [==============================] - 36s 3ms/step - loss: 0.5543
# total chars:  89
# what our country could accomplish if we started working together as One People, under One
#
#
#
# Epoch 1/1
# 11479/11479 [==============================] - 36s 3ms/step - loss: 0.5523
# total chars:  104
# IslesRBYanksFan Politicians are all talk and no action. Bush and Rubio couldn't answer simple question @
#
#
#
# Epoch 1/1
# 11479/11479 [==============================] - 36s 3ms/step - loss: 0.5514
# total chars:  98
# Because if we win tomorrow, we will be able to make America MAKE AMERICA GREAT AGAIN! MAKE AMERICA
#
#
#
# Epoch 1/1
# 11479/11479 [==============================] - 36s 3ms/step - loss: 0.5500
# total chars:  142
# staggering influence. Stay True! Great and savvy bizman! America GREAT! @realJoeMurray Hopefully tomorrow is the day we start to make AMERICA
#
#
#
# Epoch 1/1
# 11479/11479 [==============================] - 36s 3ms/step - loss: 0.5485
# total chars:  138
# bizman! America GREAT! @realJoeMurray Hopefully tomorrow is the day we start to make America great again! I will run, I will run, I, MAKE
#
#
#
# Epoch 1/1
# 11479/11479 [==============================] - 36s 3ms/step - loss: 0.5477
# total chars:  36
# Don't ever forget, we will, together
#
#
#
# Epoch 1/1
# 11479/11479 [==============================] - 36s 3ms/step - loss: 0.5461
# total chars:  143
# asset. I'm on board trump can make America great again. @incorrectpoliti Oh My are they starting to WAKE UP. MAKE AMERICA GREAT AGAIN! We will
#
#
#
# Epoch 1/1
# 11479/11479 [==============================] - 36s 3ms/step - loss: 0.5457
# total chars:  141
# Stevekwebb @realDonaldTrump Love it! @tedcruz is done. We need someone who is proven. @realDonaldTrump will make America Great Again again
#
#
#
# Epoch 1/1
# 11479/11479 [==============================] - 36s 3ms/step - loss: 0.5445
# total chars:  97
# NOTHING will stop us in our quest to MAKE AMERICA SAFE AND GREAT AGAIN! #Trump2016 #VoteTrumpSC
#
#
#
# Epoch 1/1
# 11479/11479 [==============================] - 36s 3ms/step - loss: 0.5443
# total chars:  135
# Many new jobs, high business enthusiasm,.. MAKE AMERICA GREAT AGAIN! Wacky totally unhinged Tom Steyer, who has been fighting me and my
#
#
#
# Epoch 1/1
# 11479/11479 [==============================] - 36s 3ms/step - loss: 0.5428
# total chars:  141
# Courageous Patriots have fought and died for our great American Flag we MUST honor and respect it! MAKE AMERICA GREAT AGAIN! @York, you will
#
#
#
# Epoch 1/1
# 11479/11479 [==============================] - 36s 3ms/step - loss: 0.5413
# total chars:  121
# 75 because it's all Trump, all the time. The time to get tough we hold all the cards. Let's Make America Great Again! Via
#
#
#
# Epoch 1/1
# 11479/11479 [==============================] - 36s 3ms/step - loss: 0.5407
# total chars:  89
# easily beat Hillary Clinton and I havn't even focused on her yet. On our way MAKE AMERICA
#
#
#
# Epoch 1/1
# 11479/11479 [==============================] - 36s 3ms/step - loss: 0.5392
# total chars:  139
# low energy. @SueSabo MEDIA WANTS A PUPPET. WE WANT DONALD TRUMP TO MAKE AMERICA GREAT AGAIN, LAST CHANCE TO MAKE AMERICA GREAT Thank you @
#
#
#
# Epoch 1/1
# 11479/11479 [==============================] - 37s 3ms/step - loss: 0.5387
# total chars:  99
# YEAR. WE MUST ALL WORK TOGETHER TO, FINALLY, MAKE AMERICA SAFE AGAIN AND GREAT AGAIN! Happy all the
#
#
#
# Epoch 1/1
# 11479/11479 [==============================] - 35s 3ms/step - loss: 0.5383
# total chars:  145
# 00 A. M. @ABC will be announcing new poll numbers. MAKE AMERICA GREAT AGAIN! @AmericaFirst Thank you Washington! Together, WE will MAKE AMERICA
#
#
#
# Epoch 1/1
# 11479/11479 [==============================] - 36s 3ms/step - loss: 0.5363
# total chars:  142
# You're going to look back at this election, and say this is by far the most important vote you've ever cast for anyone at any time. Once again
#
#
#
# Epoch 1/1
# 11479/11479 [==============================] - 36s 3ms/step - loss: 0.5358
# total chars:  77
# Dem debate except Donald is tweeting about it! @MintzShire @realDonaldTrump
#
#
#
# Epoch 1/1
# 11479/11479 [==============================] - 36s 3ms/step - loss: 0.5350
# total chars:  137
# Get out and VOTE tomorrow! We will MAKE AMERICA GREAT AGAIN! @DaveInKeno Mr. Trump, Sir, this country is, and has been, on a right. Make
#
#
#
# Epoch 1/1
# 11479/11479 [==============================] - 36s 3ms/step - loss: 0.5340
# total chars:  93
# Honesty will be restored. Republicans are the Party of Abraham Lincoln and, come November 8th
#
#
#
# Epoch 1/1
# 11479/11479 [==============================] - 36s 3ms/step - loss: 0.5338
# total chars:  109
# tuned! @Chris_R_2014 @WendyPeters What I admire is that Donald Trump loves this country. He will fight that
#
#
#
# Epoch 1/1
# 11479/11479 [==============================] - 36s 3ms/step - loss: 0.5326
# total chars:  139
# guy with the blue make America great again hat on or the one with the red make America or that woman with the beautiful blonde hair. I said
#
#
#
# Epoch 1/1
# 11479/11479 [==============================] - 36s 3ms/step - loss: 0.5321
# total chars:  117
# energy. @SueSabo MEDIA WANTS A PUPPET. WE WANT DONALD TRUMP TO MAKE AMERICA GREAT AGAIN, LAST CHANCE TO MAKE AMERICA
#
#
#
# Epoch 1/1
# 11479/11479 [==============================] - 36s 3ms/step - loss: 0.5318
# total chars:  143
# closely behind Jeb Bush but Bush will NEVER Make America Great Again! @the day and have the economy and jobs. MAKE AMERICA GREAT AGAIN! I will
#
#
#
# Epoch 1/1
# 11479/11479 [==============================] - 36s 3ms/step - loss: 0.5308
# total chars:  146
# the people. We Will Make America Wealthy Again. We Will Make America Strong Again. We Will Make America Wealthy Again. We Will Make America Strong
#
#
#
# Epoch 1/1
# 11479/11479 [==============================] - 36s 3ms/step - loss: 0.5292
# total chars:  139
# her cronies. Let's Make America Great Again! We need your support to get to the White House and defeat #CrookedHillary. Let's Make America
#
#
#
# Epoch 1/1
# 11479/11479 [==============================] - 36s 3ms/step - loss: 0.5290
# total chars:  120
# night. Thanks for the nice words. MAKE AMERICA GREAT AGAIN! #Trump2016 #VoteTrumpSC Thank you South Carolina! Together
#
#
#
# Epoch 1/1
# 11479/11479 [==============================] - 36s 3ms/step - loss: 0.5283
# total chars:  130
# Together, we will MAKE AMERICA SAFE AND GREAT AGAIN! #ImWithYou #AmericaFirst Together, we are going to MAKE AMERICA GREAT AGAIN
#
#
#
# Epoch 1/1
# 11479/11479 [==============================] - 35s 3ms/step - loss: 0.5281
# total chars:  74
# Pandorasandy1 @realDonaldTrump we need Donald Trump to make America great
#
#
#
# Epoch 1/1
# 11479/11479 [==============================] - 36s 3ms/step - loss: 0.5271
# total chars:  143
# specialists in conservation, not those with radical political agendas. It will be a future of conservation, of prosperity, and of great success
#
#
#
# Epoch 1/1
# 11479/11479 [==============================] - 36s 3ms/step - loss: 0.5259
# total chars:  110
# My @greta int. on @FoxNews with @MELANIATRUMP at OPO discussing my potential candidacy making America great
#
#
#
# Epoch 1/1
# 11479/11479 [==============================] - 36s 3ms/step - loss: 0.5259
# total chars:  99
# Lets MAKE AMERICA SAFE AND GREAT AGAIN with the American people. #AmericaFirst... Thank you Toledo
#
#
#
# Epoch 1/1
# 11479/11479 [==============================] - 36s 3ms/step - loss: 0.5248
# total chars:  153
# savvy bizman! America GREAT! @realJoeMurray Hopefully tomorrow is the day we start to make America great again! Looking forward to it, @realDonaldTrump
#
#
#
# Epoch 1/1
# 11479/11479 [==============================] - 36s 3ms/step - loss: 0.5244
# total chars:  129
# staggering influence. Stay True! Great and savvy bizman! America GREAT! @realJoeMurray Hopefully tomorrow is the day we start to
#
#
#
# Epoch 1/1
# 11479/11479 [==============================] - 36s 3ms/step - loss: 0.5243
# total chars:  126
# long way to go to MAKE AMERICA GREAT AGAIN! @videosigninc @@ birthday to the great @TheLeeGreenwood. You and your beautiful
#
#
#
# Epoch 1/1
# 11479/11479 [==============================] - 36s 3ms/step - loss: 0.5239
# total chars:  141
# P. M. on @FoxNews Turn off the football for 15 minutes, Make America Great Again! Via @CBNNews by @TheBrodyFile Donald Trump 'We Must Make
#
#
#
# Epoch 1/1
# 11479/11479 [==============================] - 36s 3ms/step - loss: 0.5230
# total chars:  142
# LEGAL again... He will make America LEGAL again... We will make America wealthy again. We will make America strong again. We will MAKE AMERICA
#
#
#
# Epoch 1/1
# 11479/11479 [==============================] - 36s 3ms/step - loss: 0.5222
# total chars:  74
# US gov't to do the same. Let's Make America Great Again! @williamgardanis
#
#
#
# Epoch 1/1
# 11479/11479 [==============================] - 36s 3ms/step - loss: 0.5218
# total chars:  143
# country. We will bring back our jobs. We will make America strong again. We will make America safe again. And we will make America strong again
#
#
#
# Epoch 1/1
# 11479/11479 [==============================] - 36s 3ms/step - loss: 0.5211
# total chars:  102
# believed in this Country! your going to make America Great Again! I am counting on your help to defeat
#
#
#
# Epoch 1/1
# 11479/11479 [==============================] - 36s 3ms/step - loss: 0.5207
# total chars:  120
# ted cruz stole your c slogan. Only you can really make america great again #Trump2016 @Doctor_Platek @realDonaldTrump
#
#
#
# Epoch 1/1
# 11479/11479 [==============================] - 36s 3ms/step - loss: 0.5206
# total chars:  87
# next few days. MAKE AMERICA GREAT AGAIN! Thank you Pennsylvania! Together, we are going
#
#
#
# Epoch 1/1
# 11479/11479 [==============================] - 36s 3ms/step - loss: 0.5207
# total chars:  137
# beautiful song have made such a difference. MAKE AMERICA GREAT AGAIN! In this this Republicans and you, and I will win for you. Together,
#
#
#
# Epoch 1/1
# 10368/11479 [==========================>...] - ETA: 3s - loss: 0.5155
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-27-b84a273f7e91> in <module>()
#       1 for i in range (0,200):
#       2     print('\n\n')
# ----> 3     model6.fit(X_version_byalltext, y_version_byalltext, batch_size=BATCH_SIZE, verbose=1, nb_epoch=1)
#       4     nb_epoch += 1
#       5     output_as_sentence(generate_words(model6))
#
# /usr/local/lib/python2.7/dist-packages/keras/models.pyc in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#     958                               initial_epoch=initial_epoch,
#     959                               steps_per_epoch=steps_per_epoch,
# --> 960                               validation_steps=validation_steps)
#     961
#     962     def evaluate(self, x, y, batch_size=32, verbose=1,
#
# /usr/local/lib/python2.7/dist-packages/keras/engine/training.pyc in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1655                               initial_epoch=initial_epoch,
#    1656                               steps_per_epoch=steps_per_epoch,
# -> 1657                               validation_steps=validation_steps)
#    1658
#    1659     def evaluate(self, x=None, y=None,
#
# /usr/local/lib/python2.7/dist-packages/keras/engine/training.pyc in _fit_loop(self, f, ins, out_labels, batch_size, epochs, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps)
#    1211                     batch_logs['size'] = len(batch_ids)
#    1212                     callbacks.on_batch_begin(batch_index, batch_logs)
# -> 1213                     outs = f(ins_batch)
#    1214                     if not isinstance(outs, list):
#    1215                         outs = [outs]
#
# /usr/local/lib/python2.7/dist-packages/keras/backend/tensorflow_backend.pyc in __call__(self, inputs)
#    2355         session = get_session()
#    2356         updated = session.run(fetches=fetches, feed_dict=feed_dict,
# -> 2357                               **self.session_kwargs)
#    2358         return updated[:len(self.outputs)]
#    2359
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in run(self, fetches, feed_dict, options, run_metadata)
#     887     try:
#     888       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 889                          run_metadata_ptr)
#     890       if run_metadata:
#     891         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1118     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1119       results = self._do_run(handle, final_targets, final_fetches,
# -> 1120                              feed_dict_tensor, options, run_metadata)
#    1121     else:
#    1122       results = []
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1315     if handle is None:
#    1316       return self._do_call(_run_fn, self._session, feeds, fetches, targets,
# -> 1317                            options, run_metadata)
#    1318     else:
#    1319       return self._do_call(_prun_fn, self._session, handle, feeds, fetches)
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _do_call(self, fn, *args)
#    1321   def _do_call(self, fn, *args):
#    1322     try:
# -> 1323       return fn(*args)
#    1324     except errors.OpError as e:
#    1325       message = compat.as_text(e.message)
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1300           return tf_session.TF_Run(session, options,
#    1301                                    feed_dict, fetch_list, target_list,
# -> 1302                                    status, run_metadata)
#    1303
#    1304     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %% [markdown]
# ## Generate tweets from models

# %% [markdown]
# ### Model 1
# 2016 & 2017 tweets, using version 1 of training set

# %%
model1.load_weights('model1/checkpoint_700_epoch_140.hdf5')
model1.compile(loss='categorical_crossentropy', optimizer='adam')

for i in range(0,20):
    print 'Model 1 Tweet ', i
    output_as_sentence(generate_words(model1))
# Out:
# Model 1 Tweet  0
# total chars:  75
# SERVER, and were rejected, still don t.....................................
# Model 1 Tweet  1
# total chars:  116
# gave Hillary Clinton a free pass for many bad deeds! Media wrong. I!??@@@@ FoxNews FoxNews run FBI his? MOVEMENT
# Model 1 Tweet  2
# total chars:  145
# outcry would be if@ SnoopDogg, bleached emails, had husband meet I Justice why going. Clinton. He was..............,,,,,....,,,,,,,,,,,,,,,,,,,,
# Model 1 Tweet  3
# total chars:  142
# Podesta Russian Company. Trump Russia story is no collusion." Russia. I......................................................................
# Model 1 Tweet  4
# total chars:  138
# historic dismissed idea that President I President? Jail!?? S! The Hunt! Hunt! Hunt Hunt Hunt felt Senator Senator Senator Senator Senator
# Model 1 Tweet  5
# total chars:  86
# since the election. Every story is badly slanted. We..................................
# Model 1 Tweet  6
# total chars:  59
# By the way, if Russia was working so hard on the? out......
# Model 1 Tweet  7
# total chars:  117
# covered by@ FoxNews or money from Russia to Clinton sale of find strong pass........................................
# Model 1 Tweet  8
# total chars:  143
# appreciate how" kind" President Obama was to the@@ FoxNews FoxNews Witch run W.? they????? immigrants??????????????????????????????????????
# Model 1 Tweet  9
# total chars:  120
# etc. I ve already given my opinion.......................................................... hasn.......................
# Model 1 Tweet  10
# total chars:  46
# Thanks scam and excuse for losing the election
# Model 1 Tweet  11
# total chars:  43
# Comey lied and leaked and totally protected
# Model 1 Tweet  12
# total chars:  143
# BEFORE Fake Media ask about the Dems dealings with Russia why not give him the info............................................................
# Model 1 Tweet  13
# total chars:  174
# Comey lied and leaked and totally protected Hillary Clinton. Tell I........................., the the,,.......................................................................
# Model 1 Tweet  14
# total chars:  26
# scam and excuse for losing
# Model 1 Tweet  15
# total chars:  148
# still beat Hillary in...............................................................................................................................
# Model 1 Tweet  16
# total chars:  111
# rejected, still don t..........................................................................................
# Model 1 Tweet  17
# total chars:  139
# speeches and social media. I had to........................................................................................................
# Model 1 Tweet  18
# total chars:  140
# Mike Flynn should ask for immunity in that this is a a paid is a total hoax, Russia, the deleted the to respect.............................
# Model 1 Tweet  19
# total chars:  96
# involved, he is OK with it. Tell that to Israel, many! e!!!.....................................

# %% [markdown]
# ### Model 2
# Show progression of model over epoch trainings

# %%
for e in range(20,101,20):

    model2.load_weights('model2/checkpoint_700_epoch_%s.hdf5' % e)
    model2.compile(loss='categorical_crossentropy', optimizer='adam')

    print 'TRAINED OVER %s EPOCHS\n\n' % e
    for i in range(1,6):
        print 'Model 2 Tweet ', i
        output_as_sentence(generate_words(model2))
        print '\n'
# Out:
# TRAINED OVER 20 EPOCHS
#
#
# Model 2 Tweet  1
# total chars:  85
# troyconway to take back our country and MAKE AMERICA GREAT AGAIN! Trump2016 must save
#
#
# Model 2 Tweet  2
# total chars:  87
# Flag. It is time to take an outsider to take an outsider to bring our American American
#
#
# Model 2 Tweet  3
# total chars:  63
# built on our common culture and values as one People, under One
#
#
# Model 2 Tweet  4
# total chars:  135
# TOGETHER we will MAKE AMERICA GREAT AGAIN! Thanks to the cronies. MAKE AMERICA. great.. GREAT GREAT.... MAKE. MAKE to MAKE AMERICA MAKE
#
#
# Model 2 Tweet  5
# total chars:  93
# 4@ realDonaldTrump to make AMERICA great again. We need a President to to the White American
#
#
# TRAINED OVER 40 EPOCHS
#
#
# Model 2 Tweet  1
# total chars:  140
# keep speaking the truth! The media has the your your your your best. order. MAKE. MAKE. MAKE. MAKE..........................................
#
#
# Model 2 Tweet  2
# total chars:  140
# VISA system is broken, like so much else in our country. MAKE AMERICA GREAT AGAIN.......... He. straffordnhgop. straffordnhgop. worker. Make
#
#
# Model 2 Tweet  3
# total chars:  124
# CRUZ 11 This is at the house@ vote and and vote for the vote of our country and MAKE AMERICA GREAT AGAIN! Trump2016... He s
#
#
# Model 2 Tweet  4
# total chars:  42
# WartburgCollege discussing how politicians
#
#
# Model 2 Tweet  5
# total chars:  48
# hired to do great president.. MAKE AMERICA GREAT
#
#
# TRAINED OVER 60 EPOCHS
#
#
# Model 2 Tweet  1
# total chars:  132
# wages, and amazing schools. I will MAKE AMERICA GREAT AGAIN! MAKE AMERICA GREAT AGAIN! MAKE AMERICA need to make are your Washington
#
#
# Model 2 Tweet  2
# total chars:  142
# discard the failed policies and division of the past of of by we we I I We July June We We We We We this June factories I we we we we we we we
#
#
# Model 2 Tweet  3
# total chars:  68
# People, under One God, saluting one, flag..... MAKE.. Rory Rory MAKE
#
#
# Model 2 Tweet  4
# total chars:  84
# goal MAKE AMERICA GREAT AGAIN! TRUMP 37 CRUZ 11 This is a big numbers Kellyannepolls
#
#
# Model 2 Tweet  5
# total chars:  126
# sound nice, but we have no choice in again.... Make. Make America GREAT the in the you to Make AMERICA GREAT GREAT GREAT GREAT
#
#
# TRAINED OVER 80 EPOCHS
#
#
# Model 2 Tweet  1
# total chars:  143
# enterprise reality. MAKE AMERICA GREAT with TRUMP 2016" Let will make America great again!!!!"@ realDonaldTrump@ megynkelly@@ one one one
#
#
# Model 2 Tweet  2
# total chars:  140
# else in our country. We will take back our country and MAKE AMERICA GREAT AGAIN! AmericaFirst..... You can help can Make America Great Again
#
#
# Model 2 Tweet  3
# total chars:  105
# Social Security Making America Great Again!!!!!!!!@ tedcruz,,,,,,,,,,,, and and,,,,, and and and and and
#
#
# Model 2 Tweet  4
# total chars:  237
# discard the failed policies and division of the past and we can that we Let Let keep Let make make Let Dream Dream mistake Let steel steel steel steel everywhere everywhere everywhere everywhere everywhere mistake onto onto onto onto One
#
#
# Model 2 Tweet  5
# total chars:  138
# need your support to get to the White House and making America great again. Make to Make Make Make Make Make Make Make be great steel Flag
#
#
# TRAINED OVER 100 EPOCHS
#
#
# Model 2 Tweet  1
# total chars:  137
# dumping ground for the world. Pols don t get it. Make America Great Again!!!!!!!!!!!!!! deals to MAKE to Make Make Make... Make Make Make
#
#
# Model 2 Tweet  2
# total chars:  54
# Totally meaningless, however, if we don for the future
#
#
# Model 2 Tweet  3
# total chars:  144
# foxandfriends. Keep it up! Make America Great Again!!!!!!!" Make to Make to time, great,,,,,,,,,,,,,,,,,, ways SuperBowl SuperBowl TheEconomist
#
#
# Model 2 Tweet  4
# total chars:  108
# tr3s3can@ realDonaldTrump@ realDonaldTrump Make America Great Again! Make AMERICA GREAT AGAIN!" Make will
#
#
# Model 2 Tweet  5
# total chars:  145
# discard the failed policies and division of the past, and country and nation who is for the Monday from not not about it at the with the@ Accord

# %% [markdown]
# ### Model 4

# %%
for e in range(20,141,20):

    model4.load_weights('model4/checkpoint_700_epoch_%s.hdf5' % e)
    model4.compile(loss='categorical_crossentropy', optimizer='adam')

    print 'TRAINED OVER %s EPOCHS\n\n' % e
    for i in range(1,6):
        print 'Model 4 Tweet ', i
        output_as_sentence(generate_words(model4))
        print '\n'
# Out:
# TRAINED OVER 20 EPOCHS
#
#
# Model 4 Tweet  1
# total chars:  136
# Tom Steyer, who has been fighting me and my Make America Great Again agenda from beginning, never wins elections! Together, we will Make
#
#
# Model 4 Tweet  2
# total chars:  130
# two from @realDonaldTrump about making America great again We must build a wall to secure our border. It will save lives and help
#
#
# Model 4 Tweet  3
# total chars:  63
# leadership. Let s Make America Great Again Via @ConcordNHPatch
#
#
# Model 4 Tweet  4
# total chars:  141
# Protect the rule of law! Let s Make America Great Again Government can be efficient with the right leadership. Let s Make America Great Again
#
#
# Model 4 Tweet  5
# total chars:  144
# Strength! Let s Make America Great Again! Today I will be rallying with with 15, 000 patriots in Arizona for border security! Let s Make America
#
#
# TRAINED OVER 40 EPOCHS
#
#
# Model 4 Tweet  1
# total chars:  140
# unlock the potential of every American community, and every American family, who yearns for a big rally with amazing people! I have one goal
#
#
# Model 4 Tweet  2
# total chars:  107
# devotion to each other and to their country are the traits that we need to make America great again. We are
#
#
# Model 4 Tweet  3
# total chars:  124
# conservative solutions. Let s make America great again! The right leadership can help economy while creating security around
#
#
# Model 4 Tweet  4
# total chars:  137
# low energy."" @SueSabo MEDIA WANTS A PUPPET. WE WANT DONALD TRUMP TO MAKE AMERICA GREAT AGAIN, LAST CHANCE TO MAKE AMERICA GREAT Thank
#
#
# Model 4 Tweet  5
# total chars:  140
# Center now for an 8pmE MAKE AMERICA GREAT AGAIN... Well, the Special Elections are over and those that want to MAKE AMERICA GREAT AGAIN! Get
#
#
# TRAINED OVER 60 EPOCHS
#
#
# Model 4 Tweet  1
# total chars:  143
# elites want Common Core so they can take education out of parental control. NO! Let s Make America Great Again!" @Knight276 @realDonaldTrump
#
#
# Model 4 Tweet  2
# total chars:  129
# Received a standing ovation in packed house @MorningsideEdu after Sam Clovis intro! Let s Make America Great Again! I am in Iowa
#
#
# Model 4 Tweet  3
# total chars:  105
# greatest hope that the Republican Party can be the home of the African American vote once again. Together
#
#
# Model 4 Tweet  4
# total chars:  142
# 4 @realDonaldTrump to #MakeAmericaGreatAgain #TRUMP Massive crowds already forming in Jacksonville will be and incredible day 12 noon! MAKE
#
#
# Model 4 Tweet  5
# total chars:  72
# OANN Trump is the only one who can make America great again." True!" @
#
#
# TRAINED OVER 80 EPOCHS
#
#
# Model 4 Tweet  1
# total chars:  79
# BreitbartNews by @rwildewrites" Donald Trump I Can Make America Great Again"
#
#
# Model 4 Tweet  2
# total chars:  140
# broken, like so much else in our country. We better get it fixed really fast. MAKE AMERICA GREAT AGAIN!" @dboiarsky @realDonaldTrump MAKE
#
#
# Model 4 Tweet  3
# total chars:  60
# Once again, we are going to have a government of, by and for
#
#
# Model 4 Tweet  4
# total chars:  135
# Fake News, all the money spent 0 The MAKE AMERICA GREAT AGAIN agenda is doing very well despite the distraction of the Witch Hunt. Many
#
#
# Model 4 Tweet  5
# total chars:  88
# accurate polls last time around. But #FakeNews likes to say we re in the 30 s. They are
#
#
# TRAINED OVER 100 EPOCHS
#
#
# Model 4 Tweet  1
# total chars:  143
# again. We will make America safe again. And we will make America great again. Thank you, everybody. We Will Make America Wealthy Again. We Will
#
#
# Model 4 Tweet  2
# total chars:  140
# the people. We Will Make America Wealthy Again. We Will Make America Strong Again. We Will Make America Safe Again. And We Will Make America
#
#
# Model 4 Tweet  3
# total chars:  35
# watched lowell mass speech. Awesome
#
#
# Model 4 Tweet  4
# total chars:  114
# totally unhinged Tom Steyer, who has been fighting me and my Make America Great Again agenda from beginning, never
#
#
# Model 4 Tweet  5
# total chars:  112
# After #Irma @POTUS is focused on saving lives, not swamp shenanigans. #Dobbs #MA... MAKE AMERICA GREAT AGAIN
#
#
# TRAINED OVER 120 EPOCHS
#
#
# Model 4 Tweet  1
# total chars:  136
# KWWL int. from @WartburgCollege discussing how politicians have failed us Making America Great Again! My @msnbc int w @krystalball at
#
#
# Model 4 Tweet  2
# total chars:  97
# across the country, Americans of every kind are coming together w one simple goal to MAKE AMERICA
#
#
# Model 4 Tweet  3
# total chars:  86
# HaloOneForTrump @FoxNews @CNN @GOP I love you Trump! MAKE AMERICA GREAT AGAIN!" Go
#
#
# Model 4 Tweet  4
# total chars:  132
# location. We are going to Make America Great Again! I am counting on your help to defeat Hillary Clinton and her cronies. Let s Make
#
#
# Model 4 Tweet  5
# total chars:  121
# Adam Scott are doing great! Watch on NBC at 3 00 P. M. MAKE AMERICA GREAT AGAIN! #AmericaFirst #Trump2016 Then, on June
#
#
# TRAINED OVER 140 EPOCHS
#
#
# Model 4 Tweet  1
# total chars:  136
# 4TH OF JULY TO EVERYONE! MAKE AMERICA GREAT AGAIN! We need jobs we need them fast. I am a job creator. None of the pols can or will. Let
#
#
# Model 4 Tweet  2
# total chars:  89
# hero America needs! #Trump2016" Thank you, I only want to make America great again!" @
#
#
# Model 4 Tweet  3
# total chars:  113
# worse almost ZERO growth this quarter. Nobody can beat me on the economy and jobs. MAKE AMERICA GREAT AGAIN Thank
#
#
# Model 4 Tweet  4
# total chars:  75
# Kaine is awful, Trump and Pence are the ticket.. no more lies, we are ready
#
#
# Model 4 Tweet  5
# total chars:  137
# watch Dem debate except Donald is tweeting about it!" @MintzShire @realDonaldTrump @007lLisav @CNN @CNNPolitics We need Trump Now!!

# %%
model4.load_weights('model4/checkpoint_700_epoch_140.hdf5')
model4.compile(loss='categorical_crossentropy', optimizer='adam')

for i in range(1,20):
    output_as_sentence(generate_words(model4))
    print '\n'
# Out:
# total chars:  157
# Kirkwood Community College. Heading to the U. S. Cellular Center now for an 8pmE MAKE AMERICA GREAT AGAIN... Well, the country of, together, be Doctor_Platek
#
#
# total chars:  130
# necessary to MAKE AMERICA GREAT AGAIN! Will be working all weekend in choosing the great men and women who will be helping to MAKE
#
#
# total chars:  129
# Totally meaningless, however, if we don t WIN IT ALL and Make America Great Again! We are going to have a great time in Cleveland
#
#
# total chars:  139
# where the crowd is amazing. Dr. Robert Jeffress will make the introduction. Make America Great Again! RT @williebosshog Make America Great
#
#
# total chars:  141
# LEADER to LEAD. Let s make America great again! VOTE TRUMP 2016"" @pnicastro1 @WayneNewtonMrLV He did give tremendous praise for you this
#
#
# total chars:  137
# nanaelaine7 @realDonaldTrump only YOU can make it GREAT again. Your plan is the only one inside reality. MAKE AMERICA GREAT with TRUMP"
#
#
# total chars:  137
# PianoBecca @realDonaldTrump No Amercian, really, can impact such staggering influence. Stay True! Great and savvy bizman! America GREAT!
#
#
# total chars:  140
# choice wealthy again. But we are going to make America great again. We re going to make America great again. This isn t about me; it s about
#
#
# total chars:  48
# EVERYONE! MAKE AMERICA GREAT AGAIN! We need jobs
#
#
# total chars:  141
# Needed Leaders who negotiate smart trade deals. Only one knows The Art of The Deal. Let s Make America Great Again! Huge Townhall tomorrow at
#
#
# total chars:  141
# How to Make America Great Again. Doing really well. Great Thanksgiving or Christmas present!" @burgettn @AB1132 @realDonaldTrump it s the
#
#
# total chars:  121
# WORK TOGETHER TO, FINALLY, MAKE AMERICA SAFE AGAIN AND GREAT AGAIN! A is New day and have a really amazing year. Together
#
#
# total chars:  100
# GOP Dinner. We can bring common sense to DC Make America Great Again! I ll be in Iowa tonight making
#
#
# total chars:  148
# PRESIDENTS DAY MAKE AMERICA GREAT AGAIN! Enjoy the #SuperBowl and then we continue MAKE AMERICA GREAT AGAIN! MAKE AMERICA GREAT AGAIN! MAKE AMERICA
#
#
# total chars:  104
# truth. Keep it up, Mr. Trump. You can help us make America great again. Never give up." We must restore
#
#
# total chars:  58
# SaijoSaijo75 @realDonaldTrump thank you for your personal
#
#
# total chars:  50
# their dumb, one sided panels when a podium speaker
#
#
# total chars:  126
# , we will MAKE AMERICA GREAT AGAIN! MAKE AMERICA GREAT AGAIN! MAKE AMERICA GREAT AGAIN! MAKE AMERICA GREAT AGAIN! MAKE AMERICA
#
#
# total chars:  127
# Social Security Making America Great Again!" @williamgardanis @realDonaldTrump To fix America requires SUPERMAN but there is

# %% [markdown]
# ## Model 6
# Most successful version

# %%
model6.load_weights('model6/checkpoint_700_epoch_80.hdf5')
model6.compile(loss='categorical_crossentropy', optimizer='adam')

for i in range(1,20):
    output_as_sentence(generate_words(model6))
    print '\n'
# Out:
# total chars:  138
# quarter. Nobody can beat me on the economy and jobs. MAKE AMERICA GREAT AGAIN! I will be in South Carolina all week. Saturday is BIG, BIG,
#
#
# total chars:  143
# endorse our speaker of the House, Paul Ryan. We are going to make America great again. We are going to make America great again. It can be! Our
#
#
# total chars:  142
# Confidence counts. @PianoBecca @realDonaldTrump No Amercian, really, can impact such staggering influence. Stay True! Great and savvy bizman
#
#
# total chars:  101
# Breaking Down the Trump Factor Let's Make America Great Again! Today I will be rallying with with 15,
#
#
# total chars:  133
# Via @DMRegister by @brianneDMR Trump Bring back jobs from overseas Let's Make America Great Again! New American vote for a security
#
#
# total chars:  129
# poorer in many cases. He is so great. Because if we win tomorrow, we will be country, and of business can or that in polls in any
#
#
# total chars:  115
# sold out! MAKE AMERICA GREAT AGAIN! Looking forward to being interviewed by Sam Clovis tomorrow at @MorningsideEdu
#
#
# total chars:  106
# July, @realDonaldTrump will take the first step in the process of making America great again! #Trump2016
#
#
# total chars:  124
# Come June July, @realDonaldTrump will take the first step in the process of making America great again! #Trump2016 Looking
#
#
# total chars:  106
# love you Trump! MAKE AMERICA GREAT AGAIN! Go out and @change in the very important swing states, and lost
#
#
# total chars:  145
# Leaders who negotiate smart trade deals. Only one knows The Art of The Deal. Let's Make America Great Again! @Trump2016 by @TheBrodyFile Donald
#
#
# total chars:  125
# CNNPolitics We need Trump Now!!! Make America Great Again! @Reuters in elected, I will going to MAKE AMERICA GREAT AGAIN! It
#
#
# total chars:  53
# Witch Hunt. Many new jobs, high business enthusiasm,.
#
#
# total chars:  141
# Pennsylvania! Fantastic crowd and people. MAKE AMERICA GREAT AGAIN! I will be in South Carolina all week. Saturday is BIG, BIG, BIG, BIG! Get
#
#
# total chars:  144
# DonaldTrump2016 @_Snurk We need @realDonaldTrump to MAKE AMERICA GREAT AGAIN! @Kellyannepolls After #They for the big day MAKE AMERICA GREAT
#
#
# total chars:  117
# How to Make America Great Again. Doing really well. Great Thanksgiving or Christmas MAKE. MAKE AMERICA GREAT AGAIN! I
#
#
# total chars:  141
# resort in U. S. Rory and Adam Scott are doing great! Watch on NBC at 3 00 P. M. The White House Rose Garden. MAKE AMERICA GREAT AGAIN! I will
#
#
# total chars:  126
# introduction. Make America Great Again! RT @they Donald @speaking and making. speech. a big speech in a duty to care for our
#
#
# total chars:  92
# Huge Townhall tomorrow at 5PM in the NH Barrington Middle School! Thanks to @straffordnhgop
